# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
#변수 선언
learning_rate = 0.001
num_epochs = 30
batch_size = 256
input_size = 784
hidden1_size = 256
hidden2_size = 256
output_size = 10 
display_step = 1

# %%
x = tf.placeholder(tf.float32,shape=[None,input_size])
y = tf.placeholder(tf.float32,shape=[None,output_size])

# %%
#Declare ANN model
def build_ANN(x):
    W1 = tf.Variable(tf.random_normal(shape=[input_size,hidden1_size]))
    b1 = tf.Variable(tf.random_normal(shape=[hidden1_size]))
    H1_output = tf.nn.relu(tf.matmul(x,W1)+b1)
    W2 = tf.Variable(tf.random_normal(shape=[hidden1_size,hidden2_size]))
    b2 = tf.Variable(tf.random_normal(shape=[hidden2_size]))
    H2_output = tf.nn.relu(tf.matmul(H1_output,W2)+b2)
    W_output = tf.Variable(tf.random_normal(shape=[hidden2_size,output_size]))
    b_output = tf.Variable(tf.random_normal(shape=[output_size]))
    logits = tf.matmul(H2_output,W_output) + b_output
    return logits

# %%
predicted_value = build_ANN(x)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=predicted_value,labels=y))
train_step = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for step in range(num_epochs):
        average_loss = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        for i in range(total_batch):
            batch_x , batch_y = mnist.train.next_batch(batch_size)
            _,current_loss = sess.run([train_step,cost],feed_dict={x:batch_x,y:batch_y})
            average_loss += current_loss/total_batch
            if step % display_step == 0:
                print("반복(step) : %d , 손실함수(cost) : %f"%((step+1),average_loss))
     
    correct_prediction = tf.equal(tf.argmax(predicted_value,1),tf.argmax(y,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction,"float"))
    print("정확도(Accuracy): %f"%(accuracy.eval(feed_dict={x:mnist.test.images,y:mnist.test.labels})))
# Out:
# 반복(step) : 1 , 손실함수(cost) : 12.889831
# 반복(step) : 1 , 손실함수(cost) : 24.766883
# 반복(step) : 1 , 손실함수(cost) : 35.675441
# 반복(step) : 1 , 손실함수(cost) : 46.536436
# 반복(step) : 1 , 손실함수(cost) : 56.541375
# 반복(step) : 1 , 손실함수(cost) : 66.523766
# 반복(step) : 1 , 손실함수(cost) : 74.859069
# 반복(step) : 1 , 손실함수(cost) : 82.876703
# 반복(step) : 1 , 손실함수(cost) : 90.367006
# 반복(step) : 1 , 손실함수(cost) : 97.707855
# 반복(step) : 1 , 손실함수(cost) : 104.281475
# 반복(step) : 1 , 손실함수(cost) : 110.650347
# 반복(step) : 1 , 손실함수(cost) : 116.510942
# 반복(step) : 1 , 손실함수(cost) : 122.406115
# 반복(step) : 1 , 손실함수(cost) : 127.786009
# 반복(step) : 1 , 손실함수(cost) : 133.211252
# 반복(step) : 1 , 손실함수(cost) : 138.795392
# 반복(step) : 1 , 손실함수(cost) : 143.522567
# 반복(step) : 1 , 손실함수(cost) : 148.253335
# 반복(step) : 1 , 손실함수(cost) : 152.936599
# 반복(step) : 1 , 손실함수(cost) : 156.992916
# 반복(step) : 1 , 손실함수(cost) : 161.458320
# 반복(step) : 1 , 손실함수(cost) : 165.718527
# 반복(step) : 1 , 손실함수(cost) : 169.592261
# 반복(step) : 1 , 손실함수(cost) : 173.409897
# 반복(step) : 1 , 손실함수(cost) : 177.369543
# 반복(step) : 1 , 손실함수(cost) : 180.890699
# 반복(step) : 1 , 손실함수(cost) : 184.679778
# 반복(step) : 1 , 손실함수(cost) : 187.997302
# 반복(step) : 1 , 손실함수(cost) : 191.504945
# 반복(step) : 1 , 손실함수(cost) : 194.918501
# 반복(step) : 1 , 손실함수(cost) : 198.129978
# 반복(step) : 1 , 손실함수(cost) : 201.390952
# 반복(step) : 1 , 손실함수(cost) : 204.038306
# 반복(step) : 1 , 손실함수(cost) : 206.516412
# 반복(step) : 1 , 손실함수(cost) : 209.383382
# 반복(step) : 1 , 손실함수(cost) : 212.394093
# 반복(step) : 1 , 손실함수(cost) : 214.958015
# 반복(step) : 1 , 손실함수(cost) : 217.481816
# 반복(step) : 1 , 손실함수(cost) : 220.166396
# 반복(step) : 1 , 손실함수(cost) : 222.669371
# 반복(step) : 1 , 손실함수(cost) : 225.396931
# 반복(step) : 1 , 손실함수(cost) : 227.793116
# 반복(step) : 1 , 손실함수(cost) : 229.856298
# 반복(step) : 1 , 손실함수(cost) : 232.269577
# 반복(step) : 1 , 손실함수(cost) : 234.398615
# 반복(step) : 1 , 손실함수(cost) : 236.540366
# 반복(step) : 1 , 손실함수(cost) : 238.510106
# 반복(step) : 1 , 손실함수(cost) : 240.196848
# 반복(step) : 1 , 손실함수(cost) : 242.136594
# 반복(step) : 1 , 손실함수(cost) : 243.928082
# 반복(step) : 1 , 손실함수(cost) : 245.871435
# 반복(step) : 1 , 손실함수(cost) : 247.581204
# 반복(step) : 1 , 손실함수(cost) : 249.599958
# 반복(step) : 1 , 손실함수(cost) : 250.922163
# 반복(step) : 1 , 손실함수(cost) : 252.671036
# 반복(step) : 1 , 손실함수(cost) : 254.288632
# 반복(step) : 1 , 손실함수(cost) : 255.705149
# 반복(step) : 1 , 손실함수(cost) : 257.323512
# 반복(step) : 1 , 손실함수(cost) : 258.952495
# 반복(step) : 1 , 손실함수(cost) : 260.437155
# 반복(step) : 1 , 손실함수(cost) : 262.152040
# 반복(step) : 1 , 손실함수(cost) : 263.532361
# 반복(step) : 1 , 손실함수(cost) : 265.041806
# 반복(step) : 1 , 손실함수(cost) : 266.323919
# 반복(step) : 1 , 손실함수(cost) : 267.752185
# 반복(step) : 1 , 손실함수(cost) : 269.320894
# 반복(step) : 1 , 손실함수(cost) : 270.565073
# 반복(step) : 1 , 손실함수(cost) : 271.939582
# 반복(step) : 1 , 손실함수(cost) : 273.378207
# 반복(step) : 1 , 손실함수(cost) : 274.677441
# 반복(step) : 1 , 손실함수(cost) : 276.133562
# 반복(step) : 1 , 손실함수(cost) : 277.395755
# 반복(step) : 1 , 손실함수(cost) : 278.494803
# 반복(step) : 1 , 손실함수(cost) : 279.720268
# 반복(step) : 1 , 손실함수(cost) : 280.856784
# 반복(step) : 1 , 손실함수(cost) : 281.981372
# 반복(step) : 1 , 손실함수(cost) : 282.964695
# 반복(step) : 1 , 손실함수(cost) : 284.255714
# 반복(step) : 1 , 손실함수(cost) : 285.375706
# 반복(step) : 1 , 손실함수(cost) : 286.270439
# 반복(step) : 1 , 손실함수(cost) : 287.440293
# 반복(step) : 1 , 손실함수(cost) : 288.414059
# 반복(step) : 1 , 손실함수(cost) : 289.642689
# 반복(step) : 1 , 손실함수(cost) : 290.558350
# 반복(step) : 1 , 손실함수(cost) : 291.725341
# 반복(step) : 1 , 손실함수(cost) : 292.512857
# 반복(step) : 1 , 손실함수(cost) : 293.405522
# 반복(step) : 1 , 손실함수(cost) : 294.452090
# 반복(step) : 1 , 손실함수(cost) : 295.477323
# 반복(step) : 1 , 손실함수(cost) : 296.513576
# 반복(step) : 1 , 손실함수(cost) : 297.506730
# 반복(step) : 1 , 손실함수(cost) : 298.543773
# 반복(step) : 1 , 손실함수(cost) : 299.509953
# 반복(step) : 1 , 손실함수(cost) : 300.565746
# 반복(step) : 1 , 손실함수(cost) : 301.450705
# 반복(step) : 1 , 손실함수(cost) : 302.323571
# 반복(step) : 1 , 손실함수(cost) : 303.328210
# 반복(step) : 1 , 손실함수(cost) : 304.331735
# 반복(step) : 1 , 손실함수(cost) : 305.449709
# 반복(step) : 1 , 손실함수(cost) : 306.212022
# 반복(step) : 1 , 손실함수(cost) : 307.074857
# 반복(step) : 1 , 손실함수(cost) : 308.058573
# 반복(step) : 1 , 손실함수(cost) : 308.927765
# 반복(step) : 1 , 손실함수(cost) : 309.970419
# 반복(step) : 1 , 손실함수(cost) : 310.925309
# 반복(step) : 1 , 손실함수(cost) : 311.690845
# 반복(step) : 1 , 손실함수(cost) : 312.429944
# 반복(step) : 1 , 손실함수(cost) : 313.205336
# 반복(step) : 1 , 손실함수(cost) : 313.967051
# 반복(step) : 1 , 손실함수(cost) : 314.708446
# 반복(step) : 1 , 손실함수(cost) : 315.353059
# 반복(step) : 1 , 손실함수(cost) : 316.152786
# 반복(step) : 1 , 손실함수(cost) : 316.929183
# 반복(step) : 1 , 손실함수(cost) : 317.661782
# 반복(step) : 1 , 손실함수(cost) : 318.285587
# 반복(step) : 1 , 손실함수(cost) : 319.143500
# 반복(step) : 1 , 손실함수(cost) : 319.830278
# 반복(step) : 1 , 손실함수(cost) : 320.603420
# 반복(step) : 1 , 손실함수(cost) : 321.353625
# 반복(step) : 1 , 손실함수(cost) : 322.022310
# 반복(step) : 1 , 손실함수(cost) : 322.760559
# 반복(step) : 1 , 손실함수(cost) : 323.467196
# 반복(step) : 1 , 손실함수(cost) : 324.185173
# 반복(step) : 1 , 손실함수(cost) : 324.865476
# 반복(step) : 1 , 손실함수(cost) : 325.542181
# 반복(step) : 1 , 손실함수(cost) : 326.298089
# 반복(step) : 1 , 손실함수(cost) : 327.109759
# 반복(step) : 1 , 손실함수(cost) : 327.862213
# 반복(step) : 1 , 손실함수(cost) : 328.440857
# 반복(step) : 1 , 손실함수(cost) : 329.057253
# 반복(step) : 1 , 손실함수(cost) : 329.661955
# 반복(step) : 1 , 손실함수(cost) : 330.230238
# 반복(step) : 1 , 손실함수(cost) : 330.810040
# 반복(step) : 1 , 손실함수(cost) : 331.506488
# 반복(step) : 1 , 손실함수(cost) : 332.190696
# 반복(step) : 1 , 손실함수(cost) : 332.856671
# 반복(step) : 1 , 손실함수(cost) : 333.392946
# 반복(step) : 1 , 손실함수(cost) : 333.875837
# 반복(step) : 1 , 손실함수(cost) : 334.461770
# 반복(step) : 1 , 손실함수(cost) : 335.197978
# 반복(step) : 1 , 손실함수(cost) : 335.802165
# 반복(step) : 1 , 손실함수(cost) : 336.455192
# 반복(step) : 1 , 손실함수(cost) : 337.131715
# 반복(step) : 1 , 손실함수(cost) : 337.819703
# 반복(step) : 1 , 손실함수(cost) : 338.331315
# 반복(step) : 1 , 손실함수(cost) : 339.077907
# 반복(step) : 1 , 손실함수(cost) : 339.659076
# 반복(step) : 1 , 손실함수(cost) : 340.216736
# 반복(step) : 1 , 손실함수(cost) : 340.924419
# 반복(step) : 1 , 손실함수(cost) : 341.649812
# 반복(step) : 1 , 손실함수(cost) : 342.060020
# 반복(step) : 1 , 손실함수(cost) : 342.568652
# 반복(step) : 1 , 손실함수(cost) : 343.115261
# 반복(step) : 1 , 손실함수(cost) : 343.729731
# 반복(step) : 1 , 손실함수(cost) : 344.323212
# 반복(step) : 1 , 손실함수(cost) : 344.812992
# 반복(step) : 1 , 손실함수(cost) : 345.306829
# 반복(step) : 1 , 손실함수(cost) : 345.869889
# 반복(step) : 1 , 손실함수(cost) : 346.525232
# 반복(step) : 1 , 손실함수(cost) : 346.912069
# 반복(step) : 1 , 손실함수(cost) : 347.496228
# 반복(step) : 1 , 손실함수(cost) : 348.176213
# 반복(step) : 1 , 손실함수(cost) : 348.727615
# 반복(step) : 1 , 손실함수(cost) : 349.086273
# 반복(step) : 1 , 손실함수(cost) : 349.711160
# 반복(step) : 1 , 손실함수(cost) : 350.256018
# 반복(step) : 1 , 손실함수(cost) : 350.765932
# 반복(step) : 1 , 손실함수(cost) : 351.296684
# 반복(step) : 1 , 손실함수(cost) : 351.688587
# 반복(step) : 1 , 손실함수(cost) : 352.174544
# 반복(step) : 1 , 손실함수(cost) : 352.814068
# 반복(step) : 1 , 손실함수(cost) : 353.399360
# 반복(step) : 1 , 손실함수(cost) : 353.909005
# 반복(step) : 1 , 손실함수(cost) : 354.516086
# 반복(step) : 1 , 손실함수(cost) : 355.005158
# 반복(step) : 1 , 손실함수(cost) : 355.412010
# 반복(step) : 1 , 손실함수(cost) : 355.947262
# 반복(step) : 1 , 손실함수(cost) : 356.314673
# 반복(step) : 1 , 손실함수(cost) : 356.883377
# 반복(step) : 1 , 손실함수(cost) : 357.382625
# 반복(step) : 1 , 손실함수(cost) : 357.883689
# 반복(step) : 1 , 손실함수(cost) : 358.374511
# 반복(step) : 1 , 손실함수(cost) : 358.781617
# 반복(step) : 1 , 손실함수(cost) : 359.347776
# 반복(step) : 1 , 손실함수(cost) : 359.661057
# 반복(step) : 1 , 손실함수(cost) : 360.156873
# 반복(step) : 1 , 손실함수(cost) : 360.653227
# 반복(step) : 1 , 손실함수(cost) : 361.026607
# 반복(step) : 1 , 손실함수(cost) : 361.515820
# 반복(step) : 1 , 손실함수(cost) : 361.973821
# 반복(step) : 1 , 손실함수(cost) : 362.349134
# 반복(step) : 1 , 손실함수(cost) : 362.701344
# 반복(step) : 1 , 손실함수(cost) : 363.100432
# 반복(step) : 1 , 손실함수(cost) : 363.554736
# 반복(step) : 1 , 손실함수(cost) : 364.000501
# 반복(step) : 1 , 손실함수(cost) : 364.631468
# 반복(step) : 1 , 손실함수(cost) : 365.158826
# 반복(step) : 1 , 손실함수(cost) : 365.561799
# 반복(step) : 1 , 손실함수(cost) : 366.105511
# 반복(step) : 1 , 손실함수(cost) : 366.551079
# 반복(step) : 1 , 손실함수(cost) : 367.088409
# 반복(step) : 1 , 손실함수(cost) : 367.563594
# 반복(step) : 1 , 손실함수(cost) : 367.982617
# 반복(step) : 1 , 손실함수(cost) : 368.462601
# 반복(step) : 1 , 손실함수(cost) : 368.819244
# 반복(step) : 1 , 손실함수(cost) : 369.403061
# 반복(step) : 1 , 손실함수(cost) : 369.827197
# 반복(step) : 1 , 손실함수(cost) : 370.295372
# 반복(step) : 1 , 손실함수(cost) : 370.796191
# 반복(step) : 1 , 손실함수(cost) : 371.242525
# 반복(step) : 1 , 손실함수(cost) : 371.819187
# 반복(step) : 1 , 손실함수(cost) : 372.298314
# 반복(step) : 1 , 손실함수(cost) : 372.778499
# 반복(step) : 2 , 손실함수(cost) : 0.358407
# 반복(step) : 2 , 손실함수(cost) : 0.840407
# 반복(step) : 2 , 손실함수(cost) : 1.194044
# 반복(step) : 2 , 손실함수(cost) : 1.519453
# 반복(step) : 2 , 손실함수(cost) : 2.197421
# 반복(step) : 2 , 손실함수(cost) : 2.717307
# 반복(step) : 2 , 손실함수(cost) : 3.246476
# 반복(step) : 2 , 손실함수(cost) : 3.801150
# 반복(step) : 2 , 손실함수(cost) : 4.440244
# 반복(step) : 2 , 손실함수(cost) : 4.813340
# 반복(step) : 2 , 손실함수(cost) : 5.255318
# 반복(step) : 2 , 손실함수(cost) : 5.533803
# 반복(step) : 2 , 손실함수(cost) : 5.948463
# 반복(step) : 2 , 손실함수(cost) : 6.400528
# 반복(step) : 2 , 손실함수(cost) : 6.858975
# 반복(step) : 2 , 손실함수(cost) : 7.191331
# 반복(step) : 2 , 손실함수(cost) : 7.479452
# 반복(step) : 2 , 손실함수(cost) : 7.962143
# 반복(step) : 2 , 손실함수(cost) : 8.364932
# 반복(step) : 2 , 손실함수(cost) : 8.790476
# 반복(step) : 2 , 손실함수(cost) : 9.111904
# 반복(step) : 2 , 손실함수(cost) : 9.445581
# 반복(step) : 2 , 손실함수(cost) : 10.079631
# 반복(step) : 2 , 손실함수(cost) : 10.456450
# 반복(step) : 2 , 손실함수(cost) : 10.859204
# 반복(step) : 2 , 손실함수(cost) : 11.240039
# 반복(step) : 2 , 손실함수(cost) : 11.541717
# 반복(step) : 2 , 손실함수(cost) : 11.887933
# 반복(step) : 2 , 손실함수(cost) : 12.383157
# 반복(step) : 2 , 손실함수(cost) : 12.900823
# 반복(step) : 2 , 손실함수(cost) : 13.229406
# 반복(step) : 2 , 손실함수(cost) : 13.576010
# 반복(step) : 2 , 손실함수(cost) : 14.027636
# 반복(step) : 2 , 손실함수(cost) : 14.388263
# 반복(step) : 2 , 손실함수(cost) : 14.870486
# 반복(step) : 2 , 손실함수(cost) : 15.280135
# 반복(step) : 2 , 손실함수(cost) : 15.584749
# 반복(step) : 2 , 손실함수(cost) : 15.917121
# 반복(step) : 2 , 손실함수(cost) : 16.199492
# 반복(step) : 2 , 손실함수(cost) : 16.435375
# 반복(step) : 2 , 손실함수(cost) : 16.822597
# 반복(step) : 2 , 손실함수(cost) : 17.149450
# 반복(step) : 2 , 손실함수(cost) : 17.500393
# 반복(step) : 2 , 손실함수(cost) : 17.876916
# 반복(step) : 2 , 손실함수(cost) : 18.111660
# 반복(step) : 2 , 손실함수(cost) : 18.478800
# 반복(step) : 2 , 손실함수(cost) : 18.773249
# 반복(step) : 2 , 손실함수(cost) : 19.269393
# 반복(step) : 2 , 손실함수(cost) : 19.555105
# 반복(step) : 2 , 손실함수(cost) : 19.879154
# 반복(step) : 2 , 손실함수(cost) : 20.349898
# 반복(step) : 2 , 손실함수(cost) : 20.684913
# 반복(step) : 2 , 손실함수(cost) : 21.068054
# 반복(step) : 2 , 손실함수(cost) : 21.430449
# 반복(step) : 2 , 손실함수(cost) : 21.805303
# 반복(step) : 2 , 손실함수(cost) : 22.164463
# 반복(step) : 2 , 손실함수(cost) : 22.491909
# 반복(step) : 2 , 손실함수(cost) : 22.900567
# 반복(step) : 2 , 손실함수(cost) : 23.271018
# 반복(step) : 2 , 손실함수(cost) : 23.513431
# 반복(step) : 2 , 손실함수(cost) : 23.905076
# 반복(step) : 2 , 손실함수(cost) : 24.234864
# 반복(step) : 2 , 손실함수(cost) : 24.552311
# 반복(step) : 2 , 손실함수(cost) : 24.935238
# 반복(step) : 2 , 손실함수(cost) : 25.327823
# 반복(step) : 2 , 손실함수(cost) : 25.705498
# 반복(step) : 2 , 손실함수(cost) : 26.167964
# 반복(step) : 2 , 손실함수(cost) : 26.510442
# 반복(step) : 2 , 손실함수(cost) : 26.918142
# 반복(step) : 2 , 손실함수(cost) : 27.277764
# 반복(step) : 2 , 손실함수(cost) : 27.577119
# 반복(step) : 2 , 손실함수(cost) : 27.938666
# 반복(step) : 2 , 손실함수(cost) : 28.219305
# 반복(step) : 2 , 손실함수(cost) : 28.546184
# 반복(step) : 2 , 손실함수(cost) : 28.820910
# 반복(step) : 2 , 손실함수(cost) : 29.068954
# 반복(step) : 2 , 손실함수(cost) : 29.401094
# 반복(step) : 2 , 손실함수(cost) : 29.733913
# 반복(step) : 2 , 손실함수(cost) : 29.948558
# 반복(step) : 2 , 손실함수(cost) : 30.271035
# 반복(step) : 2 , 손실함수(cost) : 30.609340
# 반복(step) : 2 , 손실함수(cost) : 30.844204
# 반복(step) : 2 , 손실함수(cost) : 31.339520
# 반복(step) : 2 , 손실함수(cost) : 31.584233
# 반복(step) : 2 , 손실함수(cost) : 31.986669
# 반복(step) : 2 , 손실함수(cost) : 32.445170
# 반복(step) : 2 , 손실함수(cost) : 32.709454
# 반복(step) : 2 , 손실함수(cost) : 33.100055
# 반복(step) : 2 , 손실함수(cost) : 33.410377
# 반복(step) : 2 , 손실함수(cost) : 33.745838
# 반복(step) : 2 , 손실함수(cost) : 34.003677
# 반복(step) : 2 , 손실함수(cost) : 34.358373
# 반복(step) : 2 , 손실함수(cost) : 34.644628
# 반복(step) : 2 , 손실함수(cost) : 34.972670
# 반복(step) : 2 , 손실함수(cost) : 35.334947
# 반복(step) : 2 , 손실함수(cost) : 35.511954
# 반복(step) : 2 , 손실함수(cost) : 35.768052
# 반복(step) : 2 , 손실함수(cost) : 36.004989
# 반복(step) : 2 , 손실함수(cost) : 36.327624
# 반복(step) : 2 , 손실함수(cost) : 36.703648
# 반복(step) : 2 , 손실함수(cost) : 36.981731
# 반복(step) : 2 , 손실함수(cost) : 37.226579
# 반복(step) : 2 , 손실함수(cost) : 37.487763
# 반복(step) : 2 , 손실함수(cost) : 37.757491
# 반복(step) : 2 , 손실함수(cost) : 37.970400
# 반복(step) : 2 , 손실함수(cost) : 38.386822
# 반복(step) : 2 , 손실함수(cost) : 38.677086
# 반복(step) : 2 , 손실함수(cost) : 38.996448
# 반복(step) : 2 , 손실함수(cost) : 39.393547
# 반복(step) : 2 , 손실함수(cost) : 39.807121
# 반복(step) : 2 , 손실함수(cost) : 40.162496
# 반복(step) : 2 , 손실함수(cost) : 40.437896
# 반복(step) : 2 , 손실함수(cost) : 40.709471
# 반복(step) : 2 , 손실함수(cost) : 41.098129
# 반복(step) : 2 , 손실함수(cost) : 41.333118
# 반복(step) : 2 , 손실함수(cost) : 41.673892
# 반복(step) : 2 , 손실함수(cost) : 41.918625
# 반복(step) : 2 , 손실함수(cost) : 42.255093
# 반복(step) : 2 , 손실함수(cost) : 42.522370
# 반복(step) : 2 , 손실함수(cost) : 42.971487
# 반복(step) : 2 , 손실함수(cost) : 43.235000
# 반복(step) : 2 , 손실함수(cost) : 43.435773
# 반복(step) : 2 , 손실함수(cost) : 43.639789
# 반복(step) : 2 , 손실함수(cost) : 44.023705
# 반복(step) : 2 , 손실함수(cost) : 44.306077
# 반복(step) : 2 , 손실함수(cost) : 44.583648
# 반복(step) : 2 , 손실함수(cost) : 44.863058
# 반복(step) : 2 , 손실함수(cost) : 45.115350
# 반복(step) : 2 , 손실함수(cost) : 45.417258
# 반복(step) : 2 , 손실함수(cost) : 45.824726
# 반복(step) : 2 , 손실함수(cost) : 45.982311
# 반복(step) : 2 , 손실함수(cost) : 46.312871
# 반복(step) : 2 , 손실함수(cost) : 46.593396
# 반복(step) : 2 , 손실함수(cost) : 46.882765
# 반복(step) : 2 , 손실함수(cost) : 47.165636
# 반복(step) : 2 , 손실함수(cost) : 47.432488
# 반복(step) : 2 , 손실함수(cost) : 47.772686
# 반복(step) : 2 , 손실함수(cost) : 48.014898
# 반복(step) : 2 , 손실함수(cost) : 48.264456
# 반복(step) : 2 , 손실함수(cost) : 48.602172
# 반복(step) : 2 , 손실함수(cost) : 49.000654
# 반복(step) : 2 , 손실함수(cost) : 49.320543
# 반복(step) : 2 , 손실함수(cost) : 49.696135
# 반복(step) : 2 , 손실함수(cost) : 50.072686
# 반복(step) : 2 , 손실함수(cost) : 50.441644
# 반복(step) : 2 , 손실함수(cost) : 50.705986
# 반복(step) : 2 , 손실함수(cost) : 51.020366
# 반복(step) : 2 , 손실함수(cost) : 51.268081
# 반복(step) : 2 , 손실함수(cost) : 51.516487
# 반복(step) : 2 , 손실함수(cost) : 51.808941
# 반복(step) : 2 , 손실함수(cost) : 52.137700
# 반복(step) : 2 , 손실함수(cost) : 52.404758
# 반복(step) : 2 , 손실함수(cost) : 52.735590
# 반복(step) : 2 , 손실함수(cost) : 53.060835
# 반복(step) : 2 , 손실함수(cost) : 53.364691
# 반복(step) : 2 , 손실함수(cost) : 53.567750
# 반복(step) : 2 , 손실함수(cost) : 53.882413
# 반복(step) : 2 , 손실함수(cost) : 54.198201
# 반복(step) : 2 , 손실함수(cost) : 54.429943
# 반복(step) : 2 , 손실함수(cost) : 54.673715
# 반복(step) : 2 , 손실함수(cost) : 54.982209
# 반복(step) : 2 , 손실함수(cost) : 55.325957
# 반복(step) : 2 , 손실함수(cost) : 55.539035
# 반복(step) : 2 , 손실함수(cost) : 55.827323
# 반복(step) : 2 , 손실함수(cost) : 56.094398
# 반복(step) : 2 , 손실함수(cost) : 56.425682
# 반복(step) : 2 , 손실함수(cost) : 56.831425
# 반복(step) : 2 , 손실함수(cost) : 57.107501
# 반복(step) : 2 , 손실함수(cost) : 57.412550
# 반복(step) : 2 , 손실함수(cost) : 57.730131
# 반복(step) : 2 , 손실함수(cost) : 57.997080
# 반복(step) : 2 , 손실함수(cost) : 58.314671
# 반복(step) : 2 , 손실함수(cost) : 58.649842
# 반복(step) : 2 , 손실함수(cost) : 58.977065
# 반복(step) : 2 , 손실함수(cost) : 59.229584
# 반복(step) : 2 , 손실함수(cost) : 59.575734
# 반복(step) : 2 , 손실함수(cost) : 59.803837
# 반복(step) : 2 , 손실함수(cost) : 60.068949
# 반복(step) : 2 , 손실함수(cost) : 60.353848
# 반복(step) : 2 , 손실함수(cost) : 60.636303
# 반복(step) : 2 , 손실함수(cost) : 60.932168
# 반복(step) : 2 , 손실함수(cost) : 61.202453
# 반복(step) : 2 , 손실함수(cost) : 61.431540
# 반복(step) : 2 , 손실함수(cost) : 61.813393
# 반복(step) : 2 , 손실함수(cost) : 62.068024
# 반복(step) : 2 , 손실함수(cost) : 62.267628
# 반복(step) : 2 , 손실함수(cost) : 62.512186
# 반복(step) : 2 , 손실함수(cost) : 62.809167
# 반복(step) : 2 , 손실함수(cost) : 63.003608
# 반복(step) : 2 , 손실함수(cost) : 63.347308
# 반복(step) : 2 , 손실함수(cost) : 63.673192
# 반복(step) : 2 , 손실함수(cost) : 63.916923
# 반복(step) : 2 , 손실함수(cost) : 64.169384
# 반복(step) : 2 , 손실함수(cost) : 64.357571
# 반복(step) : 2 , 손실함수(cost) : 64.607188
# 반복(step) : 2 , 손실함수(cost) : 64.917570
# 반복(step) : 2 , 손실함수(cost) : 65.162383
# 반복(step) : 2 , 손실함수(cost) : 65.371234
# 반복(step) : 2 , 손실함수(cost) : 65.631778
# 반복(step) : 2 , 손실함수(cost) : 65.855641
# 반복(step) : 2 , 손실함수(cost) : 66.069729
# 반복(step) : 2 , 손실함수(cost) : 66.272332
# 반복(step) : 2 , 손실함수(cost) : 66.576549
# 반복(step) : 2 , 손실함수(cost) : 66.719120
# 반복(step) : 2 , 손실함수(cost) : 67.064591
# 반복(step) : 2 , 손실함수(cost) : 67.276149
# 반복(step) : 2 , 손실함수(cost) : 67.549397
# 반복(step) : 2 , 손실함수(cost) : 67.830740
# 반복(step) : 2 , 손실함수(cost) : 68.024442
# 반복(step) : 2 , 손실함수(cost) : 68.355612
# 반복(step) : 2 , 손실함수(cost) : 68.607624
# 반복(step) : 2 , 손실함수(cost) : 68.825029
# 반복(step) : 2 , 손실함수(cost) : 69.027529
# 반복(step) : 2 , 손실함수(cost) : 69.295822
# 반복(step) : 3 , 손실함수(cost) : 0.354773
# 반복(step) : 3 , 손실함수(cost) : 0.621638
# 반복(step) : 3 , 손실함수(cost) : 0.846273
# 반복(step) : 3 , 손실함수(cost) : 1.079962
# 반복(step) : 3 , 손실함수(cost) : 1.389193
# 반복(step) : 3 , 손실함수(cost) : 1.613892
# 반복(step) : 3 , 손실함수(cost) : 1.876735
# 반복(step) : 3 , 손실함수(cost) : 2.257021
# 반복(step) : 3 , 손실함수(cost) : 2.467472
# 반복(step) : 3 , 손실함수(cost) : 2.639401
# 반복(step) : 3 , 손실함수(cost) : 2.895448
# 반복(step) : 3 , 손실함수(cost) : 3.170072
# 반복(step) : 3 , 손실함수(cost) : 3.488244
# 반복(step) : 3 , 손실함수(cost) : 3.719322
# 반복(step) : 3 , 손실함수(cost) : 3.917750
# 반복(step) : 3 , 손실함수(cost) : 4.231081
# 반복(step) : 3 , 손실함수(cost) : 4.449805
# 반복(step) : 3 , 손실함수(cost) : 4.678100
# 반복(step) : 3 , 손실함수(cost) : 4.979303
# 반복(step) : 3 , 손실함수(cost) : 5.255637
# 반복(step) : 3 , 손실함수(cost) : 5.521077
# 반복(step) : 3 , 손실함수(cost) : 5.709054
# 반복(step) : 3 , 손실함수(cost) : 5.873523
# 반복(step) : 3 , 손실함수(cost) : 6.121793
# 반복(step) : 3 , 손실함수(cost) : 6.365272
# 반복(step) : 3 , 손실함수(cost) : 6.741762
# 반복(step) : 3 , 손실함수(cost) : 6.917821
# 반복(step) : 3 , 손실함수(cost) : 7.182537
# 반복(step) : 3 , 손실함수(cost) : 7.441729
# 반복(step) : 3 , 손실함수(cost) : 7.685034
# 반복(step) : 3 , 손실함수(cost) : 7.943713
# 반복(step) : 3 , 손실함수(cost) : 8.130759
# 반복(step) : 3 , 손실함수(cost) : 8.447035
# 반복(step) : 3 , 손실함수(cost) : 8.673382
# 반복(step) : 3 , 손실함수(cost) : 8.826918
# 반복(step) : 3 , 손실함수(cost) : 9.032471
# 반복(step) : 3 , 손실함수(cost) : 9.262521
# 반복(step) : 3 , 손실함수(cost) : 9.482157
# 반복(step) : 3 , 손실함수(cost) : 9.788576
# 반복(step) : 3 , 손실함수(cost) : 9.990496
# 반복(step) : 3 , 손실함수(cost) : 10.182957
# 반복(step) : 3 , 손실함수(cost) : 10.403683
# 반복(step) : 3 , 손실함수(cost) : 10.656297
# 반복(step) : 3 , 손실함수(cost) : 10.828424
# 반복(step) : 3 , 손실함수(cost) : 11.030284
# 반복(step) : 3 , 손실함수(cost) : 11.243521
# 반복(step) : 3 , 손실함수(cost) : 11.521380
# 반복(step) : 3 , 손실함수(cost) : 11.730562
# 반복(step) : 3 , 손실함수(cost) : 11.939501
# 반복(step) : 3 , 손실함수(cost) : 12.304346
# 반복(step) : 3 , 손실함수(cost) : 12.501171
# 반복(step) : 3 , 손실함수(cost) : 12.768429
# 반복(step) : 3 , 손실함수(cost) : 12.931005
# 반복(step) : 3 , 손실함수(cost) : 13.104829
# 반복(step) : 3 , 손실함수(cost) : 13.336998
# 반복(step) : 3 , 손실함수(cost) : 13.478347
# 반복(step) : 3 , 손실함수(cost) : 13.735889
# 반복(step) : 3 , 손실함수(cost) : 13.954968
# 반복(step) : 3 , 손실함수(cost) : 14.229382
# 반복(step) : 3 , 손실함수(cost) : 14.431997
# 반복(step) : 3 , 손실함수(cost) : 14.715743
# 반복(step) : 3 , 손실함수(cost) : 14.901406
# 반복(step) : 3 , 손실함수(cost) : 15.091823
# 반복(step) : 3 , 손실함수(cost) : 15.334535
# 반복(step) : 3 , 손실함수(cost) : 15.526799
# 반복(step) : 3 , 손실함수(cost) : 15.658124
# 반복(step) : 3 , 손실함수(cost) : 15.795227
# 반복(step) : 3 , 손실함수(cost) : 15.967704
# 반복(step) : 3 , 손실함수(cost) : 16.232203
# 반복(step) : 3 , 손실함수(cost) : 16.396520
# 반복(step) : 3 , 손실함수(cost) : 16.637867
# 반복(step) : 3 , 손실함수(cost) : 16.852922
# 반복(step) : 3 , 손실함수(cost) : 17.041240
# 반복(step) : 3 , 손실함수(cost) : 17.250191
# 반복(step) : 3 , 손실함수(cost) : 17.470085
# 반복(step) : 3 , 손실함수(cost) : 17.737311
# 반복(step) : 3 , 손실함수(cost) : 17.865424
# 반복(step) : 3 , 손실함수(cost) : 18.022889
# 반복(step) : 3 , 손실함수(cost) : 18.168156
# 반복(step) : 3 , 손실함수(cost) : 18.333195
# 반복(step) : 3 , 손실함수(cost) : 18.556106
# 반복(step) : 3 , 손실함수(cost) : 18.739320
# 반복(step) : 3 , 손실함수(cost) : 18.922612
# 반복(step) : 3 , 손실함수(cost) : 19.221079
# 반복(step) : 3 , 손실함수(cost) : 19.416692
# 반복(step) : 3 , 손실함수(cost) : 19.673773
# 반복(step) : 3 , 손실함수(cost) : 19.866372
# 반복(step) : 3 , 손실함수(cost) : 20.085727
# 반복(step) : 3 , 손실함수(cost) : 20.290653
# 반복(step) : 3 , 손실함수(cost) : 20.469785
# 반복(step) : 3 , 손실함수(cost) : 20.709598
# 반복(step) : 3 , 손실함수(cost) : 20.969665
# 반복(step) : 3 , 손실함수(cost) : 21.204414
# 반복(step) : 3 , 손실함수(cost) : 21.431669
# 반복(step) : 3 , 손실함수(cost) : 21.650403
# 반복(step) : 3 , 손실함수(cost) : 21.816261
# 반복(step) : 3 , 손실함수(cost) : 22.019542
# 반복(step) : 3 , 손실함수(cost) : 22.151080
# 반복(step) : 3 , 손실함수(cost) : 22.326142
# 반복(step) : 3 , 손실함수(cost) : 22.569439
# 반복(step) : 3 , 손실함수(cost) : 22.754615
# 반복(step) : 3 , 손실함수(cost) : 22.986911
# 반복(step) : 3 , 손실함수(cost) : 23.172619
# 반복(step) : 3 , 손실함수(cost) : 23.404106
# 반복(step) : 3 , 손실함수(cost) : 23.606884
# 반복(step) : 3 , 손실함수(cost) : 23.753402
# 반복(step) : 3 , 손실함수(cost) : 23.883329
# 반복(step) : 3 , 손실함수(cost) : 24.146325
# 반복(step) : 3 , 손실함수(cost) : 24.408032
# 반복(step) : 3 , 손실함수(cost) : 24.623816
# 반복(step) : 3 , 손실함수(cost) : 24.861333
# 반복(step) : 3 , 손실함수(cost) : 25.195961
# 반복(step) : 3 , 손실함수(cost) : 25.359906
# 반복(step) : 3 , 손실함수(cost) : 25.570618
# 반복(step) : 3 , 손실함수(cost) : 25.706944
# 반복(step) : 3 , 손실함수(cost) : 25.917055
# 반복(step) : 3 , 손실함수(cost) : 26.137368
# 반복(step) : 3 , 손실함수(cost) : 26.339895
# 반복(step) : 3 , 손실함수(cost) : 26.584766
# 반복(step) : 3 , 손실함수(cost) : 26.793056
# 반복(step) : 3 , 손실함수(cost) : 27.006718
# 반복(step) : 3 , 손실함수(cost) : 27.181924
# 반복(step) : 3 , 손실함수(cost) : 27.332084
# 반복(step) : 3 , 손실함수(cost) : 27.573564
# 반복(step) : 3 , 손실함수(cost) : 27.734531
# 반복(step) : 3 , 손실함수(cost) : 27.835392
# 반복(step) : 3 , 손실함수(cost) : 28.129804
# 반복(step) : 3 , 손실함수(cost) : 28.326956
# 반복(step) : 3 , 손실함수(cost) : 28.553893
# 반복(step) : 3 , 손실함수(cost) : 28.792958
# 반복(step) : 3 , 손실함수(cost) : 29.058749
# 반복(step) : 3 , 손실함수(cost) : 29.367164
# 반복(step) : 3 , 손실함수(cost) : 29.557869
# 반복(step) : 3 , 손실함수(cost) : 29.845522
# 반복(step) : 3 , 손실함수(cost) : 30.089615
# 반복(step) : 3 , 손실함수(cost) : 30.249272
# 반복(step) : 3 , 손실함수(cost) : 30.393099
# 반복(step) : 3 , 손실함수(cost) : 30.595552
# 반복(step) : 3 , 손실함수(cost) : 30.871863
# 반복(step) : 3 , 손실함수(cost) : 31.090522
# 반복(step) : 3 , 손실함수(cost) : 31.328253
# 반복(step) : 3 , 손실함수(cost) : 31.527031
# 반복(step) : 3 , 손실함수(cost) : 31.669375
# 반복(step) : 3 , 손실함수(cost) : 31.863905
# 반복(step) : 3 , 손실함수(cost) : 32.099937
# 반복(step) : 3 , 손실함수(cost) : 32.349183
# 반복(step) : 3 , 손실함수(cost) : 32.577854
# 반복(step) : 3 , 손실함수(cost) : 32.782949
# 반복(step) : 3 , 손실함수(cost) : 32.969445
# 반복(step) : 3 , 손실함수(cost) : 33.193058
# 반복(step) : 3 , 손실함수(cost) : 33.492335
# 반복(step) : 3 , 손실함수(cost) : 33.648619
# 반복(step) : 3 , 손실함수(cost) : 33.791626
# 반복(step) : 3 , 손실함수(cost) : 34.007001
# 반복(step) : 3 , 손실함수(cost) : 34.203007
# 반복(step) : 3 , 손실함수(cost) : 34.441450
# 반복(step) : 3 , 손실함수(cost) : 34.641445
# 반복(step) : 3 , 손실함수(cost) : 34.802057
# 반복(step) : 3 , 손실함수(cost) : 34.984178
# 반복(step) : 3 , 손실함수(cost) : 35.129165
# 반복(step) : 3 , 손실함수(cost) : 35.331075
# 반복(step) : 3 , 손실함수(cost) : 35.607444
# 반복(step) : 3 , 손실함수(cost) : 35.780321
# 반복(step) : 3 , 손실함수(cost) : 35.889825
# 반복(step) : 3 , 손실함수(cost) : 36.159943
# 반복(step) : 3 , 손실함수(cost) : 36.267283
# 반복(step) : 3 , 손실함수(cost) : 36.492498
# 반복(step) : 3 , 손실함수(cost) : 36.628138
# 반복(step) : 3 , 손실함수(cost) : 36.878215
# 반복(step) : 3 , 손실함수(cost) : 37.060474
# 반복(step) : 3 , 손실함수(cost) : 37.182001
# 반복(step) : 3 , 손실함수(cost) : 37.347809
# 반복(step) : 3 , 손실함수(cost) : 37.566104
# 반복(step) : 3 , 손실함수(cost) : 37.666783
# 반복(step) : 3 , 손실함수(cost) : 37.829730
# 반복(step) : 3 , 손실함수(cost) : 37.962608
# 반복(step) : 3 , 손실함수(cost) : 38.191920
# 반복(step) : 3 , 손실함수(cost) : 38.383607
# 반복(step) : 3 , 손실함수(cost) : 38.639833
# 반복(step) : 3 , 손실함수(cost) : 38.946436
# 반복(step) : 3 , 손실함수(cost) : 39.080723
# 반복(step) : 3 , 손실함수(cost) : 39.273858
# 반복(step) : 3 , 손실함수(cost) : 39.488729
# 반복(step) : 3 , 손실함수(cost) : 39.653617
# 반복(step) : 3 , 손실함수(cost) : 39.854634
# 반복(step) : 3 , 손실함수(cost) : 40.004348
# 반복(step) : 3 , 손실함수(cost) : 40.186510
# 반복(step) : 3 , 손실함수(cost) : 40.298650
# 반복(step) : 3 , 손실함수(cost) : 40.570268
# 반복(step) : 3 , 손실함수(cost) : 40.786559
# 반복(step) : 3 , 손실함수(cost) : 40.988379
# 반복(step) : 3 , 손실함수(cost) : 41.189888
# 반복(step) : 3 , 손실함수(cost) : 41.366823
# 반복(step) : 3 , 손실함수(cost) : 41.520706
# 반복(step) : 3 , 손실함수(cost) : 41.811815
# 반복(step) : 3 , 손실함수(cost) : 41.976319
# 반복(step) : 3 , 손실함수(cost) : 42.201171
# 반복(step) : 3 , 손실함수(cost) : 42.498500
# 반복(step) : 3 , 손실함수(cost) : 42.663582
# 반복(step) : 3 , 손실함수(cost) : 42.873787
# 반복(step) : 3 , 손실함수(cost) : 43.083338
# 반복(step) : 3 , 손실함수(cost) : 43.211288
# 반복(step) : 3 , 손실함수(cost) : 43.415719
# 반복(step) : 3 , 손실함수(cost) : 43.693540
# 반복(step) : 3 , 손실함수(cost) : 43.891814
# 반복(step) : 3 , 손실함수(cost) : 44.065693
# 반복(step) : 3 , 손실함수(cost) : 44.216492
# 반복(step) : 3 , 손실함수(cost) : 44.406365
# 반복(step) : 3 , 손실함수(cost) : 44.680488
# 반복(step) : 3 , 손실함수(cost) : 44.930205
# 반복(step) : 3 , 손실함수(cost) : 45.138354
# 반복(step) : 3 , 손실함수(cost) : 45.347044
# 반복(step) : 3 , 손실함수(cost) : 45.552073
# 반복(step) : 3 , 손실함수(cost) : 45.721573
# 반복(step) : 4 , 손실함수(cost) : 0.201895
# 반복(step) : 4 , 손실함수(cost) : 0.377767
# 반복(step) : 4 , 손실함수(cost) : 0.603390
# 반복(step) : 4 , 손실함수(cost) : 0.868041
# 반복(step) : 4 , 손실함수(cost) : 0.991408
# 반복(step) : 4 , 손실함수(cost) : 1.164201
# 반복(step) : 4 , 손실함수(cost) : 1.378907
# 반복(step) : 4 , 손실함수(cost) : 1.541014
# 반복(step) : 4 , 손실함수(cost) : 1.753953
# 반복(step) : 4 , 손실함수(cost) : 2.026751
# 반복(step) : 4 , 손실함수(cost) : 2.198031
# 반복(step) : 4 , 손실함수(cost) : 2.356669
# 반복(step) : 4 , 손실함수(cost) : 2.528232
# 반복(step) : 4 , 손실함수(cost) : 2.656959
# 반복(step) : 4 , 손실함수(cost) : 2.786672
# 반복(step) : 4 , 손실함수(cost) : 2.959166
# 반복(step) : 4 , 손실함수(cost) : 3.112012
# 반복(step) : 4 , 손실함수(cost) : 3.265891
# 반복(step) : 4 , 손실함수(cost) : 3.397048
# 반복(step) : 4 , 손실함수(cost) : 3.510993
# 반복(step) : 4 , 손실함수(cost) : 3.698361
# 반복(step) : 4 , 손실함수(cost) : 3.840471
# 반복(step) : 4 , 손실함수(cost) : 4.026663
# 반복(step) : 4 , 손실함수(cost) : 4.255822
# 반복(step) : 4 , 손실함수(cost) : 4.432159
# 반복(step) : 4 , 손실함수(cost) : 4.644792
# 반복(step) : 4 , 손실함수(cost) : 4.856188
# 반복(step) : 4 , 손실함수(cost) : 4.939083
# 반복(step) : 4 , 손실함수(cost) : 5.020995
# 반복(step) : 4 , 손실함수(cost) : 5.197911
# 반복(step) : 4 , 손실함수(cost) : 5.348616
# 반복(step) : 4 , 손실함수(cost) : 5.543524
# 반복(step) : 4 , 손실함수(cost) : 5.771303
# 반복(step) : 4 , 손실함수(cost) : 5.897840
# 반복(step) : 4 , 손실함수(cost) : 6.054395
# 반복(step) : 4 , 손실함수(cost) : 6.166908
# 반복(step) : 4 , 손실함수(cost) : 6.278435
# 반복(step) : 4 , 손실함수(cost) : 6.416030
# 반복(step) : 4 , 손실함수(cost) : 6.579265
# 반복(step) : 4 , 손실함수(cost) : 6.687401
# 반복(step) : 4 , 손실함수(cost) : 6.907259
# 반복(step) : 4 , 손실함수(cost) : 7.075292
# 반복(step) : 4 , 손실함수(cost) : 7.284018
# 반복(step) : 4 , 손실함수(cost) : 7.425250
# 반복(step) : 4 , 손실함수(cost) : 7.549922
# 반복(step) : 4 , 손실함수(cost) : 7.639668
# 반복(step) : 4 , 손실함수(cost) : 7.729876
# 반복(step) : 4 , 손실함수(cost) : 7.874759
# 반복(step) : 4 , 손실함수(cost) : 8.001942
# 반복(step) : 4 , 손실함수(cost) : 8.124669
# 반복(step) : 4 , 손실함수(cost) : 8.267475
# 반복(step) : 4 , 손실함수(cost) : 8.483279
# 반복(step) : 4 , 손실함수(cost) : 8.677289
# 반복(step) : 4 , 손실함수(cost) : 8.901687
# 반복(step) : 4 , 손실함수(cost) : 9.080051
# 반복(step) : 4 , 손실함수(cost) : 9.172295
# 반복(step) : 4 , 손실함수(cost) : 9.330555
# 반복(step) : 4 , 손실함수(cost) : 9.466075
# 반복(step) : 4 , 손실함수(cost) : 9.692785
# 반복(step) : 4 , 손실함수(cost) : 9.940729
# 반복(step) : 4 , 손실함수(cost) : 10.065404
# 반복(step) : 4 , 손실함수(cost) : 10.243378
# 반복(step) : 4 , 손실함수(cost) : 10.377998
# 반복(step) : 4 , 손실함수(cost) : 10.446817
# 반복(step) : 4 , 손실함수(cost) : 10.689862
# 반복(step) : 4 , 손실함수(cost) : 10.832365
# 반복(step) : 4 , 손실함수(cost) : 10.951111
# 반복(step) : 4 , 손실함수(cost) : 11.056909
# 반복(step) : 4 , 손실함수(cost) : 11.215491
# 반복(step) : 4 , 손실함수(cost) : 11.415665
# 반복(step) : 4 , 손실함수(cost) : 11.557572
# 반복(step) : 4 , 손실함수(cost) : 11.721564
# 반복(step) : 4 , 손실함수(cost) : 11.920729
# 반복(step) : 4 , 손실함수(cost) : 11.992837
# 반복(step) : 4 , 손실함수(cost) : 12.115601
# 반복(step) : 4 , 손실함수(cost) : 12.355893
# 반복(step) : 4 , 손실함수(cost) : 12.539562
# 반복(step) : 4 , 손실함수(cost) : 12.711616
# 반복(step) : 4 , 손실함수(cost) : 12.852746
# 반복(step) : 4 , 손실함수(cost) : 13.079843
# 반복(step) : 4 , 손실함수(cost) : 13.235877
# 반복(step) : 4 , 손실함수(cost) : 13.359349
# 반복(step) : 4 , 손실함수(cost) : 13.464676
# 반복(step) : 4 , 손실함수(cost) : 13.629293
# 반복(step) : 4 , 손실함수(cost) : 13.827596
# 반복(step) : 4 , 손실함수(cost) : 14.045364
# 반복(step) : 4 , 손실함수(cost) : 14.314975
# 반복(step) : 4 , 손실함수(cost) : 14.519389
# 반복(step) : 4 , 손실함수(cost) : 14.604738
# 반복(step) : 4 , 손실함수(cost) : 14.714720
# 반복(step) : 4 , 손실함수(cost) : 14.946996
# 반복(step) : 4 , 손실함수(cost) : 15.102613
# 반복(step) : 4 , 손실함수(cost) : 15.363707
# 반복(step) : 4 , 손실함수(cost) : 15.495178
# 반복(step) : 4 , 손실함수(cost) : 15.684230
# 반복(step) : 4 , 손실함수(cost) : 15.895275
# 반복(step) : 4 , 손실함수(cost) : 16.018858
# 반복(step) : 4 , 손실함수(cost) : 16.137470
# 반복(step) : 4 , 손실함수(cost) : 16.275515
# 반복(step) : 4 , 손실함수(cost) : 16.434300
# 반복(step) : 4 , 손실함수(cost) : 16.682225
# 반복(step) : 4 , 손실함수(cost) : 16.776667
# 반복(step) : 4 , 손실함수(cost) : 16.937772
# 반복(step) : 4 , 손실함수(cost) : 17.073713
# 반복(step) : 4 , 손실함수(cost) : 17.242554
# 반복(step) : 4 , 손실함수(cost) : 17.421588
# 반복(step) : 4 , 손실함수(cost) : 17.587415
# 반복(step) : 4 , 손실함수(cost) : 17.796115
# 반복(step) : 4 , 손실함수(cost) : 17.912631
# 반복(step) : 4 , 손실함수(cost) : 17.966683
# 반복(step) : 4 , 손실함수(cost) : 18.111585
# 반복(step) : 4 , 손실함수(cost) : 18.226643
# 반복(step) : 4 , 손실함수(cost) : 18.397138
# 반복(step) : 4 , 손실함수(cost) : 18.614617
# 반복(step) : 4 , 손실함수(cost) : 18.733822
# 반복(step) : 4 , 손실함수(cost) : 18.863427
# 반복(step) : 4 , 손실함수(cost) : 18.994154
# 반복(step) : 4 , 손실함수(cost) : 19.213940
# 반복(step) : 4 , 손실함수(cost) : 19.379001
# 반복(step) : 4 , 손실함수(cost) : 19.492919
# 반복(step) : 4 , 손실함수(cost) : 19.663137
# 반복(step) : 4 , 손실함수(cost) : 19.855071
# 반복(step) : 4 , 손실함수(cost) : 20.029525
# 반복(step) : 4 , 손실함수(cost) : 20.169774
# 반복(step) : 4 , 손실함수(cost) : 20.396252
# 반복(step) : 4 , 손실함수(cost) : 20.586011
# 반복(step) : 4 , 손실함수(cost) : 20.748271
# 반복(step) : 4 , 손실함수(cost) : 20.861928
# 반복(step) : 4 , 손실함수(cost) : 21.032150
# 반복(step) : 4 , 손실함수(cost) : 21.174434
# 반복(step) : 4 , 손실함수(cost) : 21.351834
# 반복(step) : 4 , 손실함수(cost) : 21.560314
# 반복(step) : 4 , 손실함수(cost) : 21.717032
# 반복(step) : 4 , 손실함수(cost) : 21.874037
# 반복(step) : 4 , 손실함수(cost) : 22.059745
# 반복(step) : 4 , 손실함수(cost) : 22.143729
# 반복(step) : 4 , 손실함수(cost) : 22.241033
# 반복(step) : 4 , 손실함수(cost) : 22.370221
# 반복(step) : 4 , 손실함수(cost) : 22.516168
# 반복(step) : 4 , 손실함수(cost) : 22.658088
# 반복(step) : 4 , 손실함수(cost) : 22.810796
# 반복(step) : 4 , 손실함수(cost) : 22.950264
# 반복(step) : 4 , 손실함수(cost) : 23.086999
# 반복(step) : 4 , 손실함수(cost) : 23.234229
# 반복(step) : 4 , 손실함수(cost) : 23.315969
# 반복(step) : 4 , 손실함수(cost) : 23.461390
# 반복(step) : 4 , 손실함수(cost) : 23.634140
# 반복(step) : 4 , 손실함수(cost) : 23.770122
# 반복(step) : 4 , 손실함수(cost) : 23.954458
# 반복(step) : 4 , 손실함수(cost) : 24.230117
# 반복(step) : 4 , 손실함수(cost) : 24.339924
# 반복(step) : 4 , 손실함수(cost) : 24.444431
# 반복(step) : 4 , 손실함수(cost) : 24.683477
# 반복(step) : 4 , 손실함수(cost) : 24.830989
# 반복(step) : 4 , 손실함수(cost) : 24.959233
# 반복(step) : 4 , 손실함수(cost) : 25.144436
# 반복(step) : 4 , 손실함수(cost) : 25.274966
# 반복(step) : 4 , 손실함수(cost) : 25.405055
# 반복(step) : 4 , 손실함수(cost) : 25.546543
# 반복(step) : 4 , 손실함수(cost) : 25.661947
# 반복(step) : 4 , 손실함수(cost) : 25.749755
# 반복(step) : 4 , 손실함수(cost) : 25.950207
# 반복(step) : 4 , 손실함수(cost) : 26.058870
# 반복(step) : 4 , 손실함수(cost) : 26.273243
# 반복(step) : 4 , 손실함수(cost) : 26.356867
# 반복(step) : 4 , 손실함수(cost) : 26.542374
# 반복(step) : 4 , 손실함수(cost) : 26.700631
# 반복(step) : 4 , 손실함수(cost) : 26.823090
# 반복(step) : 4 , 손실함수(cost) : 26.957769
# 반복(step) : 4 , 손실함수(cost) : 27.116970
# 반복(step) : 4 , 손실함수(cost) : 27.245492
# 반복(step) : 4 , 손실함수(cost) : 27.373731
# 반복(step) : 4 , 손실함수(cost) : 27.514795
# 반복(step) : 4 , 손실함수(cost) : 27.614285
# 반복(step) : 4 , 손실함수(cost) : 27.741078
# 반복(step) : 4 , 손실함수(cost) : 27.895384
# 반복(step) : 4 , 손실함수(cost) : 28.039068
# 반복(step) : 4 , 손실함수(cost) : 28.177954
# 반복(step) : 4 , 손실함수(cost) : 28.330852
# 반복(step) : 4 , 손실함수(cost) : 28.460772
# 반복(step) : 4 , 손실함수(cost) : 28.583951
# 반복(step) : 4 , 손실함수(cost) : 28.798302
# 반복(step) : 4 , 손실함수(cost) : 28.904243
# 반복(step) : 4 , 손실함수(cost) : 29.049685
# 반복(step) : 4 , 손실함수(cost) : 29.239273
# 반복(step) : 4 , 손실함수(cost) : 29.436223
# 반복(step) : 4 , 손실함수(cost) : 29.624073
# 반복(step) : 4 , 손실함수(cost) : 29.766932
# 반복(step) : 4 , 손실함수(cost) : 29.934418
# 반복(step) : 4 , 손실함수(cost) : 30.118685
# 반복(step) : 4 , 손실함수(cost) : 30.225124
# 반복(step) : 4 , 손실함수(cost) : 30.390201
# 반복(step) : 4 , 손실함수(cost) : 30.465269
# 반복(step) : 4 , 손실함수(cost) : 30.585894
# 반복(step) : 4 , 손실함수(cost) : 30.721087
# 반복(step) : 4 , 손실함수(cost) : 30.816985
# 반복(step) : 4 , 손실함수(cost) : 30.881255
# 반복(step) : 4 , 손실함수(cost) : 31.053798
# 반복(step) : 4 , 손실함수(cost) : 31.212534
# 반복(step) : 4 , 손실함수(cost) : 31.381576
# 반복(step) : 4 , 손실함수(cost) : 31.497090
# 반복(step) : 4 , 손실함수(cost) : 31.644927
# 반복(step) : 4 , 손실함수(cost) : 31.803968
# 반복(step) : 4 , 손실함수(cost) : 31.913680
# 반복(step) : 4 , 손실함수(cost) : 32.069887
# 반복(step) : 4 , 손실함수(cost) : 32.345202
# 반복(step) : 4 , 손실함수(cost) : 32.458425
# 반복(step) : 4 , 손실함수(cost) : 32.595184
# 반복(step) : 4 , 손실함수(cost) : 32.721942
# 반복(step) : 4 , 손실함수(cost) : 32.889575
# 반복(step) : 4 , 손실함수(cost) : 33.029693
# 반복(step) : 4 , 손실함수(cost) : 33.190019
# 반복(step) : 4 , 손실함수(cost) : 33.344816
# 반복(step) : 4 , 손실함수(cost) : 33.453514
# 반복(step) : 5 , 손실함수(cost) : 0.154431
# 반복(step) : 5 , 손실함수(cost) : 0.313006
# 반복(step) : 5 , 손실함수(cost) : 0.448032
# 반복(step) : 5 , 손실함수(cost) : 0.591693
# 반복(step) : 5 , 손실함수(cost) : 0.691517
# 반복(step) : 5 , 손실함수(cost) : 0.779170
# 반복(step) : 5 , 손실함수(cost) : 0.927699
# 반복(step) : 5 , 손실함수(cost) : 1.048537
# 반복(step) : 5 , 손실함수(cost) : 1.186751
# 반복(step) : 5 , 손실함수(cost) : 1.365424
# 반복(step) : 5 , 손실함수(cost) : 1.482215
# 반복(step) : 5 , 손실함수(cost) : 1.556775
# 반복(step) : 5 , 손실함수(cost) : 1.709980
# 반복(step) : 5 , 손실함수(cost) : 1.963658
# 반복(step) : 5 , 손실함수(cost) : 2.125279
# 반복(step) : 5 , 손실함수(cost) : 2.216788
# 반복(step) : 5 , 손실함수(cost) : 2.303511
# 반복(step) : 5 , 손실함수(cost) : 2.522903
# 반복(step) : 5 , 손실함수(cost) : 2.715209
# 반복(step) : 5 , 손실함수(cost) : 2.800554
# 반복(step) : 5 , 손실함수(cost) : 2.924356
# 반복(step) : 5 , 손실함수(cost) : 2.991750
# 반복(step) : 5 , 손실함수(cost) : 3.139938
# 반복(step) : 5 , 손실함수(cost) : 3.306486
# 반복(step) : 5 , 손실함수(cost) : 3.440598
# 반복(step) : 5 , 손실함수(cost) : 3.581666
# 반복(step) : 5 , 손실함수(cost) : 3.706930
# 반복(step) : 5 , 손실함수(cost) : 3.879343
# 반복(step) : 5 , 손실함수(cost) : 3.966534
# 반복(step) : 5 , 손실함수(cost) : 4.139075
# 반복(step) : 5 , 손실함수(cost) : 4.255471
# 반복(step) : 5 , 손실함수(cost) : 4.391202
# 반복(step) : 5 , 손실함수(cost) : 4.534863
# 반복(step) : 5 , 손실함수(cost) : 4.651897
# 반복(step) : 5 , 손실함수(cost) : 4.766424
# 반복(step) : 5 , 손실함수(cost) : 4.902977
# 반복(step) : 5 , 손실함수(cost) : 5.072484
# 반복(step) : 5 , 손실함수(cost) : 5.209379
# 반복(step) : 5 , 손실함수(cost) : 5.327556
# 반복(step) : 5 , 손실함수(cost) : 5.487808
# 반복(step) : 5 , 손실함수(cost) : 5.641323
# 반복(step) : 5 , 손실함수(cost) : 5.815527
# 반복(step) : 5 , 손실함수(cost) : 5.923236
# 반복(step) : 5 , 손실함수(cost) : 6.022022
# 반복(step) : 5 , 손실함수(cost) : 6.157311
# 반복(step) : 5 , 손실함수(cost) : 6.275066
# 반복(step) : 5 , 손실함수(cost) : 6.402843
# 반복(step) : 5 , 손실함수(cost) : 6.607507
# 반복(step) : 5 , 손실함수(cost) : 6.726727
# 반복(step) : 5 , 손실함수(cost) : 6.936459
# 반복(step) : 5 , 손실함수(cost) : 7.052901
# 반복(step) : 5 , 손실함수(cost) : 7.209871
# 반복(step) : 5 , 손실함수(cost) : 7.307677
# 반복(step) : 5 , 손실함수(cost) : 7.466228
# 반복(step) : 5 , 손실함수(cost) : 7.526219
# 반복(step) : 5 , 손실함수(cost) : 7.623636
# 반복(step) : 5 , 손실함수(cost) : 7.722422
# 반복(step) : 5 , 손실함수(cost) : 7.836814
# 반복(step) : 5 , 손실함수(cost) : 7.979385
# 반복(step) : 5 , 손실함수(cost) : 8.078776
# 반복(step) : 5 , 손실함수(cost) : 8.211838
# 반복(step) : 5 , 손실함수(cost) : 8.272223
# 반복(step) : 5 , 손실함수(cost) : 8.372748
# 반복(step) : 5 , 손실함수(cost) : 8.535373
# 반복(step) : 5 , 손실함수(cost) : 8.683000
# 반복(step) : 5 , 손실함수(cost) : 8.778998
# 반복(step) : 5 , 손실함수(cost) : 8.914402
# 반복(step) : 5 , 손실함수(cost) : 9.000932
# 반복(step) : 5 , 손실함수(cost) : 9.108327
# 반복(step) : 5 , 손실함수(cost) : 9.282352
# 반복(step) : 5 , 손실함수(cost) : 9.368016
# 반복(step) : 5 , 손실함수(cost) : 9.444032
# 반복(step) : 5 , 손실함수(cost) : 9.562863
# 반복(step) : 5 , 손실함수(cost) : 9.655842
# 반복(step) : 5 , 손실함수(cost) : 9.744525
# 반복(step) : 5 , 손실함수(cost) : 9.911206
# 반복(step) : 5 , 손실함수(cost) : 10.030349
# 반복(step) : 5 , 손실함수(cost) : 10.103159
# 반복(step) : 5 , 손실함수(cost) : 10.170983
# 반복(step) : 5 , 손실함수(cost) : 10.240597
# 반복(step) : 5 , 손실함수(cost) : 10.375749
# 반복(step) : 5 , 손실함수(cost) : 10.496085
# 반복(step) : 5 , 손실함수(cost) : 10.592229
# 반복(step) : 5 , 손실함수(cost) : 10.790925
# 반복(step) : 5 , 손실함수(cost) : 10.914521
# 반복(step) : 5 , 손실함수(cost) : 11.046356
# 반복(step) : 5 , 손실함수(cost) : 11.134470
# 반복(step) : 5 , 손실함수(cost) : 11.219974
# 반복(step) : 5 , 손실함수(cost) : 11.361687
# 반복(step) : 5 , 손실함수(cost) : 11.400809
# 반복(step) : 5 , 손실함수(cost) : 11.497628
# 반복(step) : 5 , 손실함수(cost) : 11.562495
# 반복(step) : 5 , 손실함수(cost) : 11.738619
# 반복(step) : 5 , 손실함수(cost) : 11.840200
# 반복(step) : 5 , 손실함수(cost) : 11.904740
# 반복(step) : 5 , 손실함수(cost) : 12.042239
# 반복(step) : 5 , 손실함수(cost) : 12.165489
# 반복(step) : 5 , 손실함수(cost) : 12.364100
# 반복(step) : 5 , 손실함수(cost) : 12.462882
# 반복(step) : 5 , 손실함수(cost) : 12.532058
# 반복(step) : 5 , 손실함수(cost) : 12.627514
# 반복(step) : 5 , 손실함수(cost) : 12.783552
# 반복(step) : 5 , 손실함수(cost) : 12.922463
# 반복(step) : 5 , 손실함수(cost) : 13.084916
# 반복(step) : 5 , 손실함수(cost) : 13.254751
# 반복(step) : 5 , 손실함수(cost) : 13.382263
# 반복(step) : 5 , 손실함수(cost) : 13.527557
# 반복(step) : 5 , 손실함수(cost) : 13.601240
# 반복(step) : 5 , 손실함수(cost) : 13.730432
# 반복(step) : 5 , 손실함수(cost) : 13.914267
# 반복(step) : 5 , 손실함수(cost) : 14.043666
# 반복(step) : 5 , 손실함수(cost) : 14.149446
# 반복(step) : 5 , 손실함수(cost) : 14.235460
# 반복(step) : 5 , 손실함수(cost) : 14.341309
# 반복(step) : 5 , 손실함수(cost) : 14.529828
# 반복(step) : 5 , 손실함수(cost) : 14.633322
# 반복(step) : 5 , 손실함수(cost) : 14.743148
# 반복(step) : 5 , 손실함수(cost) : 14.858567
# 반복(step) : 5 , 손실함수(cost) : 14.981378
# 반복(step) : 5 , 손실함수(cost) : 15.070278
# 반복(step) : 5 , 손실함수(cost) : 15.129051
# 반복(step) : 5 , 손실함수(cost) : 15.266748
# 반복(step) : 5 , 손실함수(cost) : 15.391844
# 반복(step) : 5 , 손실함수(cost) : 15.480498
# 반복(step) : 5 , 손실함수(cost) : 15.591490
# 반복(step) : 5 , 손실함수(cost) : 15.677191
# 반복(step) : 5 , 손실함수(cost) : 15.880277
# 반복(step) : 5 , 손실함수(cost) : 15.959624
# 반복(step) : 5 , 손실함수(cost) : 16.079986
# 반복(step) : 5 , 손실함수(cost) : 16.151836
# 반복(step) : 5 , 손실함수(cost) : 16.296373
# 반복(step) : 5 , 손실함수(cost) : 16.382749
# 반복(step) : 5 , 손실함수(cost) : 16.479087
# 반복(step) : 5 , 손실함수(cost) : 16.548300
# 반복(step) : 5 , 손실함수(cost) : 16.666372
# 반복(step) : 5 , 손실함수(cost) : 16.794449
# 반복(step) : 5 , 손실함수(cost) : 16.902881
# 반복(step) : 5 , 손실함수(cost) : 17.033491
# 반복(step) : 5 , 손실함수(cost) : 17.191168
# 반복(step) : 5 , 손실함수(cost) : 17.286563
# 반복(step) : 5 , 손실함수(cost) : 17.368215
# 반복(step) : 5 , 손실함수(cost) : 17.453380
# 반복(step) : 5 , 손실함수(cost) : 17.564043
# 반복(step) : 5 , 손실함수(cost) : 17.690455
# 반복(step) : 5 , 손실함수(cost) : 17.781134
# 반복(step) : 5 , 손실함수(cost) : 17.975116
# 반복(step) : 5 , 손실함수(cost) : 18.138392
# 반복(step) : 5 , 손실함수(cost) : 18.316739
# 반복(step) : 5 , 손실함수(cost) : 18.434975
# 반복(step) : 5 , 손실함수(cost) : 18.596871
# 반복(step) : 5 , 손실함수(cost) : 18.810611
# 반복(step) : 5 , 손실함수(cost) : 18.934087
# 반복(step) : 5 , 손실함수(cost) : 19.065404
# 반복(step) : 5 , 손실함수(cost) : 19.142609
# 반복(step) : 5 , 손실함수(cost) : 19.256209
# 반복(step) : 5 , 손실함수(cost) : 19.386010
# 반복(step) : 5 , 손실함수(cost) : 19.590301
# 반복(step) : 5 , 손실함수(cost) : 19.709189
# 반복(step) : 5 , 손실함수(cost) : 19.849646
# 반복(step) : 5 , 손실함수(cost) : 19.934249
# 반복(step) : 5 , 손실함수(cost) : 20.058933
# 반복(step) : 5 , 손실함수(cost) : 20.125621
# 반복(step) : 5 , 손실함수(cost) : 20.263111
# 반복(step) : 5 , 손실함수(cost) : 20.359108
# 반복(step) : 5 , 손실함수(cost) : 20.480556
# 반복(step) : 5 , 손실함수(cost) : 20.597760
# 반복(step) : 5 , 손실함수(cost) : 20.705816
# 반복(step) : 5 , 손실함수(cost) : 20.806087
# 반복(step) : 5 , 손실함수(cost) : 20.959705
# 반복(step) : 5 , 손실함수(cost) : 21.092944
# 반복(step) : 5 , 손실함수(cost) : 21.197855
# 반복(step) : 5 , 손실함수(cost) : 21.317830
# 반복(step) : 5 , 손실함수(cost) : 21.458205
# 반복(step) : 5 , 손실함수(cost) : 21.590342
# 반복(step) : 5 , 손실함수(cost) : 21.702587
# 반복(step) : 5 , 손실함수(cost) : 21.781618
# 반복(step) : 5 , 손실함수(cost) : 21.967278
# 반복(step) : 5 , 손실함수(cost) : 22.047308
# 반복(step) : 5 , 손실함수(cost) : 22.166673
# 반복(step) : 5 , 손실함수(cost) : 22.244343
# 반복(step) : 5 , 손실함수(cost) : 22.327419
# 반복(step) : 5 , 손실함수(cost) : 22.495503
# 반복(step) : 5 , 손실함수(cost) : 22.619189
# 반복(step) : 5 , 손실함수(cost) : 22.755209
# 반복(step) : 5 , 손실함수(cost) : 22.881929
# 반복(step) : 5 , 손실함수(cost) : 22.937032
# 반복(step) : 5 , 손실함수(cost) : 23.099704
# 반복(step) : 5 , 손실함수(cost) : 23.196590
# 반복(step) : 5 , 손실함수(cost) : 23.332688
# 반복(step) : 5 , 손실함수(cost) : 23.425143
# 반복(step) : 5 , 손실함수(cost) : 23.522282
# 반복(step) : 5 , 손실함수(cost) : 23.681813
# 반복(step) : 5 , 손실함수(cost) : 23.803765
# 반복(step) : 5 , 손실함수(cost) : 24.004860
# 반복(step) : 5 , 손실함수(cost) : 24.179515
# 반복(step) : 5 , 손실함수(cost) : 24.327144
# 반복(step) : 5 , 손실함수(cost) : 24.497644
# 반복(step) : 5 , 손실함수(cost) : 24.640640
# 반복(step) : 5 , 손실함수(cost) : 24.716603
# 반복(step) : 5 , 손실함수(cost) : 24.871958
# 반복(step) : 5 , 손실함수(cost) : 24.932325
# 반복(step) : 5 , 손실함수(cost) : 25.059050
# 반복(step) : 5 , 손실함수(cost) : 25.196903
# 반복(step) : 5 , 손실함수(cost) : 25.329174
# 반복(step) : 5 , 손실함수(cost) : 25.428219
# 반복(step) : 5 , 손실함수(cost) : 25.537285
# 반복(step) : 5 , 손실함수(cost) : 25.666271
# 반복(step) : 5 , 손실함수(cost) : 25.828156
# 반복(step) : 5 , 손실함수(cost) : 25.917506
# 반복(step) : 5 , 손실함수(cost) : 26.055159
# 반복(step) : 5 , 손실함수(cost) : 26.111911
# 반복(step) : 5 , 손실함수(cost) : 26.249950
# 반복(step) : 5 , 손실함수(cost) : 26.378921
# 반복(step) : 5 , 손실함수(cost) : 26.587573
# 반복(step) : 6 , 손실함수(cost) : 0.072938
# 반복(step) : 6 , 손실함수(cost) : 0.183851
# 반복(step) : 6 , 손실함수(cost) : 0.279747
# 반복(step) : 6 , 손실함수(cost) : 0.356887
# 반복(step) : 6 , 손실함수(cost) : 0.444820
# 반복(step) : 6 , 손실함수(cost) : 0.585282
# 반복(step) : 6 , 손실함수(cost) : 0.731921
# 반복(step) : 6 , 손실함수(cost) : 0.850351
# 반복(step) : 6 , 손실함수(cost) : 0.910654
# 반복(step) : 6 , 손실함수(cost) : 0.995553
# 반복(step) : 6 , 손실함수(cost) : 1.088797
# 반복(step) : 6 , 손실함수(cost) : 1.174246
# 반복(step) : 6 , 손실함수(cost) : 1.278047
# 반복(step) : 6 , 손실함수(cost) : 1.490263
# 반복(step) : 6 , 손실함수(cost) : 1.595797
# 반복(step) : 6 , 손실함수(cost) : 1.698072
# 반복(step) : 6 , 손실함수(cost) : 1.780415
# 반복(step) : 6 , 손실함수(cost) : 1.855122
# 반복(step) : 6 , 손실함수(cost) : 1.970568
# 반복(step) : 6 , 손실함수(cost) : 2.080848
# 반복(step) : 6 , 손실함수(cost) : 2.184407
# 반복(step) : 6 , 손실함수(cost) : 2.360635
# 반복(step) : 6 , 손실함수(cost) : 2.473894
# 반복(step) : 6 , 손실함수(cost) : 2.556196
# 반복(step) : 6 , 손실함수(cost) : 2.685788
# 반복(step) : 6 , 손실함수(cost) : 2.757997
# 반복(step) : 6 , 손실함수(cost) : 2.920072
# 반복(step) : 6 , 손실함수(cost) : 2.990806
# 반복(step) : 6 , 손실함수(cost) : 3.162011
# 반복(step) : 6 , 손실함수(cost) : 3.252075
# 반복(step) : 6 , 손실함수(cost) : 3.317267
# 반복(step) : 6 , 손실함수(cost) : 3.375263
# 반복(step) : 6 , 손실함수(cost) : 3.470120
# 반복(step) : 6 , 손실함수(cost) : 3.586275
# 반복(step) : 6 , 손실함수(cost) : 3.651261
# 반복(step) : 6 , 손실함수(cost) : 3.847084
# 반복(step) : 6 , 손실함수(cost) : 3.975476
# 반복(step) : 6 , 손실함수(cost) : 4.078565
# 반복(step) : 6 , 손실함수(cost) : 4.196315
# 반복(step) : 6 , 손실함수(cost) : 4.321061
# 반복(step) : 6 , 손실함수(cost) : 4.406322
# 반복(step) : 6 , 손실함수(cost) : 4.516779
# 반복(step) : 6 , 손실함수(cost) : 4.626293
# 반복(step) : 6 , 손실함수(cost) : 4.707956
# 반복(step) : 6 , 손실함수(cost) : 4.802829
# 반복(step) : 6 , 손실함수(cost) : 4.894560
# 반복(step) : 6 , 손실함수(cost) : 5.033529
# 반복(step) : 6 , 손실함수(cost) : 5.117014
# 반복(step) : 6 , 손실함수(cost) : 5.244702
# 반복(step) : 6 , 손실함수(cost) : 5.394774
# 반복(step) : 6 , 손실함수(cost) : 5.484230
# 반복(step) : 6 , 손실함수(cost) : 5.576103
# 반복(step) : 6 , 손실함수(cost) : 5.609592
# 반복(step) : 6 , 손실함수(cost) : 5.667714
# 반복(step) : 6 , 손실함수(cost) : 5.747406
# 반복(step) : 6 , 손실함수(cost) : 5.849875
# 반복(step) : 6 , 손실함수(cost) : 6.002280
# 반복(step) : 6 , 손실함수(cost) : 6.052892
# 반복(step) : 6 , 손실함수(cost) : 6.130971
# 반복(step) : 6 , 손실함수(cost) : 6.251249
# 반복(step) : 6 , 손실함수(cost) : 6.454851
# 반복(step) : 6 , 손실함수(cost) : 6.540462
# 반복(step) : 6 , 손실함수(cost) : 6.680037
# 반복(step) : 6 , 손실함수(cost) : 6.770916
# 반복(step) : 6 , 손실함수(cost) : 6.869006
# 반복(step) : 6 , 손실함수(cost) : 6.999021
# 반복(step) : 6 , 손실함수(cost) : 7.119795
# 반복(step) : 6 , 손실함수(cost) : 7.253488
# 반복(step) : 6 , 손실함수(cost) : 7.320087
# 반복(step) : 6 , 손실함수(cost) : 7.457323
# 반복(step) : 6 , 손실함수(cost) : 7.524033
# 반복(step) : 6 , 손실함수(cost) : 7.568452
# 반복(step) : 6 , 손실함수(cost) : 7.670748
# 반복(step) : 6 , 손실함수(cost) : 7.794525
# 반복(step) : 6 , 손실함수(cost) : 7.868293
# 반복(step) : 6 , 손실함수(cost) : 7.898307
# 반복(step) : 6 , 손실함수(cost) : 7.946326
# 반복(step) : 6 , 손실함수(cost) : 8.031358
# 반복(step) : 6 , 손실함수(cost) : 8.154368
# 반복(step) : 6 , 손실함수(cost) : 8.244256
# 반복(step) : 6 , 손실함수(cost) : 8.326839
# 반복(step) : 6 , 손실함수(cost) : 8.439650
# 반복(step) : 6 , 손실함수(cost) : 8.565108
# 반복(step) : 6 , 손실함수(cost) : 8.669812
# 반복(step) : 6 , 손실함수(cost) : 8.778628
# 반복(step) : 6 , 손실함수(cost) : 8.849312
# 반복(step) : 6 , 손실함수(cost) : 8.934673
# 반복(step) : 6 , 손실함수(cost) : 9.011303
# 반복(step) : 6 , 손실함수(cost) : 9.071369
# 반복(step) : 6 , 손실함수(cost) : 9.154786
# 반복(step) : 6 , 손실함수(cost) : 9.227543
# 반복(step) : 6 , 손실함수(cost) : 9.335806
# 반복(step) : 6 , 손실함수(cost) : 9.432851
# 반복(step) : 6 , 손실함수(cost) : 9.513433
# 반복(step) : 6 , 손실함수(cost) : 9.625874
# 반복(step) : 6 , 손실함수(cost) : 9.740396
# 반복(step) : 6 , 손실함수(cost) : 9.852118
# 반복(step) : 6 , 손실함수(cost) : 10.004551
# 반복(step) : 6 , 손실함수(cost) : 10.100726
# 반복(step) : 6 , 손실함수(cost) : 10.165729
# 반복(step) : 6 , 손실함수(cost) : 10.241593
# 반복(step) : 6 , 손실함수(cost) : 10.322704
# 반복(step) : 6 , 손실함수(cost) : 10.484103
# 반복(step) : 6 , 손실함수(cost) : 10.592440
# 반복(step) : 6 , 손실함수(cost) : 10.681909
# 반복(step) : 6 , 손실함수(cost) : 10.841312
# 반복(step) : 6 , 손실함수(cost) : 10.997058
# 반복(step) : 6 , 손실함수(cost) : 11.124682
# 반복(step) : 6 , 손실함수(cost) : 11.235495
# 반복(step) : 6 , 손실함수(cost) : 11.331033
# 반복(step) : 6 , 손실함수(cost) : 11.383484
# 반복(step) : 6 , 손실함수(cost) : 11.505437
# 반복(step) : 6 , 손실함수(cost) : 11.583260
# 반복(step) : 6 , 손실함수(cost) : 11.646589
# 반복(step) : 6 , 손실함수(cost) : 11.736033
# 반복(step) : 6 , 손실함수(cost) : 11.813416
# 반복(step) : 6 , 손실함수(cost) : 11.921616
# 반복(step) : 6 , 손실함수(cost) : 12.014450
# 반복(step) : 6 , 손실함수(cost) : 12.124572
# 반복(step) : 6 , 손실함수(cost) : 12.191722
# 반복(step) : 6 , 손실함수(cost) : 12.312191
# 반복(step) : 6 , 손실함수(cost) : 12.395834
# 반복(step) : 6 , 손실함수(cost) : 12.451204
# 반복(step) : 6 , 손실함수(cost) : 12.583976
# 반복(step) : 6 , 손실함수(cost) : 12.675111
# 반복(step) : 6 , 손실함수(cost) : 12.740423
# 반복(step) : 6 , 손실함수(cost) : 12.863094
# 반복(step) : 6 , 손실함수(cost) : 12.977239
# 반복(step) : 6 , 손실함수(cost) : 13.041685
# 반복(step) : 6 , 손실함수(cost) : 13.104359
# 반복(step) : 6 , 손실함수(cost) : 13.222703
# 반복(step) : 6 , 손실함수(cost) : 13.280008
# 반복(step) : 6 , 손실함수(cost) : 13.349780
# 반복(step) : 6 , 손실함수(cost) : 13.408070
# 반복(step) : 6 , 손실함수(cost) : 13.508251
# 반복(step) : 6 , 손실함수(cost) : 13.619262
# 반복(step) : 6 , 손실함수(cost) : 13.718064
# 반복(step) : 6 , 손실함수(cost) : 13.827752
# 반복(step) : 6 , 손실함수(cost) : 13.981399
# 반복(step) : 6 , 손실함수(cost) : 14.089152
# 반복(step) : 6 , 손실함수(cost) : 14.175792
# 반복(step) : 6 , 손실함수(cost) : 14.324737
# 반복(step) : 6 , 손실함수(cost) : 14.362200
# 반복(step) : 6 , 손실함수(cost) : 14.400716
# 반복(step) : 6 , 손실함수(cost) : 14.497920
# 반복(step) : 6 , 손실함수(cost) : 14.589327
# 반복(step) : 6 , 손실함수(cost) : 14.687838
# 반복(step) : 6 , 손실함수(cost) : 14.747567
# 반복(step) : 6 , 손실함수(cost) : 14.866179
# 반복(step) : 6 , 손실함수(cost) : 15.004042
# 반복(step) : 6 , 손실함수(cost) : 15.073266
# 반복(step) : 6 , 손실함수(cost) : 15.201373
# 반복(step) : 6 , 손실함수(cost) : 15.390920
# 반복(step) : 6 , 손실함수(cost) : 15.439205
# 반복(step) : 6 , 손실함수(cost) : 15.538890
# 반복(step) : 6 , 손실함수(cost) : 15.680946
# 반복(step) : 6 , 손실함수(cost) : 15.820792
# 반복(step) : 6 , 손실함수(cost) : 15.921059
# 반복(step) : 6 , 손실함수(cost) : 15.979675
# 반복(step) : 6 , 손실함수(cost) : 16.038900
# 반복(step) : 6 , 손실함수(cost) : 16.125663
# 반복(step) : 6 , 손실함수(cost) : 16.181238
# 반복(step) : 6 , 손실함수(cost) : 16.286798
# 반복(step) : 6 , 손실함수(cost) : 16.395677
# 반복(step) : 6 , 손실함수(cost) : 16.447139
# 반복(step) : 6 , 손실함수(cost) : 16.573213
# 반복(step) : 6 , 손실함수(cost) : 16.705229
# 반복(step) : 6 , 손실함수(cost) : 16.802496
# 반복(step) : 6 , 손실함수(cost) : 16.882323
# 반복(step) : 6 , 손실함수(cost) : 16.991772
# 반복(step) : 6 , 손실함수(cost) : 17.109449
# 반복(step) : 6 , 손실함수(cost) : 17.218122
# 반복(step) : 6 , 손실함수(cost) : 17.298386
# 반복(step) : 6 , 손실함수(cost) : 17.432669
# 반복(step) : 6 , 손실함수(cost) : 17.555889
# 반복(step) : 6 , 손실함수(cost) : 17.661164
# 반복(step) : 6 , 손실함수(cost) : 17.770028
# 반복(step) : 6 , 손실함수(cost) : 17.881855
# 반복(step) : 6 , 손실함수(cost) : 17.981893
# 반복(step) : 6 , 손실함수(cost) : 18.059595
# 반복(step) : 6 , 손실함수(cost) : 18.184424
# 반복(step) : 6 , 손실함수(cost) : 18.280893
# 반복(step) : 6 , 손실함수(cost) : 18.373074
# 반복(step) : 6 , 손실함수(cost) : 18.406845
# 반복(step) : 6 , 손실함수(cost) : 18.479768
# 반복(step) : 6 , 손실함수(cost) : 18.548518
# 반복(step) : 6 , 손실함수(cost) : 18.675585
# 반복(step) : 6 , 손실함수(cost) : 18.776524
# 반복(step) : 6 , 손실함수(cost) : 18.862982
# 반복(step) : 6 , 손실함수(cost) : 18.945352
# 반복(step) : 6 , 손실함수(cost) : 18.991735
# 반복(step) : 6 , 손실함수(cost) : 19.092104
# 반복(step) : 6 , 손실함수(cost) : 19.187927
# 반복(step) : 6 , 손실함수(cost) : 19.280191
# 반복(step) : 6 , 손실함수(cost) : 19.380423
# ...
# 반복(step) : 29 , 손실함수(cost) : 0.016769
# 반복(step) : 29 , 손실함수(cost) : 0.019003
# 반복(step) : 29 , 손실함수(cost) : 0.021113
# 반복(step) : 29 , 손실함수(cost) : 0.021940
# 반복(step) : 29 , 손실함수(cost) : 0.022694
# 반복(step) : 29 , 손실함수(cost) : 0.022935
# 반복(step) : 29 , 손실함수(cost) : 0.023039
# 반복(step) : 29 , 손실함수(cost) : 0.023350
# 반복(step) : 29 , 손실함수(cost) : 0.024180
# 반복(step) : 29 , 손실함수(cost) : 0.024268
# 반복(step) : 29 , 손실함수(cost) : 0.025859
# 반복(step) : 29 , 손실함수(cost) : 0.025859
# 반복(step) : 29 , 손실함수(cost) : 0.027845
# 반복(step) : 29 , 손실함수(cost) : 0.028105
# 반복(step) : 29 , 손실함수(cost) : 0.028843
# 반복(step) : 29 , 손실함수(cost) : 0.029547
# 반복(step) : 29 , 손실함수(cost) : 0.033088
# 반복(step) : 29 , 손실함수(cost) : 0.034388
# 반복(step) : 29 , 손실함수(cost) : 0.035398
# 반복(step) : 29 , 손실함수(cost) : 0.038097
# 반복(step) : 29 , 손실함수(cost) : 0.038097
# 반복(step) : 29 , 손실함수(cost) : 0.039047
# 반복(step) : 29 , 손실함수(cost) : 0.039649
# 반복(step) : 29 , 손실함수(cost) : 0.041403
# 반복(step) : 29 , 손실함수(cost) : 0.042103
# 반복(step) : 29 , 손실함수(cost) : 0.042103
# 반복(step) : 29 , 손실함수(cost) : 0.043820
# 반복(step) : 29 , 손실함수(cost) : 0.045101
# 반복(step) : 29 , 손실함수(cost) : 0.046881
# 반복(step) : 29 , 손실함수(cost) : 0.048062
# 반복(step) : 29 , 손실함수(cost) : 0.050513
# 반복(step) : 29 , 손실함수(cost) : 0.055538
# 반복(step) : 29 , 손실함수(cost) : 0.056007
# 반복(step) : 29 , 손실함수(cost) : 0.056432
# 반복(step) : 29 , 손실함수(cost) : 0.056432
# 반복(step) : 29 , 손실함수(cost) : 0.056432
# 반복(step) : 29 , 손실함수(cost) : 0.056748
# 반복(step) : 29 , 손실함수(cost) : 0.059609
# 반복(step) : 29 , 손실함수(cost) : 0.061199
# 반복(step) : 29 , 손실함수(cost) : 0.063728
# 반복(step) : 29 , 손실함수(cost) : 0.066280
# 반복(step) : 29 , 손실함수(cost) : 0.066280
# 반복(step) : 29 , 손실함수(cost) : 0.066281
# 반복(step) : 29 , 손실함수(cost) : 0.066281
# 반복(step) : 29 , 손실함수(cost) : 0.070768
# 반복(step) : 29 , 손실함수(cost) : 0.076627
# 반복(step) : 29 , 손실함수(cost) : 0.078451
# 반복(step) : 29 , 손실함수(cost) : 0.079168
# 반복(step) : 29 , 손실함수(cost) : 0.079880
# 반복(step) : 29 , 손실함수(cost) : 0.079880
# 반복(step) : 29 , 손실함수(cost) : 0.080755
# 반복(step) : 29 , 손실함수(cost) : 0.080755
# 반복(step) : 29 , 손실함수(cost) : 0.080824
# 반복(step) : 29 , 손실함수(cost) : 0.083522
# 반복(step) : 29 , 손실함수(cost) : 0.085093
# 반복(step) : 29 , 손실함수(cost) : 0.085359
# 반복(step) : 29 , 손실함수(cost) : 0.085359
# 반복(step) : 29 , 손실함수(cost) : 0.085908
# 반복(step) : 29 , 손실함수(cost) : 0.086158
# 반복(step) : 29 , 손실함수(cost) : 0.087721
# 반복(step) : 29 , 손실함수(cost) : 0.087721
# 반복(step) : 29 , 손실함수(cost) : 0.088075
# 반복(step) : 29 , 손실함수(cost) : 0.089193
# 반복(step) : 29 , 손실함수(cost) : 0.089193
# 반복(step) : 29 , 손실함수(cost) : 0.089246
# 반복(step) : 29 , 손실함수(cost) : 0.096011
# 반복(step) : 29 , 손실함수(cost) : 0.096768
# 반복(step) : 29 , 손실함수(cost) : 0.096771
# 반복(step) : 29 , 손실함수(cost) : 0.096771
# 반복(step) : 29 , 손실함수(cost) : 0.098209
# 반복(step) : 29 , 손실함수(cost) : 0.100424
# 반복(step) : 29 , 손실함수(cost) : 0.102260
# 반복(step) : 29 , 손실함수(cost) : 0.102260
# 반복(step) : 29 , 손실함수(cost) : 0.102391
# 반복(step) : 29 , 손실함수(cost) : 0.103700
# 반복(step) : 29 , 손실함수(cost) : 0.105241
# 반복(step) : 29 , 손실함수(cost) : 0.105434
# 반복(step) : 29 , 손실함수(cost) : 0.116539
# 반복(step) : 29 , 손실함수(cost) : 0.117086
# 반복(step) : 29 , 손실함수(cost) : 0.120181
# 반복(step) : 29 , 손실함수(cost) : 0.122419
# 반복(step) : 29 , 손실함수(cost) : 0.122841
# 반복(step) : 29 , 손실함수(cost) : 0.125191
# 반복(step) : 29 , 손실함수(cost) : 0.126321
# 반복(step) : 29 , 손실함수(cost) : 0.127715
# 반복(step) : 29 , 손실함수(cost) : 0.129010
# 반복(step) : 29 , 손실함수(cost) : 0.130864
# 반복(step) : 29 , 손실함수(cost) : 0.131429
# 반복(step) : 29 , 손실함수(cost) : 0.131922
# 반복(step) : 29 , 손실함수(cost) : 0.134158
# 반복(step) : 29 , 손실함수(cost) : 0.134158
# 반복(step) : 29 , 손실함수(cost) : 0.135662
# 반복(step) : 29 , 손실함수(cost) : 0.135662
# 반복(step) : 29 , 손실함수(cost) : 0.137182
# 반복(step) : 29 , 손실함수(cost) : 0.137667
# 반복(step) : 29 , 손실함수(cost) : 0.137667
# 반복(step) : 29 , 손실함수(cost) : 0.138173
# 반복(step) : 29 , 손실함수(cost) : 0.138173
# 반복(step) : 29 , 손실함수(cost) : 0.138462
# 반복(step) : 29 , 손실함수(cost) : 0.138504
# 반복(step) : 29 , 손실함수(cost) : 0.138572
# 반복(step) : 29 , 손실함수(cost) : 0.139534
# 반복(step) : 29 , 손실함수(cost) : 0.139788
# 반복(step) : 29 , 손실함수(cost) : 0.140349
# 반복(step) : 29 , 손실함수(cost) : 0.140491
# 반복(step) : 29 , 손실함수(cost) : 0.141066
# 반복(step) : 29 , 손실함수(cost) : 0.141072
# 반복(step) : 29 , 손실함수(cost) : 0.142848
# 반복(step) : 29 , 손실함수(cost) : 0.142848
# 반복(step) : 29 , 손실함수(cost) : 0.143394
# 반복(step) : 29 , 손실함수(cost) : 0.147039
# 반복(step) : 29 , 손실함수(cost) : 0.148417
# 반복(step) : 29 , 손실함수(cost) : 0.148584
# 반복(step) : 29 , 손실함수(cost) : 0.148906
# 반복(step) : 29 , 손실함수(cost) : 0.149316
# 반복(step) : 29 , 손실함수(cost) : 0.149960
# 반복(step) : 29 , 손실함수(cost) : 0.153047
# 반복(step) : 29 , 손실함수(cost) : 0.153454
# 반복(step) : 29 , 손실함수(cost) : 0.153454
# 반복(step) : 29 , 손실함수(cost) : 0.153454
# 반복(step) : 29 , 손실함수(cost) : 0.153454
# 반복(step) : 29 , 손실함수(cost) : 0.153454
# 반복(step) : 29 , 손실함수(cost) : 0.153463
# 반복(step) : 29 , 손실함수(cost) : 0.153463
# 반복(step) : 29 , 손실함수(cost) : 0.157580
# 반복(step) : 29 , 손실함수(cost) : 0.159181
# 반복(step) : 29 , 손실함수(cost) : 0.161000
# 반복(step) : 29 , 손실함수(cost) : 0.162175
# 반복(step) : 29 , 손실함수(cost) : 0.162175
# 반복(step) : 29 , 손실함수(cost) : 0.162175
# 반복(step) : 29 , 손실함수(cost) : 0.165031
# 반복(step) : 29 , 손실함수(cost) : 0.165318
# 반복(step) : 29 , 손실함수(cost) : 0.165854
# 반복(step) : 29 , 손실함수(cost) : 0.169995
# 반복(step) : 29 , 손실함수(cost) : 0.170192
# 반복(step) : 29 , 손실함수(cost) : 0.170603
# 반복(step) : 29 , 손실함수(cost) : 0.170633
# 반복(step) : 29 , 손실함수(cost) : 0.173706
# 반복(step) : 29 , 손실함수(cost) : 0.175764
# 반복(step) : 29 , 손실함수(cost) : 0.178369
# 반복(step) : 29 , 손실함수(cost) : 0.181344
# 반복(step) : 29 , 손실함수(cost) : 0.183098
# 반복(step) : 29 , 손실함수(cost) : 0.184580
# 반복(step) : 29 , 손실함수(cost) : 0.185845
# 반복(step) : 29 , 손실함수(cost) : 0.185845
# 반복(step) : 29 , 손실함수(cost) : 0.188206
# 반복(step) : 29 , 손실함수(cost) : 0.188456
# 반복(step) : 29 , 손실함수(cost) : 0.192224
# 반복(step) : 29 , 손실함수(cost) : 0.192951
# 반복(step) : 29 , 손실함수(cost) : 0.193180
# 반복(step) : 29 , 손실함수(cost) : 0.198805
# 반복(step) : 29 , 손실함수(cost) : 0.205792
# 반복(step) : 29 , 손실함수(cost) : 0.207148
# 반복(step) : 29 , 손실함수(cost) : 0.208109
# 반복(step) : 29 , 손실함수(cost) : 0.208600
# 반복(step) : 29 , 손실함수(cost) : 0.209118
# 반복(step) : 29 , 손실함수(cost) : 0.209679
# 반복(step) : 29 , 손실함수(cost) : 0.213976
# 반복(step) : 29 , 손실함수(cost) : 0.214853
# 반복(step) : 29 , 손실함수(cost) : 0.215113
# 반복(step) : 29 , 손실함수(cost) : 0.215113
# 반복(step) : 29 , 손실함수(cost) : 0.215956
# 반복(step) : 29 , 손실함수(cost) : 0.216412
# 반복(step) : 29 , 손실함수(cost) : 0.216996
# 반복(step) : 29 , 손실함수(cost) : 0.218756
# 반복(step) : 29 , 손실함수(cost) : 0.220535
# 반복(step) : 29 , 손실함수(cost) : 0.220689
# 반복(step) : 29 , 손실함수(cost) : 0.220689
# 반복(step) : 29 , 손실함수(cost) : 0.220689
# 반복(step) : 29 , 손실함수(cost) : 0.220689
# 반복(step) : 29 , 손실함수(cost) : 0.220689
# 반복(step) : 29 , 손실함수(cost) : 0.222064
# 반복(step) : 29 , 손실함수(cost) : 0.226777
# 반복(step) : 29 , 손실함수(cost) : 0.228051
# 반복(step) : 29 , 손실함수(cost) : 0.230708
# 반복(step) : 29 , 손실함수(cost) : 0.231073
# 반복(step) : 29 , 손실함수(cost) : 0.232664
# 반복(step) : 29 , 손실함수(cost) : 0.233142
# 반복(step) : 29 , 손실함수(cost) : 0.234578
# 반복(step) : 29 , 손실함수(cost) : 0.234578
# 반복(step) : 29 , 손실함수(cost) : 0.235322
# 반복(step) : 29 , 손실함수(cost) : 0.238455
# 반복(step) : 29 , 손실함수(cost) : 0.240597
# 반복(step) : 29 , 손실함수(cost) : 0.241699
# 반복(step) : 29 , 손실함수(cost) : 0.246247
# 반복(step) : 29 , 손실함수(cost) : 0.246726
# 반복(step) : 29 , 손실함수(cost) : 0.248056
# 반복(step) : 29 , 손실함수(cost) : 0.252539
# 반복(step) : 29 , 손실함수(cost) : 0.252708
# 반복(step) : 29 , 손실함수(cost) : 0.258199
# 반복(step) : 29 , 손실함수(cost) : 0.259032
# 반복(step) : 29 , 손실함수(cost) : 0.261415
# 반복(step) : 29 , 손실함수(cost) : 0.263998
# 반복(step) : 29 , 손실함수(cost) : 0.268818
# 반복(step) : 29 , 손실함수(cost) : 0.268818
# 반복(step) : 29 , 손실함수(cost) : 0.270105
# 반복(step) : 29 , 손실함수(cost) : 0.270106
# 반복(step) : 29 , 손실함수(cost) : 0.272901
# 반복(step) : 29 , 손실함수(cost) : 0.284404
# 반복(step) : 29 , 손실함수(cost) : 0.284774
# 반복(step) : 29 , 손실함수(cost) : 0.284818
# 반복(step) : 29 , 손실함수(cost) : 0.284853
# 반복(step) : 29 , 손실함수(cost) : 0.285756
# 반복(step) : 29 , 손실함수(cost) : 0.286052
# 반복(step) : 29 , 손실함수(cost) : 0.286287
# 반복(step) : 29 , 손실함수(cost) : 0.287855
# 반복(step) : 30 , 손실함수(cost) : 0.001357
# 반복(step) : 30 , 손실함수(cost) : 0.001357
# 반복(step) : 30 , 손실함수(cost) : 0.003715
# 반복(step) : 30 , 손실함수(cost) : 0.003716
# 반복(step) : 30 , 손실함수(cost) : 0.006913
# 반복(step) : 30 , 손실함수(cost) : 0.007131
# 반복(step) : 30 , 손실함수(cost) : 0.008770
# 반복(step) : 30 , 손실함수(cost) : 0.009418
# 반복(step) : 30 , 손실함수(cost) : 0.020642
# 반복(step) : 30 , 손실함수(cost) : 0.021870
# 반복(step) : 30 , 손실함수(cost) : 0.021870
# 반복(step) : 30 , 손실함수(cost) : 0.023566
# 반복(step) : 30 , 손실함수(cost) : 0.024113
# 반복(step) : 30 , 손실함수(cost) : 0.026717
# 반복(step) : 30 , 손실함수(cost) : 0.028645
# 반복(step) : 30 , 손실함수(cost) : 0.028645
# 반복(step) : 30 , 손실함수(cost) : 0.030696
# 반복(step) : 30 , 손실함수(cost) : 0.032262
# 반복(step) : 30 , 손실함수(cost) : 0.032262
# 반복(step) : 30 , 손실함수(cost) : 0.032347
# 반복(step) : 30 , 손실함수(cost) : 0.032473
# 반복(step) : 30 , 손실함수(cost) : 0.034218
# 반복(step) : 30 , 손실함수(cost) : 0.034666
# 반복(step) : 30 , 손실함수(cost) : 0.036186
# 반복(step) : 30 , 손실함수(cost) : 0.037240
# 반복(step) : 30 , 손실함수(cost) : 0.037898
# 반복(step) : 30 , 손실함수(cost) : 0.038150
# 반복(step) : 30 , 손실함수(cost) : 0.038150
# 반복(step) : 30 , 손실함수(cost) : 0.041219
# 반복(step) : 30 , 손실함수(cost) : 0.041219
# 반복(step) : 30 , 손실함수(cost) : 0.041509
# 반복(step) : 30 , 손실함수(cost) : 0.044078
# 반복(step) : 30 , 손실함수(cost) : 0.048466
# 반복(step) : 30 , 손실함수(cost) : 0.048987
# 반복(step) : 30 , 손실함수(cost) : 0.050751
# 반복(step) : 30 , 손실함수(cost) : 0.054564
# 반복(step) : 30 , 손실함수(cost) : 0.054564
# 반복(step) : 30 , 손실함수(cost) : 0.055898
# 반복(step) : 30 , 손실함수(cost) : 0.057923
# 반복(step) : 30 , 손실함수(cost) : 0.058754
# 반복(step) : 30 , 손실함수(cost) : 0.059040
# 반복(step) : 30 , 손실함수(cost) : 0.061224
# 반복(step) : 30 , 손실함수(cost) : 0.064592
# 반복(step) : 30 , 손실함수(cost) : 0.067248
# 반복(step) : 30 , 손실함수(cost) : 0.067515
# 반복(step) : 30 , 손실함수(cost) : 0.069279
# 반복(step) : 30 , 손실함수(cost) : 0.072055
# 반복(step) : 30 , 손실함수(cost) : 0.072817
# 반복(step) : 30 , 손실함수(cost) : 0.072817
# 반복(step) : 30 , 손실함수(cost) : 0.072933
# 반복(step) : 30 , 손실함수(cost) : 0.074096
# 반복(step) : 30 , 손실함수(cost) : 0.074616
# 반복(step) : 30 , 손실함수(cost) : 0.074790
# 반복(step) : 30 , 손실함수(cost) : 0.075144
# 반복(step) : 30 , 손실함수(cost) : 0.076719
# 반복(step) : 30 , 손실함수(cost) : 0.077302
# 반복(step) : 30 , 손실함수(cost) : 0.079745
# 반복(step) : 30 , 손실함수(cost) : 0.082079
# 반복(step) : 30 , 손실함수(cost) : 0.083045
# 반복(step) : 30 , 손실함수(cost) : 0.083700
# 반복(step) : 30 , 손실함수(cost) : 0.083759
# 반복(step) : 30 , 손실함수(cost) : 0.083759
# 반복(step) : 30 , 손실함수(cost) : 0.087011
# 반복(step) : 30 , 손실함수(cost) : 0.087011
# 반복(step) : 30 , 손실함수(cost) : 0.087552
# 반복(step) : 30 , 손실함수(cost) : 0.089450
# 반복(step) : 30 , 손실함수(cost) : 0.093242
# 반복(step) : 30 , 손실함수(cost) : 0.093665
# 반복(step) : 30 , 손실함수(cost) : 0.095711
# 반복(step) : 30 , 손실함수(cost) : 0.095711
# 반복(step) : 30 , 손실함수(cost) : 0.096129
# 반복(step) : 30 , 손실함수(cost) : 0.096130
# 반복(step) : 30 , 손실함수(cost) : 0.096132
# 반복(step) : 30 , 손실함수(cost) : 0.096134
# 반복(step) : 30 , 손실함수(cost) : 0.096424
# 반복(step) : 30 , 손실함수(cost) : 0.097996
# 반복(step) : 30 , 손실함수(cost) : 0.098584
# 반복(step) : 30 , 손실함수(cost) : 0.098584
# 반복(step) : 30 , 손실함수(cost) : 0.101403
# 반복(step) : 30 , 손실함수(cost) : 0.103667
# 반복(step) : 30 , 손실함수(cost) : 0.103667
# 반복(step) : 30 , 손실함수(cost) : 0.105545
# 반복(step) : 30 , 손실함수(cost) : 0.106155
# 반복(step) : 30 , 손실함수(cost) : 0.106155
# 반복(step) : 30 , 손실함수(cost) : 0.106970
# 반복(step) : 30 , 손실함수(cost) : 0.107226
# 반복(step) : 30 , 손실함수(cost) : 0.107594
# 반복(step) : 30 , 손실함수(cost) : 0.107868
# 반복(step) : 30 , 손실함수(cost) : 0.109696
# 반복(step) : 30 , 손실함수(cost) : 0.111281
# 반복(step) : 30 , 손실함수(cost) : 0.111391
# 반복(step) : 30 , 손실함수(cost) : 0.111391
# 반복(step) : 30 , 손실함수(cost) : 0.111391
# 반복(step) : 30 , 손실함수(cost) : 0.112786
# 반복(step) : 30 , 손실함수(cost) : 0.113195
# 반복(step) : 30 , 손실함수(cost) : 0.113196
# 반복(step) : 30 , 손실함수(cost) : 0.117559
# 반복(step) : 30 , 손실함수(cost) : 0.117830
# 반복(step) : 30 , 손실함수(cost) : 0.118530
# 반복(step) : 30 , 손실함수(cost) : 0.118904
# 반복(step) : 30 , 손실함수(cost) : 0.118909
# 반복(step) : 30 , 손실함수(cost) : 0.120629
# 반복(step) : 30 , 손실함수(cost) : 0.121628
# 반복(step) : 30 , 손실함수(cost) : 0.121628
# 반복(step) : 30 , 손실함수(cost) : 0.122270
# 반복(step) : 30 , 손실함수(cost) : 0.124965
# 반복(step) : 30 , 손실함수(cost) : 0.125487
# 반복(step) : 30 , 손실함수(cost) : 0.125570
# 반복(step) : 30 , 손실함수(cost) : 0.125720
# 반복(step) : 30 , 손실함수(cost) : 0.126836
# 반복(step) : 30 , 손실함수(cost) : 0.127173
# 반복(step) : 30 , 손실함수(cost) : 0.127173
# 반복(step) : 30 , 손실함수(cost) : 0.127173
# 반복(step) : 30 , 손실함수(cost) : 0.130809
# 반복(step) : 30 , 손실함수(cost) : 0.131126
# 반복(step) : 30 , 손실함수(cost) : 0.131715
# 반복(step) : 30 , 손실함수(cost) : 0.131715
# 반복(step) : 30 , 손실함수(cost) : 0.132846
# 반복(step) : 30 , 손실함수(cost) : 0.132846
# 반복(step) : 30 , 손실함수(cost) : 0.132846
# 반복(step) : 30 , 손실함수(cost) : 0.133518
# 반복(step) : 30 , 손실함수(cost) : 0.135678
# 반복(step) : 30 , 손실함수(cost) : 0.135678
# 반복(step) : 30 , 손실함수(cost) : 0.136290
# 반복(step) : 30 , 손실함수(cost) : 0.136290
# 반복(step) : 30 , 손실함수(cost) : 0.136608
# 반복(step) : 30 , 손실함수(cost) : 0.137137
# 반복(step) : 30 , 손실함수(cost) : 0.139294
# 반복(step) : 30 , 손실함수(cost) : 0.141540
# 반복(step) : 30 , 손실함수(cost) : 0.145285
# 반복(step) : 30 , 손실함수(cost) : 0.146182
# 반복(step) : 30 , 손실함수(cost) : 0.146522
# 반복(step) : 30 , 손실함수(cost) : 0.146550
# 반복(step) : 30 , 손실함수(cost) : 0.159713
# 반복(step) : 30 , 손실함수(cost) : 0.160971
# 반복(step) : 30 , 손실함수(cost) : 0.162175
# 반복(step) : 30 , 손실함수(cost) : 0.162175
# 반복(step) : 30 , 손실함수(cost) : 0.162175
# 반복(step) : 30 , 손실함수(cost) : 0.163052
# 반복(step) : 30 , 손실함수(cost) : 0.164183
# 반복(step) : 30 , 손실함수(cost) : 0.164210
# 반복(step) : 30 , 손실함수(cost) : 0.166024
# 반복(step) : 30 , 손실함수(cost) : 0.166024
# 반복(step) : 30 , 손실함수(cost) : 0.166453
# 반복(step) : 30 , 손실함수(cost) : 0.166458
# 반복(step) : 30 , 손실함수(cost) : 0.169109
# 반복(step) : 30 , 손실함수(cost) : 0.169471
# 반복(step) : 30 , 손실함수(cost) : 0.170407
# 반복(step) : 30 , 손실함수(cost) : 0.171349
# 반복(step) : 30 , 손실함수(cost) : 0.172737
# 반복(step) : 30 , 손실함수(cost) : 0.173063
# 반복(step) : 30 , 손실함수(cost) : 0.173533
# 반복(step) : 30 , 손실함수(cost) : 0.175795
# 반복(step) : 30 , 손실함수(cost) : 0.175795
# 반복(step) : 30 , 손실함수(cost) : 0.176301
# 반복(step) : 30 , 손실함수(cost) : 0.176301
# 반복(step) : 30 , 손실함수(cost) : 0.176879
# 반복(step) : 30 , 손실함수(cost) : 0.179064
# 반복(step) : 30 , 손실함수(cost) : 0.179890
# 반복(step) : 30 , 손실함수(cost) : 0.182315
# 반복(step) : 30 , 손실함수(cost) : 0.186580
# 반복(step) : 30 , 손실함수(cost) : 0.187629
# 반복(step) : 30 , 손실함수(cost) : 0.187795
# 반복(step) : 30 , 손실함수(cost) : 0.188491
# 반복(step) : 30 , 손실함수(cost) : 0.189025
# 반복(step) : 30 , 손실함수(cost) : 0.189202
# 반복(step) : 30 , 손실함수(cost) : 0.191104
# 반복(step) : 30 , 손실함수(cost) : 0.191366
# 반복(step) : 30 , 손실함수(cost) : 0.192024
# 반복(step) : 30 , 손실함수(cost) : 0.192176
# 반복(step) : 30 , 손실함수(cost) : 0.192176
# 반복(step) : 30 , 손실함수(cost) : 0.192505
# 반복(step) : 30 , 손실함수(cost) : 0.192948
# 반복(step) : 30 , 손실함수(cost) : 0.192948
# 반복(step) : 30 , 손실함수(cost) : 0.192948
# 반복(step) : 30 , 손실함수(cost) : 0.194127
# 반복(step) : 30 , 손실함수(cost) : 0.194127
# 반복(step) : 30 , 손실함수(cost) : 0.194870
# 반복(step) : 30 , 손실함수(cost) : 0.195134
# 반복(step) : 30 , 손실함수(cost) : 0.195134
# 반복(step) : 30 , 손실함수(cost) : 0.195771
# 반복(step) : 30 , 손실함수(cost) : 0.196116
# 반복(step) : 30 , 손실함수(cost) : 0.196450
# 반복(step) : 30 , 손실함수(cost) : 0.197741
# 반복(step) : 30 , 손실함수(cost) : 0.197928
# 반복(step) : 30 , 손실함수(cost) : 0.198110
# 반복(step) : 30 , 손실함수(cost) : 0.199476
# 반복(step) : 30 , 손실함수(cost) : 0.199668
# 반복(step) : 30 , 손실함수(cost) : 0.200531
# 반복(step) : 30 , 손실함수(cost) : 0.200944
# 반복(step) : 30 , 손실함수(cost) : 0.201640
# 반복(step) : 30 , 손실함수(cost) : 0.204070
# 반복(step) : 30 , 손실함수(cost) : 0.204117
# 반복(step) : 30 , 손실함수(cost) : 0.204420
# 반복(step) : 30 , 손실함수(cost) : 0.205140
# 반복(step) : 30 , 손실함수(cost) : 0.206151
# 반복(step) : 30 , 손실함수(cost) : 0.208424
# 반복(step) : 30 , 손실함수(cost) : 0.212999
# 반복(step) : 30 , 손실함수(cost) : 0.219594
# 반복(step) : 30 , 손실함수(cost) : 0.221434
# 반복(step) : 30 , 손실함수(cost) : 0.222050
# 반복(step) : 30 , 손실함수(cost) : 0.226968
# 반복(step) : 30 , 손실함수(cost) : 0.228097
# 반복(step) : 30 , 손실함수(cost) : 0.231213
# 반복(step) : 30 , 손실함수(cost) : 0.232772
# 반복(step) : 30 , 손실함수(cost) : 0.233660
# 반복(step) : 30 , 손실함수(cost) : 0.233660
# 반복(step) : 30 , 손실함수(cost) : 0.233660
# 반복(step) : 30 , 손실함수(cost) : 0.234364
# 반복(step) : 30 , 손실함수(cost) : 0.234365
# 반복(step) : 30 , 손실함수(cost) : 0.234611
# 반복(step) : 30 , 손실함수(cost) : 0.234611
# 반복(step) : 30 , 손실함수(cost) : 0.235087
# 반복(step) : 30 , 손실함수(cost) : 0.235087
# 정확도(Accuracy): 0.939400
