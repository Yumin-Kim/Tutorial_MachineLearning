# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import matplotlib.pyplot as plt

# %%
#MInst 데이터 다운!! 
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
#변수 선언
learning_rate = 0.02
training_epochs = 50
batch_size = 256
input_size = 784
hidden1_size = 256
hidden2_size = 128
display_step = 1
examples_to_show = 10

# %%
x = tf.placeholder(tf.float32 , shape=[None , input_size])

# %%
def build_autoencoder(x):
    #인코딩
    W1 = tf.Variable(tf.random_normal(shape=[input_size,hidden1_size]))
    b1 = tf.Variable(tf.random_normal(shape=[hidden1_size]))
    H1_output = tf.nn.sigmoid(tf.matmul(x,W1)+b1)
    W2 = tf.Variable(tf.random_normal(shape=[hidden1_size,hidden2_size]))
    b2 = tf.Variable(tf.random_normal(shape=[hidden2_size]))
    H2_output = tf.nn.sigmoid(tf.matmul(H1_output,W2)+b2)
    #디코딩
    W3 = tf.Variable(tf.random_normal(shape=[hidden2_size,hidden1_size]))
    b3 = tf.Variable(tf.random_normal(shape=[hidden1_size]))
    H3_output = tf.nn.sigmoid(tf.matmul(H2_output,W3)+b3)
    W4 = tf.Variable(tf.random_normal(shape=[hidden1_size,input_size]))
    b4 = tf.Variable(tf.random_normal(shape=[input_size]))
    reconstructed_x = tf.nn.sigmoid(tf.matmul(H3_output,W4)+b4)
    return reconstructed_x

# %%
y_pred = build_autoencoder(x)
y_true = x

# %%
cost = tf.reduce_mean(tf.pow(y_true - y_pred,2))
train_step = tf.train.RMSPropOptimizer(learning_rate).minimize(cost)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(training_epochs):
        total_batch = int(mnist.train.num_examples/batch_size)
        for i in range(total_batch):
            batch_xs , batch_ys = mnist.train.next_batch(batch_size)
            _,current_loss = sess.run([train_step,cost],feed_dict={x:batch_xs})
            if step % display_step == 0:
                print("반복(step) : %d , 손실함수(cost) : %f"%((step+1),current_loss))
     
    reconstructored_result = sess.run(y_pred,feed_dict={x:mnist.test.images[:examples_to_show]})
    f ,a = plt.subplots(2,10,figsize=(10,2))
    for i in range(examples_to_show):
        a[0][i].imshow(np.reshape(mnist.test.images[i],(28,28)))
        a[1][i].imshow(np.reshape(reconstructored_result[i],(28,28)))
    f.savefig('reconstructed_mnisted_image.png')
# Out:
# 반복(step) : 1 , 손실함수(cost) : 0.447771
# 반복(step) : 1 , 손실함수(cost) : 0.448112
# 반복(step) : 1 , 손실함수(cost) : 0.446781
# 반복(step) : 1 , 손실함수(cost) : 0.447404
# 반복(step) : 1 , 손실함수(cost) : 0.447183
# 반복(step) : 1 , 손실함수(cost) : 0.445669
# 반복(step) : 1 , 손실함수(cost) : 0.447791
# 반복(step) : 1 , 손실함수(cost) : 0.446146
# 반복(step) : 1 , 손실함수(cost) : 0.449095
# 반복(step) : 1 , 손실함수(cost) : 0.448199
# 반복(step) : 1 , 손실함수(cost) : 0.446947
# 반복(step) : 1 , 손실함수(cost) : 0.447676
# 반복(step) : 1 , 손실함수(cost) : 0.447289
# 반복(step) : 1 , 손실함수(cost) : 0.447080
# 반복(step) : 1 , 손실함수(cost) : 0.447872
# 반복(step) : 1 , 손실함수(cost) : 0.448080
# 반복(step) : 1 , 손실함수(cost) : 0.447739
# 반복(step) : 1 , 손실함수(cost) : 0.447237
# 반복(step) : 1 , 손실함수(cost) : 0.447404
# 반복(step) : 1 , 손실함수(cost) : 0.446539
# 반복(step) : 1 , 손실함수(cost) : 0.446576
# 반복(step) : 1 , 손실함수(cost) : 0.446652
# 반복(step) : 1 , 손실함수(cost) : 0.446126
# 반복(step) : 1 , 손실함수(cost) : 0.446494
# 반복(step) : 1 , 손실함수(cost) : 0.447466
# 반복(step) : 1 , 손실함수(cost) : 0.446153
# 반복(step) : 1 , 손실함수(cost) : 0.447099
# 반복(step) : 1 , 손실함수(cost) : 0.446748
# 반복(step) : 1 , 손실함수(cost) : 0.445695
# 반복(step) : 1 , 손실함수(cost) : 0.447102
# 반복(step) : 1 , 손실함수(cost) : 0.446265
# 반복(step) : 1 , 손실함수(cost) : 0.445572
# 반복(step) : 1 , 손실함수(cost) : 0.444105
# 반복(step) : 1 , 손실함수(cost) : 0.447739
# 반복(step) : 1 , 손실함수(cost) : 0.446117
# 반복(step) : 1 , 손실함수(cost) : 0.448821
# 반복(step) : 1 , 손실함수(cost) : 0.446679
# 반복(step) : 1 , 손실함수(cost) : 0.447006
# 반복(step) : 1 , 손실함수(cost) : 0.446079
# 반복(step) : 1 , 손실함수(cost) : 0.445582
# 반복(step) : 1 , 손실함수(cost) : 0.446440
# 반복(step) : 1 , 손실함수(cost) : 0.444689
# 반복(step) : 1 , 손실함수(cost) : 0.447330
# 반복(step) : 1 , 손실함수(cost) : 0.445558
# 반복(step) : 1 , 손실함수(cost) : 0.446204
# 반복(step) : 1 , 손실함수(cost) : 0.446536
# 반복(step) : 1 , 손실함수(cost) : 0.444891
# 반복(step) : 1 , 손실함수(cost) : 0.443691
# 반복(step) : 1 , 손실함수(cost) : 0.446247
# 반복(step) : 1 , 손실함수(cost) : 0.445579
# 반복(step) : 1 , 손실함수(cost) : 0.445019
# 반복(step) : 1 , 손실함수(cost) : 0.446176
# 반복(step) : 1 , 손실함수(cost) : 0.443723
# 반복(step) : 1 , 손실함수(cost) : 0.446612
# 반복(step) : 1 , 손실함수(cost) : 0.445768
# 반복(step) : 1 , 손실함수(cost) : 0.445214
# 반복(step) : 1 , 손실함수(cost) : 0.444324
# 반복(step) : 1 , 손실함수(cost) : 0.445316
# 반복(step) : 1 , 손실함수(cost) : 0.442561
# 반복(step) : 1 , 손실함수(cost) : 0.443207
# 반복(step) : 1 , 손실함수(cost) : 0.443954
# 반복(step) : 1 , 손실함수(cost) : 0.444232
# 반복(step) : 1 , 손실함수(cost) : 0.442589
# 반복(step) : 1 , 손실함수(cost) : 0.442987
# 반복(step) : 1 , 손실함수(cost) : 0.441756
# 반복(step) : 1 , 손실함수(cost) : 0.443265
# 반복(step) : 1 , 손실함수(cost) : 0.442219
# 반복(step) : 1 , 손실함수(cost) : 0.442242
# 반복(step) : 1 , 손실함수(cost) : 0.441680
# 반복(step) : 1 , 손실함수(cost) : 0.442030
# 반복(step) : 1 , 손실함수(cost) : 0.440755
# 반복(step) : 1 , 손실함수(cost) : 0.441732
# 반복(step) : 1 , 손실함수(cost) : 0.440992
# 반복(step) : 1 , 손실함수(cost) : 0.440926
# 반복(step) : 1 , 손실함수(cost) : 0.440544
# 반복(step) : 1 , 손실함수(cost) : 0.441527
# 반복(step) : 1 , 손실함수(cost) : 0.439315
# 반복(step) : 1 , 손실함수(cost) : 0.439279
# 반복(step) : 1 , 손실함수(cost) : 0.440461
# 반복(step) : 1 , 손실함수(cost) : 0.439066
# 반복(step) : 1 , 손실함수(cost) : 0.438133
# 반복(step) : 1 , 손실함수(cost) : 0.438781
# 반복(step) : 1 , 손실함수(cost) : 0.437630
# 반복(step) : 1 , 손실함수(cost) : 0.436928
# 반복(step) : 1 , 손실함수(cost) : 0.435556
# 반복(step) : 1 , 손실함수(cost) : 0.433832
# 반복(step) : 1 , 손실함수(cost) : 0.433991
# 반복(step) : 1 , 손실함수(cost) : 0.434546
# 반복(step) : 1 , 손실함수(cost) : 0.434686
# 반복(step) : 1 , 손실함수(cost) : 0.433470
# 반복(step) : 1 , 손실함수(cost) : 0.430215
# 반복(step) : 1 , 손실함수(cost) : 0.430316
# 반복(step) : 1 , 손실함수(cost) : 0.430442
# 반복(step) : 1 , 손실함수(cost) : 0.429726
# 반복(step) : 1 , 손실함수(cost) : 0.429643
# 반복(step) : 1 , 손실함수(cost) : 0.426453
# 반복(step) : 1 , 손실함수(cost) : 0.426066
# 반복(step) : 1 , 손실함수(cost) : 0.424417
# 반복(step) : 1 , 손실함수(cost) : 0.423019
# 반복(step) : 1 , 손실함수(cost) : 0.422285
# 반복(step) : 1 , 손실함수(cost) : 0.421444
# 반복(step) : 1 , 손실함수(cost) : 0.419587
# 반복(step) : 1 , 손실함수(cost) : 0.418116
# 반복(step) : 1 , 손실함수(cost) : 0.415975
# 반복(step) : 1 , 손실함수(cost) : 0.414547
# 반복(step) : 1 , 손실함수(cost) : 0.412259
# 반복(step) : 1 , 손실함수(cost) : 0.410870
# 반복(step) : 1 , 손실함수(cost) : 0.408926
# 반복(step) : 1 , 손실함수(cost) : 0.406302
# 반복(step) : 1 , 손실함수(cost) : 0.404735
# 반복(step) : 1 , 손실함수(cost) : 0.403137
# 반복(step) : 1 , 손실함수(cost) : 0.401595
# 반복(step) : 1 , 손실함수(cost) : 0.397909
# 반복(step) : 1 , 손실함수(cost) : 0.396612
# 반복(step) : 1 , 손실함수(cost) : 0.392774
# 반복(step) : 1 , 손실함수(cost) : 0.391448
# 반복(step) : 1 , 손실함수(cost) : 0.387211
# 반복(step) : 1 , 손실함수(cost) : 0.385077
# 반복(step) : 1 , 손실함수(cost) : 0.380912
# 반복(step) : 1 , 손실함수(cost) : 0.376827
# 반복(step) : 1 , 손실함수(cost) : 0.373535
# 반복(step) : 1 , 손실함수(cost) : 0.370938
# 반복(step) : 1 , 손실함수(cost) : 0.366879
# 반복(step) : 1 , 손실함수(cost) : 0.363373
# 반복(step) : 1 , 손실함수(cost) : 0.359105
# 반복(step) : 1 , 손실함수(cost) : 0.355701
# 반복(step) : 1 , 손실함수(cost) : 0.349969
# 반복(step) : 1 , 손실함수(cost) : 0.347382
# 반복(step) : 1 , 손실함수(cost) : 0.342803
# 반복(step) : 1 , 손실함수(cost) : 0.337379
# 반복(step) : 1 , 손실함수(cost) : 0.332633
# 반복(step) : 1 , 손실함수(cost) : 0.326973
# 반복(step) : 1 , 손실함수(cost) : 0.321897
# 반복(step) : 1 , 손실함수(cost) : 0.319117
# 반복(step) : 1 , 손실함수(cost) : 0.313216
# 반복(step) : 1 , 손실함수(cost) : 0.309398
# 반복(step) : 1 , 손실함수(cost) : 0.305429
# 반복(step) : 1 , 손실함수(cost) : 0.300784
# 반복(step) : 1 , 손실함수(cost) : 0.294896
# 반복(step) : 1 , 손실함수(cost) : 0.290551
# 반복(step) : 1 , 손실함수(cost) : 0.285524
# 반복(step) : 1 , 손실함수(cost) : 0.280546
# 반복(step) : 1 , 손실함수(cost) : 0.276571
# 반복(step) : 1 , 손실함수(cost) : 0.272552
# 반복(step) : 1 , 손실함수(cost) : 0.268478
# 반복(step) : 1 , 손실함수(cost) : 0.267173
# 반복(step) : 1 , 손실함수(cost) : 0.260844
# 반복(step) : 1 , 손실함수(cost) : 0.258947
# 반복(step) : 1 , 손실함수(cost) : 0.257560
# 반복(step) : 1 , 손실함수(cost) : 0.253954
# 반복(step) : 1 , 손실함수(cost) : 0.254084
# 반복(step) : 1 , 손실함수(cost) : 0.250189
# 반복(step) : 1 , 손실함수(cost) : 0.249134
# 반복(step) : 1 , 손실함수(cost) : 0.247406
# 반복(step) : 1 , 손실함수(cost) : 0.245715
# 반복(step) : 1 , 손실함수(cost) : 0.243951
# 반복(step) : 1 , 손실함수(cost) : 0.242187
# 반복(step) : 1 , 손실함수(cost) : 0.240924
# 반복(step) : 1 , 손실함수(cost) : 0.238701
# 반복(step) : 1 , 손실함수(cost) : 0.237438
# 반복(step) : 1 , 손실함수(cost) : 0.237775
# 반복(step) : 1 , 손실함수(cost) : 0.236191
# 반복(step) : 1 , 손실함수(cost) : 0.236723
# 반복(step) : 1 , 손실함수(cost) : 0.235989
# 반복(step) : 1 , 손실함수(cost) : 0.235202
# 반복(step) : 1 , 손실함수(cost) : 0.232409
# 반복(step) : 1 , 손실함수(cost) : 0.231232
# 반복(step) : 1 , 손실함수(cost) : 0.231352
# 반복(step) : 1 , 손실함수(cost) : 0.231465
# 반복(step) : 1 , 손실함수(cost) : 0.229780
# 반복(step) : 1 , 손실함수(cost) : 0.229036
# 반복(step) : 1 , 손실함수(cost) : 0.229178
# 반복(step) : 1 , 손실함수(cost) : 0.227137
# 반복(step) : 1 , 손실함수(cost) : 0.230090
# 반복(step) : 1 , 손실함수(cost) : 0.228879
# 반복(step) : 1 , 손실함수(cost) : 0.227543
# 반복(step) : 1 , 손실함수(cost) : 0.228721
# 반복(step) : 1 , 손실함수(cost) : 0.229536
# 반복(step) : 1 , 손실함수(cost) : 0.230889
# 반복(step) : 1 , 손실함수(cost) : 0.230588
# 반복(step) : 1 , 손실함수(cost) : 0.229839
# 반복(step) : 1 , 손실함수(cost) : 0.227753
# 반복(step) : 1 , 손실함수(cost) : 0.228543
# 반복(step) : 1 , 손실함수(cost) : 0.226221
# 반복(step) : 1 , 손실함수(cost) : 0.227239
# 반복(step) : 1 , 손실함수(cost) : 0.227746
# 반복(step) : 1 , 손실함수(cost) : 0.226658
# 반복(step) : 1 , 손실함수(cost) : 0.226974
# 반복(step) : 1 , 손실함수(cost) : 0.228520
# 반복(step) : 1 , 손실함수(cost) : 0.225261
# 반복(step) : 1 , 손실함수(cost) : 0.228603
# 반복(step) : 1 , 손실함수(cost) : 0.227699
# 반복(step) : 1 , 손실함수(cost) : 0.226061
# 반복(step) : 1 , 손실함수(cost) : 0.226310
# 반복(step) : 1 , 손실함수(cost) : 0.223164
# 반복(step) : 1 , 손실함수(cost) : 0.226185
# 반복(step) : 1 , 손실함수(cost) : 0.223370
# 반복(step) : 1 , 손실함수(cost) : 0.224780
# 반복(step) : 1 , 손실함수(cost) : 0.222761
# 반복(step) : 1 , 손실함수(cost) : 0.222122
# 반복(step) : 1 , 손실함수(cost) : 0.223602
# 반복(step) : 1 , 손실함수(cost) : 0.223941
# 반복(step) : 1 , 손실함수(cost) : 0.225348
# 반복(step) : 1 , 손실함수(cost) : 0.224122
# 반복(step) : 1 , 손실함수(cost) : 0.219734
# 반복(step) : 1 , 손실함수(cost) : 0.221460
# 반복(step) : 1 , 손실함수(cost) : 0.219825
# 반복(step) : 1 , 손실함수(cost) : 0.219431
# 반복(step) : 1 , 손실함수(cost) : 0.216342
# 반복(step) : 1 , 손실함수(cost) : 0.217613
# 반복(step) : 1 , 손실함수(cost) : 0.220477
# 반복(step) : 1 , 손실함수(cost) : 0.216940
# 반복(step) : 1 , 손실함수(cost) : 0.217082
# 반복(step) : 1 , 손실함수(cost) : 0.220038
# 반복(step) : 2 , 손실함수(cost) : 0.216019
# 반복(step) : 2 , 손실함수(cost) : 0.216129
# 반복(step) : 2 , 손실함수(cost) : 0.218414
# 반복(step) : 2 , 손실함수(cost) : 0.215215
# 반복(step) : 2 , 손실함수(cost) : 0.215590
# 반복(step) : 2 , 손실함수(cost) : 0.214349
# 반복(step) : 2 , 손실함수(cost) : 0.214128
# 반복(step) : 2 , 손실함수(cost) : 0.216166
# 반복(step) : 2 , 손실함수(cost) : 0.214244
# 반복(step) : 2 , 손실함수(cost) : 0.214830
# 반복(step) : 2 , 손실함수(cost) : 0.210163
# 반복(step) : 2 , 손실함수(cost) : 0.211873
# 반복(step) : 2 , 손실함수(cost) : 0.213450
# 반복(step) : 2 , 손실함수(cost) : 0.212562
# 반복(step) : 2 , 손실함수(cost) : 0.210298
# 반복(step) : 2 , 손실함수(cost) : 0.210331
# 반복(step) : 2 , 손실함수(cost) : 0.210663
# 반복(step) : 2 , 손실함수(cost) : 0.210728
# 반복(step) : 2 , 손실함수(cost) : 0.215999
# 반복(step) : 2 , 손실함수(cost) : 0.210082
# 반복(step) : 2 , 손실함수(cost) : 0.208507
# 반복(step) : 2 , 손실함수(cost) : 0.208141
# 반복(step) : 2 , 손실함수(cost) : 0.208170
# 반복(step) : 2 , 손실함수(cost) : 0.207681
# 반복(step) : 2 , 손실함수(cost) : 0.206297
# 반복(step) : 2 , 손실함수(cost) : 0.206151
# 반복(step) : 2 , 손실함수(cost) : 0.204258
# 반복(step) : 2 , 손실함수(cost) : 0.205718
# 반복(step) : 2 , 손실함수(cost) : 0.204691
# 반복(step) : 2 , 손실함수(cost) : 0.203871
# 반복(step) : 2 , 손실함수(cost) : 0.206143
# 반복(step) : 2 , 손실함수(cost) : 0.205157
# 반복(step) : 2 , 손실함수(cost) : 0.201617
# 반복(step) : 2 , 손실함수(cost) : 0.202678
# 반복(step) : 2 , 손실함수(cost) : 0.203107
# 반복(step) : 2 , 손실함수(cost) : 0.203627
# 반복(step) : 2 , 손실함수(cost) : 0.203784
# 반복(step) : 2 , 손실함수(cost) : 0.201253
# 반복(step) : 2 , 손실함수(cost) : 0.203035
# 반복(step) : 2 , 손실함수(cost) : 0.201740
# 반복(step) : 2 , 손실함수(cost) : 0.199018
# 반복(step) : 2 , 손실함수(cost) : 0.201493
# 반복(step) : 2 , 손실함수(cost) : 0.202415
# 반복(step) : 2 , 손실함수(cost) : 0.201528
# 반복(step) : 2 , 손실함수(cost) : 0.199988
# 반복(step) : 2 , 손실함수(cost) : 0.199391
# 반복(step) : 2 , 손실함수(cost) : 0.195544
# 반복(step) : 2 , 손실함수(cost) : 0.197766
# 반복(step) : 2 , 손실함수(cost) : 0.200104
# 반복(step) : 2 , 손실함수(cost) : 0.196515
# 반복(step) : 2 , 손실함수(cost) : 0.195026
# 반복(step) : 2 , 손실함수(cost) : 0.199367
# 반복(step) : 2 , 손실함수(cost) : 0.196597
# 반복(step) : 2 , 손실함수(cost) : 0.197176
# 반복(step) : 2 , 손실함수(cost) : 0.194415
# 반복(step) : 2 , 손실함수(cost) : 0.193270
# 반복(step) : 2 , 손실함수(cost) : 0.193534
# 반복(step) : 2 , 손실함수(cost) : 0.195196
# 반복(step) : 2 , 손실함수(cost) : 0.192593
# 반복(step) : 2 , 손실함수(cost) : 0.193238
# 반복(step) : 2 , 손실함수(cost) : 0.194019
# 반복(step) : 2 , 손실함수(cost) : 0.194312
# 반복(step) : 2 , 손실함수(cost) : 0.197973
# 반복(step) : 2 , 손실함수(cost) : 0.192603
# 반복(step) : 2 , 손실함수(cost) : 0.192923
# 반복(step) : 2 , 손실함수(cost) : 0.194022
# 반복(step) : 2 , 손실함수(cost) : 0.192469
# 반복(step) : 2 , 손실함수(cost) : 0.193373
# 반복(step) : 2 , 손실함수(cost) : 0.194750
# 반복(step) : 2 , 손실함수(cost) : 0.189385
# 반복(step) : 2 , 손실함수(cost) : 0.191738
# 반복(step) : 2 , 손실함수(cost) : 0.187531
# 반복(step) : 2 , 손실함수(cost) : 0.185021
# 반복(step) : 2 , 손실함수(cost) : 0.186535
# 반복(step) : 2 , 손실함수(cost) : 0.188335
# 반복(step) : 2 , 손실함수(cost) : 0.191169
# 반복(step) : 2 , 손실함수(cost) : 0.188503
# 반복(step) : 2 , 손실함수(cost) : 0.186695
# 반복(step) : 2 , 손실함수(cost) : 0.185269
# 반복(step) : 2 , 손실함수(cost) : 0.183716
# 반복(step) : 2 , 손실함수(cost) : 0.185610
# 반복(step) : 2 , 손실함수(cost) : 0.184375
# 반복(step) : 2 , 손실함수(cost) : 0.185220
# 반복(step) : 2 , 손실함수(cost) : 0.186433
# 반복(step) : 2 , 손실함수(cost) : 0.183579
# 반복(step) : 2 , 손실함수(cost) : 0.183447
# 반복(step) : 2 , 손실함수(cost) : 0.182686
# 반복(step) : 2 , 손실함수(cost) : 0.181855
# 반복(step) : 2 , 손실함수(cost) : 0.183557
# 반복(step) : 2 , 손실함수(cost) : 0.182920
# 반복(step) : 2 , 손실함수(cost) : 0.183972
# 반복(step) : 2 , 손실함수(cost) : 0.180888
# 반복(step) : 2 , 손실함수(cost) : 0.178409
# 반복(step) : 2 , 손실함수(cost) : 0.180478
# 반복(step) : 2 , 손실함수(cost) : 0.179608
# 반복(step) : 2 , 손실함수(cost) : 0.181960
# 반복(step) : 2 , 손실함수(cost) : 0.179038
# 반복(step) : 2 , 손실함수(cost) : 0.182592
# 반복(step) : 2 , 손실함수(cost) : 0.180545
# 반복(step) : 2 , 손실함수(cost) : 0.183602
# 반복(step) : 2 , 손실함수(cost) : 0.181266
# 반복(step) : 2 , 손실함수(cost) : 0.179064
# 반복(step) : 2 , 손실함수(cost) : 0.180070
# 반복(step) : 2 , 손실함수(cost) : 0.181559
# 반복(step) : 2 , 손실함수(cost) : 0.182001
# 반복(step) : 2 , 손실함수(cost) : 0.179880
# 반복(step) : 2 , 손실함수(cost) : 0.178717
# 반복(step) : 2 , 손실함수(cost) : 0.179239
# 반복(step) : 2 , 손실함수(cost) : 0.176268
# 반복(step) : 2 , 손실함수(cost) : 0.175365
# 반복(step) : 2 , 손실함수(cost) : 0.175034
# 반복(step) : 2 , 손실함수(cost) : 0.174858
# 반복(step) : 2 , 손실함수(cost) : 0.177947
# 반복(step) : 2 , 손실함수(cost) : 0.178598
# 반복(step) : 2 , 손실함수(cost) : 0.175871
# 반복(step) : 2 , 손실함수(cost) : 0.174541
# 반복(step) : 2 , 손실함수(cost) : 0.174031
# 반복(step) : 2 , 손실함수(cost) : 0.175069
# 반복(step) : 2 , 손실함수(cost) : 0.174800
# 반복(step) : 2 , 손실함수(cost) : 0.173583
# 반복(step) : 2 , 손실함수(cost) : 0.173558
# 반복(step) : 2 , 손실함수(cost) : 0.175404
# 반복(step) : 2 , 손실함수(cost) : 0.174615
# 반복(step) : 2 , 손실함수(cost) : 0.174467
# 반복(step) : 2 , 손실함수(cost) : 0.173984
# 반복(step) : 2 , 손실함수(cost) : 0.174463
# 반복(step) : 2 , 손실함수(cost) : 0.174962
# 반복(step) : 2 , 손실함수(cost) : 0.173228
# 반복(step) : 2 , 손실함수(cost) : 0.173319
# 반복(step) : 2 , 손실함수(cost) : 0.170388
# 반복(step) : 2 , 손실함수(cost) : 0.171474
# 반복(step) : 2 , 손실함수(cost) : 0.172242
# 반복(step) : 2 , 손실함수(cost) : 0.171986
# 반복(step) : 2 , 손실함수(cost) : 0.172966
# 반복(step) : 2 , 손실함수(cost) : 0.175194
# 반복(step) : 2 , 손실함수(cost) : 0.170424
# 반복(step) : 2 , 손실함수(cost) : 0.169401
# 반복(step) : 2 , 손실함수(cost) : 0.169917
# 반복(step) : 2 , 손실함수(cost) : 0.171326
# 반복(step) : 2 , 손실함수(cost) : 0.169150
# 반복(step) : 2 , 손실함수(cost) : 0.169758
# 반복(step) : 2 , 손실함수(cost) : 0.170251
# 반복(step) : 2 , 손실함수(cost) : 0.169129
# 반복(step) : 2 , 손실함수(cost) : 0.167281
# 반복(step) : 2 , 손실함수(cost) : 0.165545
# 반복(step) : 2 , 손실함수(cost) : 0.166838
# 반복(step) : 2 , 손실함수(cost) : 0.169071
# 반복(step) : 2 , 손실함수(cost) : 0.165629
# 반복(step) : 2 , 손실함수(cost) : 0.167439
# 반복(step) : 2 , 손실함수(cost) : 0.166372
# 반복(step) : 2 , 손실함수(cost) : 0.166295
# 반복(step) : 2 , 손실함수(cost) : 0.167990
# 반복(step) : 2 , 손실함수(cost) : 0.164336
# 반복(step) : 2 , 손실함수(cost) : 0.165567
# 반복(step) : 2 , 손실함수(cost) : 0.166662
# 반복(step) : 2 , 손실함수(cost) : 0.167055
# 반복(step) : 2 , 손실함수(cost) : 0.166867
# 반복(step) : 2 , 손실함수(cost) : 0.166922
# 반복(step) : 2 , 손실함수(cost) : 0.162976
# 반복(step) : 2 , 손실함수(cost) : 0.163746
# 반복(step) : 2 , 손실함수(cost) : 0.161735
# 반복(step) : 2 , 손실함수(cost) : 0.165657
# 반복(step) : 2 , 손실함수(cost) : 0.165365
# 반복(step) : 2 , 손실함수(cost) : 0.163885
# 반복(step) : 2 , 손실함수(cost) : 0.165669
# 반복(step) : 2 , 손실함수(cost) : 0.164773
# 반복(step) : 2 , 손실함수(cost) : 0.163248
# 반복(step) : 2 , 손실함수(cost) : 0.162297
# 반복(step) : 2 , 손실함수(cost) : 0.162794
# 반복(step) : 2 , 손실함수(cost) : 0.163276
# 반복(step) : 2 , 손실함수(cost) : 0.162858
# 반복(step) : 2 , 손실함수(cost) : 0.159277
# 반복(step) : 2 , 손실함수(cost) : 0.159627
# 반복(step) : 2 , 손실함수(cost) : 0.158882
# 반복(step) : 2 , 손실함수(cost) : 0.158353
# 반복(step) : 2 , 손실함수(cost) : 0.160258
# 반복(step) : 2 , 손실함수(cost) : 0.161217
# 반복(step) : 2 , 손실함수(cost) : 0.162285
# 반복(step) : 2 , 손실함수(cost) : 0.160415
# 반복(step) : 2 , 손실함수(cost) : 0.159029
# 반복(step) : 2 , 손실함수(cost) : 0.160300
# 반복(step) : 2 , 손실함수(cost) : 0.157940
# 반복(step) : 2 , 손실함수(cost) : 0.159204
# 반복(step) : 2 , 손실함수(cost) : 0.155286
# 반복(step) : 2 , 손실함수(cost) : 0.158438
# 반복(step) : 2 , 손실함수(cost) : 0.159493
# 반복(step) : 2 , 손실함수(cost) : 0.156389
# 반복(step) : 2 , 손실함수(cost) : 0.155939
# 반복(step) : 2 , 손실함수(cost) : 0.157505
# 반복(step) : 2 , 손실함수(cost) : 0.159865
# 반복(step) : 2 , 손실함수(cost) : 0.158393
# 반복(step) : 2 , 손실함수(cost) : 0.158895
# 반복(step) : 2 , 손실함수(cost) : 0.158484
# 반복(step) : 2 , 손실함수(cost) : 0.157306
# 반복(step) : 2 , 손실함수(cost) : 0.157890
# 반복(step) : 2 , 손실함수(cost) : 0.158967
# 반복(step) : 2 , 손실함수(cost) : 0.157186
# 반복(step) : 2 , 손실함수(cost) : 0.158317
# 반복(step) : 2 , 손실함수(cost) : 0.157187
# 반복(step) : 2 , 손실함수(cost) : 0.156955
# 반복(step) : 2 , 손실함수(cost) : 0.154996
# 반복(step) : 2 , 손실함수(cost) : 0.160685
# 반복(step) : 2 , 손실함수(cost) : 0.157933
# 반복(step) : 2 , 손실함수(cost) : 0.157514
# 반복(step) : 2 , 손실함수(cost) : 0.156788
# 반복(step) : 2 , 손실함수(cost) : 0.155716
# 반복(step) : 2 , 손실함수(cost) : 0.155588
# 반복(step) : 2 , 손실함수(cost) : 0.155047
# 반복(step) : 2 , 손실함수(cost) : 0.153369
# 반복(step) : 2 , 손실함수(cost) : 0.157614
# 반복(step) : 2 , 손실함수(cost) : 0.154005
# 반복(step) : 2 , 손실함수(cost) : 0.154666
# 반복(step) : 2 , 손실함수(cost) : 0.155479
# 반복(step) : 2 , 손실함수(cost) : 0.153812
# 반복(step) : 3 , 손실함수(cost) : 0.154515
# 반복(step) : 3 , 손실함수(cost) : 0.153730
# 반복(step) : 3 , 손실함수(cost) : 0.156483
# 반복(step) : 3 , 손실함수(cost) : 0.155770
# 반복(step) : 3 , 손실함수(cost) : 0.152625
# 반복(step) : 3 , 손실함수(cost) : 0.155925
# 반복(step) : 3 , 손실함수(cost) : 0.157076
# 반복(step) : 3 , 손실함수(cost) : 0.154759
# 반복(step) : 3 , 손실함수(cost) : 0.154738
# 반복(step) : 3 , 손실함수(cost) : 0.151670
# 반복(step) : 3 , 손실함수(cost) : 0.154319
# 반복(step) : 3 , 손실함수(cost) : 0.155680
# 반복(step) : 3 , 손실함수(cost) : 0.154034
# 반복(step) : 3 , 손실함수(cost) : 0.150773
# 반복(step) : 3 , 손실함수(cost) : 0.151644
# 반복(step) : 3 , 손실함수(cost) : 0.152507
# 반복(step) : 3 , 손실함수(cost) : 0.153345
# 반복(step) : 3 , 손실함수(cost) : 0.152095
# 반복(step) : 3 , 손실함수(cost) : 0.151232
# 반복(step) : 3 , 손실함수(cost) : 0.151579
# 반복(step) : 3 , 손실함수(cost) : 0.147515
# 반복(step) : 3 , 손실함수(cost) : 0.146980
# 반복(step) : 3 , 손실함수(cost) : 0.147638
# 반복(step) : 3 , 손실함수(cost) : 0.148202
# 반복(step) : 3 , 손실함수(cost) : 0.149853
# 반복(step) : 3 , 손실함수(cost) : 0.152043
# 반복(step) : 3 , 손실함수(cost) : 0.149424
# 반복(step) : 3 , 손실함수(cost) : 0.150112
# 반복(step) : 3 , 손실함수(cost) : 0.146578
# 반복(step) : 3 , 손실함수(cost) : 0.148372
# 반복(step) : 3 , 손실함수(cost) : 0.148153
# 반복(step) : 3 , 손실함수(cost) : 0.146639
# 반복(step) : 3 , 손실함수(cost) : 0.147490
# 반복(step) : 3 , 손실함수(cost) : 0.147025
# 반복(step) : 3 , 손실함수(cost) : 0.146728
# 반복(step) : 3 , 손실함수(cost) : 0.147093
# 반복(step) : 3 , 손실함수(cost) : 0.145963
# 반복(step) : 3 , 손실함수(cost) : 0.145092
# 반복(step) : 3 , 손실함수(cost) : 0.146192
# 반복(step) : 3 , 손실함수(cost) : 0.144645
# 반복(step) : 3 , 손실함수(cost) : 0.143725
# 반복(step) : 3 , 손실함수(cost) : 0.144119
# 반복(step) : 3 , 손실함수(cost) : 0.145876
# 반복(step) : 3 , 손실함수(cost) : 0.144313
# 반복(step) : 3 , 손실함수(cost) : 0.144909
# 반복(step) : 3 , 손실함수(cost) : 0.145184
# 반복(step) : 3 , 손실함수(cost) : 0.145808
# 반복(step) : 3 , 손실함수(cost) : 0.141865
# 반복(step) : 3 , 손실함수(cost) : 0.142916
# 반복(step) : 3 , 손실함수(cost) : 0.143647
# 반복(step) : 3 , 손실함수(cost) : 0.144581
# 반복(step) : 3 , 손실함수(cost) : 0.145321
# 반복(step) : 3 , 손실함수(cost) : 0.145941
# 반복(step) : 3 , 손실함수(cost) : 0.146105
# 반복(step) : 3 , 손실함수(cost) : 0.146028
# 반복(step) : 3 , 손실함수(cost) : 0.144638
# 반복(step) : 3 , 손실함수(cost) : 0.145428
# 반복(step) : 3 , 손실함수(cost) : 0.146113
# 반복(step) : 3 , 손실함수(cost) : 0.144225
# 반복(step) : 3 , 손실함수(cost) : 0.143693
# 반복(step) : 3 , 손실함수(cost) : 0.142070
# 반복(step) : 3 , 손실함수(cost) : 0.145974
# 반복(step) : 3 , 손실함수(cost) : 0.142397
# 반복(step) : 3 , 손실함수(cost) : 0.143226
# 반복(step) : 3 , 손실함수(cost) : 0.146626
# 반복(step) : 3 , 손실함수(cost) : 0.141206
# 반복(step) : 3 , 손실함수(cost) : 0.143756
# 반복(step) : 3 , 손실함수(cost) : 0.143926
# 반복(step) : 3 , 손실함수(cost) : 0.141959
# 반복(step) : 3 , 손실함수(cost) : 0.140698
# 반복(step) : 3 , 손실함수(cost) : 0.141143
# 반복(step) : 3 , 손실함수(cost) : 0.139505
# 반복(step) : 3 , 손실함수(cost) : 0.141608
# 반복(step) : 3 , 손실함수(cost) : 0.141112
# 반복(step) : 3 , 손실함수(cost) : 0.141534
# 반복(step) : 3 , 손실함수(cost) : 0.142210
# 반복(step) : 3 , 손실함수(cost) : 0.140310
# 반복(step) : 3 , 손실함수(cost) : 0.141186
# 반복(step) : 3 , 손실함수(cost) : 0.145123
# 반복(step) : 3 , 손실함수(cost) : 0.141894
# 반복(step) : 3 , 손실함수(cost) : 0.143477
# 반복(step) : 3 , 손실함수(cost) : 0.138943
# 반복(step) : 3 , 손실함수(cost) : 0.138722
# 반복(step) : 3 , 손실함수(cost) : 0.140737
# 반복(step) : 3 , 손실함수(cost) : 0.141172
# 반복(step) : 3 , 손실함수(cost) : 0.138090
# 반복(step) : 3 , 손실함수(cost) : 0.138411
# 반복(step) : 3 , 손실함수(cost) : 0.137191
# 반복(step) : 3 , 손실함수(cost) : 0.137625
# 반복(step) : 3 , 손실함수(cost) : 0.137698
# 반복(step) : 3 , 손실함수(cost) : 0.139288
# 반복(step) : 3 , 손실함수(cost) : 0.136337
# 반복(step) : 3 , 손실함수(cost) : 0.135146
# 반복(step) : 3 , 손실함수(cost) : 0.135507
# 반복(step) : 3 , 손실함수(cost) : 0.138847
# 반복(step) : 3 , 손실함수(cost) : 0.138402
# 반복(step) : 3 , 손실함수(cost) : 0.139798
# 반복(step) : 3 , 손실함수(cost) : 0.139723
# 반복(step) : 3 , 손실함수(cost) : 0.138750
# 반복(step) : 3 , 손실함수(cost) : 0.139154
# 반복(step) : 3 , 손실함수(cost) : 0.139115
# 반복(step) : 3 , 손실함수(cost) : 0.137778
# 반복(step) : 3 , 손실함수(cost) : 0.136595
# 반복(step) : 3 , 손실함수(cost) : 0.134993
# 반복(step) : 3 , 손실함수(cost) : 0.136495
# 반복(step) : 3 , 손실함수(cost) : 0.138058
# 반복(step) : 3 , 손실함수(cost) : 0.137237
# 반복(step) : 3 , 손실함수(cost) : 0.135440
# 반복(step) : 3 , 손실함수(cost) : 0.135219
# 반복(step) : 3 , 손실함수(cost) : 0.136585
# 반복(step) : 3 , 손실함수(cost) : 0.138353
# 반복(step) : 3 , 손실함수(cost) : 0.137742
# 반복(step) : 3 , 손실함수(cost) : 0.136142
# 반복(step) : 3 , 손실함수(cost) : 0.137016
# 반복(step) : 3 , 손실함수(cost) : 0.138094
# 반복(step) : 3 , 손실함수(cost) : 0.136917
# 반복(step) : 3 , 손실함수(cost) : 0.136448
# 반복(step) : 3 , 손실함수(cost) : 0.136557
# 반복(step) : 3 , 손실함수(cost) : 0.133559
# 반복(step) : 3 , 손실함수(cost) : 0.135122
# 반복(step) : 3 , 손실함수(cost) : 0.135807
# 반복(step) : 3 , 손실함수(cost) : 0.135506
# 반복(step) : 3 , 손실함수(cost) : 0.133517
# 반복(step) : 3 , 손실함수(cost) : 0.136029
# 반복(step) : 3 , 손실함수(cost) : 0.133799
# 반복(step) : 3 , 손실함수(cost) : 0.131094
# 반복(step) : 3 , 손실함수(cost) : 0.135306
# 반복(step) : 3 , 손실함수(cost) : 0.137690
# 반복(step) : 3 , 손실함수(cost) : 0.131198
# 반복(step) : 3 , 손실함수(cost) : 0.132786
# 반복(step) : 3 , 손실함수(cost) : 0.133658
# 반복(step) : 3 , 손실함수(cost) : 0.132770
# 반복(step) : 3 , 손실함수(cost) : 0.136099
# 반복(step) : 3 , 손실함수(cost) : 0.132220
# 반복(step) : 3 , 손실함수(cost) : 0.133891
# 반복(step) : 3 , 손실함수(cost) : 0.131266
# 반복(step) : 3 , 손실함수(cost) : 0.131567
# 반복(step) : 3 , 손실함수(cost) : 0.132919
# 반복(step) : 3 , 손실함수(cost) : 0.131098
# 반복(step) : 3 , 손실함수(cost) : 0.134081
# 반복(step) : 3 , 손실함수(cost) : 0.130641
# 반복(step) : 3 , 손실함수(cost) : 0.131196
# 반복(step) : 3 , 손실함수(cost) : 0.131479
# 반복(step) : 3 , 손실함수(cost) : 0.133455
# 반복(step) : 3 , 손실함수(cost) : 0.132247
# 반복(step) : 3 , 손실함수(cost) : 0.133446
# 반복(step) : 3 , 손실함수(cost) : 0.132724
# 반복(step) : 3 , 손실함수(cost) : 0.133810
# 반복(step) : 3 , 손실함수(cost) : 0.133340
# 반복(step) : 3 , 손실함수(cost) : 0.131587
# 반복(step) : 3 , 손실함수(cost) : 0.126385
# 반복(step) : 3 , 손실함수(cost) : 0.131301
# 반복(step) : 3 , 손실함수(cost) : 0.132875
# 반복(step) : 3 , 손실함수(cost) : 0.133073
# 반복(step) : 3 , 손실함수(cost) : 0.130932
# 반복(step) : 3 , 손실함수(cost) : 0.130051
# 반복(step) : 3 , 손실함수(cost) : 0.130387
# 반복(step) : 3 , 손실함수(cost) : 0.132978
# 반복(step) : 3 , 손실함수(cost) : 0.132589
# 반복(step) : 3 , 손실함수(cost) : 0.133520
# 반복(step) : 3 , 손실함수(cost) : 0.130298
# 반복(step) : 3 , 손실함수(cost) : 0.131394
# 반복(step) : 3 , 손실함수(cost) : 0.128506
# 반복(step) : 3 , 손실함수(cost) : 0.131167
# 반복(step) : 3 , 손실함수(cost) : 0.131339
# 반복(step) : 3 , 손실함수(cost) : 0.128284
# 반복(step) : 3 , 손실함수(cost) : 0.129703
# 반복(step) : 3 , 손실함수(cost) : 0.130436
# 반복(step) : 3 , 손실함수(cost) : 0.128560
# 반복(step) : 3 , 손실함수(cost) : 0.130058
# 반복(step) : 3 , 손실함수(cost) : 0.128153
# 반복(step) : 3 , 손실함수(cost) : 0.129237
# 반복(step) : 3 , 손실함수(cost) : 0.128180
# 반복(step) : 3 , 손실함수(cost) : 0.130161
# 반복(step) : 3 , 손실함수(cost) : 0.127249
# 반복(step) : 3 , 손실함수(cost) : 0.129070
# 반복(step) : 3 , 손실함수(cost) : 0.128878
# 반복(step) : 3 , 손실함수(cost) : 0.131950
# 반복(step) : 3 , 손실함수(cost) : 0.125706
# 반복(step) : 3 , 손실함수(cost) : 0.129510
# 반복(step) : 3 , 손실함수(cost) : 0.130079
# 반복(step) : 3 , 손실함수(cost) : 0.126422
# 반복(step) : 3 , 손실함수(cost) : 0.128647
# 반복(step) : 3 , 손실함수(cost) : 0.127025
# 반복(step) : 3 , 손실함수(cost) : 0.126062
# 반복(step) : 3 , 손실함수(cost) : 0.127648
# 반복(step) : 3 , 손실함수(cost) : 0.128413
# 반복(step) : 3 , 손실함수(cost) : 0.127057
# 반복(step) : 3 , 손실함수(cost) : 0.126493
# 반복(step) : 3 , 손실함수(cost) : 0.128010
# 반복(step) : 3 , 손실함수(cost) : 0.128966
# 반복(step) : 3 , 손실함수(cost) : 0.126333
# 반복(step) : 3 , 손실함수(cost) : 0.126437
# 반복(step) : 3 , 손실함수(cost) : 0.126378
# 반복(step) : 3 , 손실함수(cost) : 0.127264
# 반복(step) : 3 , 손실함수(cost) : 0.127720
# 반복(step) : 3 , 손실함수(cost) : 0.127228
# 반복(step) : 3 , 손실함수(cost) : 0.127073
# 반복(step) : 3 , 손실함수(cost) : 0.125749
# 반복(step) : 3 , 손실함수(cost) : 0.125039
# 반복(step) : 3 , 손실함수(cost) : 0.127254
# 반복(step) : 3 , 손실함수(cost) : 0.124390
# 반복(step) : 3 , 손실함수(cost) : 0.128171
# 반복(step) : 3 , 손실함수(cost) : 0.128238
# 반복(step) : 3 , 손실함수(cost) : 0.131632
# 반복(step) : 3 , 손실함수(cost) : 0.127646
# 반복(step) : 3 , 손실함수(cost) : 0.126445
# 반복(step) : 3 , 손실함수(cost) : 0.125916
# 반복(step) : 3 , 손실함수(cost) : 0.127128
# 반복(step) : 3 , 손실함수(cost) : 0.127003
# 반복(step) : 3 , 손실함수(cost) : 0.127945
# 반복(step) : 3 , 손실함수(cost) : 0.126454
# 반복(step) : 3 , 손실함수(cost) : 0.129261
# 반복(step) : 3 , 손실함수(cost) : 0.124706
# 반복(step) : 4 , 손실함수(cost) : 0.128188
# 반복(step) : 4 , 손실함수(cost) : 0.124739
# 반복(step) : 4 , 손실함수(cost) : 0.127180
# 반복(step) : 4 , 손실함수(cost) : 0.123136
# 반복(step) : 4 , 손실함수(cost) : 0.125418
# 반복(step) : 4 , 손실함수(cost) : 0.126006
# 반복(step) : 4 , 손실함수(cost) : 0.127270
# 반복(step) : 4 , 손실함수(cost) : 0.124519
# 반복(step) : 4 , 손실함수(cost) : 0.127084
# 반복(step) : 4 , 손실함수(cost) : 0.124628
# 반복(step) : 4 , 손실함수(cost) : 0.125240
# 반복(step) : 4 , 손실함수(cost) : 0.124938
# 반복(step) : 4 , 손실함수(cost) : 0.125595
# 반복(step) : 4 , 손실함수(cost) : 0.122184
# 반복(step) : 4 , 손실함수(cost) : 0.124610
# 반복(step) : 4 , 손실함수(cost) : 0.122208
# 반복(step) : 4 , 손실함수(cost) : 0.122436
# 반복(step) : 4 , 손실함수(cost) : 0.120554
# 반복(step) : 4 , 손실함수(cost) : 0.121822
# 반복(step) : 4 , 손실함수(cost) : 0.121612
# 반복(step) : 4 , 손실함수(cost) : 0.123896
# 반복(step) : 4 , 손실함수(cost) : 0.121840
# 반복(step) : 4 , 손실함수(cost) : 0.120296
# 반복(step) : 4 , 손실함수(cost) : 0.122609
# 반복(step) : 4 , 손실함수(cost) : 0.122704
# 반복(step) : 4 , 손실함수(cost) : 0.123065
# 반복(step) : 4 , 손실함수(cost) : 0.123065
# 반복(step) : 4 , 손실함수(cost) : 0.124559
# 반복(step) : 4 , 손실함수(cost) : 0.124346
# 반복(step) : 4 , 손실함수(cost) : 0.121647
# 반복(step) : 4 , 손실함수(cost) : 0.119924
# 반복(step) : 4 , 손실함수(cost) : 0.118668
# 반복(step) : 4 , 손실함수(cost) : 0.121078
# 반복(step) : 4 , 손실함수(cost) : 0.121835
# 반복(step) : 4 , 손실함수(cost) : 0.120806
# 반복(step) : 4 , 손실함수(cost) : 0.120495
# 반복(step) : 4 , 손실함수(cost) : 0.118967
# 반복(step) : 4 , 손실함수(cost) : 0.123460
# 반복(step) : 4 , 손실함수(cost) : 0.125290
# 반복(step) : 4 , 손실함수(cost) : 0.120654
# 반복(step) : 4 , 손실함수(cost) : 0.118853
# 반복(step) : 4 , 손실함수(cost) : 0.121350
# 반복(step) : 4 , 손실함수(cost) : 0.119776
# 반복(step) : 4 , 손실함수(cost) : 0.121250
# 반복(step) : 4 , 손실함수(cost) : 0.120249
# 반복(step) : 4 , 손실함수(cost) : 0.120687
# 반복(step) : 4 , 손실함수(cost) : 0.118493
# 반복(step) : 4 , 손실함수(cost) : 0.123653
# 반복(step) : 4 , 손실함수(cost) : 0.122509
# 반복(step) : 4 , 손실함수(cost) : 0.127279
# 반복(step) : 4 , 손실함수(cost) : 0.122061
# 반복(step) : 4 , 손실함수(cost) : 0.118321
# 반복(step) : 4 , 손실함수(cost) : 0.120241
# 반복(step) : 4 , 손실함수(cost) : 0.123567
# 반복(step) : 4 , 손실함수(cost) : 0.122036
# 반복(step) : 4 , 손실함수(cost) : 0.123528
# 반복(step) : 4 , 손실함수(cost) : 0.121801
# 반복(step) : 4 , 손실함수(cost) : 0.121466
# 반복(step) : 4 , 손실함수(cost) : 0.122474
# 반복(step) : 4 , 손실함수(cost) : 0.124480
# 반복(step) : 4 , 손실함수(cost) : 0.120884
# 반복(step) : 4 , 손실함수(cost) : 0.119157
# 반복(step) : 4 , 손실함수(cost) : 0.118745
# 반복(step) : 4 , 손실함수(cost) : 0.118483
# 반복(step) : 4 , 손실함수(cost) : 0.118267
# 반복(step) : 4 , 손실함수(cost) : 0.120767
# 반복(step) : 4 , 손실함수(cost) : 0.120686
# 반복(step) : 4 , 손실함수(cost) : 0.120963
# 반복(step) : 4 , 손실함수(cost) : 0.118789
# 반복(step) : 4 , 손실함수(cost) : 0.118717
# 반복(step) : 4 , 손실함수(cost) : 0.118484
# 반복(step) : 4 , 손실함수(cost) : 0.118667
# 반복(step) : 4 , 손실함수(cost) : 0.119048
# 반복(step) : 4 , 손실함수(cost) : 0.121298
# 반복(step) : 4 , 손실함수(cost) : 0.120844
# 반복(step) : 4 , 손실함수(cost) : 0.119356
# 반복(step) : 4 , 손실함수(cost) : 0.117850
# 반복(step) : 4 , 손실함수(cost) : 0.120217
# 반복(step) : 4 , 손실함수(cost) : 0.117310
# 반복(step) : 4 , 손실함수(cost) : 0.118562
# 반복(step) : 4 , 손실함수(cost) : 0.120368
# 반복(step) : 4 , 손실함수(cost) : 0.121117
# 반복(step) : 4 , 손실함수(cost) : 0.120460
# 반복(step) : 4 , 손실함수(cost) : 0.120693
# 반복(step) : 4 , 손실함수(cost) : 0.118772
# 반복(step) : 4 , 손실함수(cost) : 0.116556
# 반복(step) : 4 , 손실함수(cost) : 0.116244
# 반복(step) : 4 , 손실함수(cost) : 0.117798
# 반복(step) : 4 , 손실함수(cost) : 0.116596
# 반복(step) : 4 , 손실함수(cost) : 0.119727
# 반복(step) : 4 , 손실함수(cost) : 0.119561
# 반복(step) : 4 , 손실함수(cost) : 0.116285
# 반복(step) : 4 , 손실함수(cost) : 0.115747
# 반복(step) : 4 , 손실함수(cost) : 0.116725
# 반복(step) : 4 , 손실함수(cost) : 0.116478
# 반복(step) : 4 , 손실함수(cost) : 0.115261
# 반복(step) : 4 , 손실함수(cost) : 0.116630
# 반복(step) : 4 , 손실함수(cost) : 0.118585
# 반복(step) : 4 , 손실함수(cost) : 0.117944
# 반복(step) : 4 , 손실함수(cost) : 0.117794
# 반복(step) : 4 , 손실함수(cost) : 0.115290
# 반복(step) : 4 , 손실함수(cost) : 0.117145
# 반복(step) : 4 , 손실함수(cost) : 0.116785
# 반복(step) : 4 , 손실함수(cost) : 0.119430
# 반복(step) : 4 , 손실함수(cost) : 0.114213
# 반복(step) : 4 , 손실함수(cost) : 0.118107
# 반복(step) : 4 , 손실함수(cost) : 0.115927
# 반복(step) : 4 , 손실함수(cost) : 0.115772
# 반복(step) : 4 , 손실함수(cost) : 0.118716
# 반복(step) : 4 , 손실함수(cost) : 0.120385
# 반복(step) : 4 , 손실함수(cost) : 0.118572
# 반복(step) : 4 , 손실함수(cost) : 0.118438
# 반복(step) : 4 , 손실함수(cost) : 0.118555
# 반복(step) : 4 , 손실함수(cost) : 0.118012
# 반복(step) : 4 , 손실함수(cost) : 0.117565
# 반복(step) : 4 , 손실함수(cost) : 0.117727
# 반복(step) : 4 , 손실함수(cost) : 0.117975
# 반복(step) : 4 , 손실함수(cost) : 0.117297
# 반복(step) : 4 , 손실함수(cost) : 0.115040
# 반복(step) : 4 , 손실함수(cost) : 0.117867
# 반복(step) : 4 , 손실함수(cost) : 0.117962
# 반복(step) : 4 , 손실함수(cost) : 0.118152
# 반복(step) : 4 , 손실함수(cost) : 0.118183
# 반복(step) : 4 , 손실함수(cost) : 0.115553
# 반복(step) : 4 , 손실함수(cost) : 0.115424
# 반복(step) : 4 , 손실함수(cost) : 0.114673
# 반복(step) : 4 , 손실함수(cost) : 0.115123
# 반복(step) : 4 , 손실함수(cost) : 0.118284
# 반복(step) : 4 , 손실함수(cost) : 0.118282
# 반복(step) : 4 , 손실함수(cost) : 0.120450
# 반복(step) : 4 , 손실함수(cost) : 0.117545
# 반복(step) : 4 , 손실함수(cost) : 0.117759
# 반복(step) : 4 , 손실함수(cost) : 0.114600
# 반복(step) : 4 , 손실함수(cost) : 0.115931
# 반복(step) : 4 , 손실함수(cost) : 0.116926
# 반복(step) : 4 , 손실함수(cost) : 0.116318
# 반복(step) : 4 , 손실함수(cost) : 0.118525
# 반복(step) : 4 , 손실함수(cost) : 0.120812
# 반복(step) : 4 , 손실함수(cost) : 0.118683
# 반복(step) : 4 , 손실함수(cost) : 0.116297
# 반복(step) : 4 , 손실함수(cost) : 0.119935
# 반복(step) : 4 , 손실함수(cost) : 0.117431
# 반복(step) : 4 , 손실함수(cost) : 0.117661
# 반복(step) : 4 , 손실함수(cost) : 0.115156
# 반복(step) : 4 , 손실함수(cost) : 0.116212
# 반복(step) : 4 , 손실함수(cost) : 0.116180
# 반복(step) : 4 , 손실함수(cost) : 0.116677
# 반복(step) : 4 , 손실함수(cost) : 0.118814
# 반복(step) : 4 , 손실함수(cost) : 0.119291
# 반복(step) : 4 , 손실함수(cost) : 0.116157
# 반복(step) : 4 , 손실함수(cost) : 0.116964
# 반복(step) : 4 , 손실함수(cost) : 0.114853
# 반복(step) : 4 , 손실함수(cost) : 0.116532
# 반복(step) : 4 , 손실함수(cost) : 0.116542
# 반복(step) : 4 , 손실함수(cost) : 0.115910
# 반복(step) : 4 , 손실함수(cost) : 0.114728
# 반복(step) : 4 , 손실함수(cost) : 0.116842
# 반복(step) : 4 , 손실함수(cost) : 0.114013
# 반복(step) : 4 , 손실함수(cost) : 0.115284
# 반복(step) : 4 , 손실함수(cost) : 0.115389
# 반복(step) : 4 , 손실함수(cost) : 0.116443
# 반복(step) : 4 , 손실함수(cost) : 0.116451
# 반복(step) : 4 , 손실함수(cost) : 0.117176
# 반복(step) : 4 , 손실함수(cost) : 0.115451
# 반복(step) : 4 , 손실함수(cost) : 0.115371
# 반복(step) : 4 , 손실함수(cost) : 0.118061
# 반복(step) : 4 , 손실함수(cost) : 0.115774
# 반복(step) : 4 , 손실함수(cost) : 0.118342
# 반복(step) : 4 , 손실함수(cost) : 0.111966
# 반복(step) : 4 , 손실함수(cost) : 0.115544
# 반복(step) : 4 , 손실함수(cost) : 0.115484
# 반복(step) : 4 , 손실함수(cost) : 0.118173
# 반복(step) : 4 , 손실함수(cost) : 0.114327
# 반복(step) : 4 , 손실함수(cost) : 0.115980
# 반복(step) : 4 , 손실함수(cost) : 0.115667
# 반복(step) : 4 , 손실함수(cost) : 0.117242
# 반복(step) : 4 , 손실함수(cost) : 0.117430
# 반복(step) : 4 , 손실함수(cost) : 0.115204
# 반복(step) : 4 , 손실함수(cost) : 0.116903
# 반복(step) : 4 , 손실함수(cost) : 0.115051
# 반복(step) : 4 , 손실함수(cost) : 0.113887
# 반복(step) : 4 , 손실함수(cost) : 0.112513
# 반복(step) : 4 , 손실함수(cost) : 0.113766
# 반복(step) : 4 , 손실함수(cost) : 0.114406
# 반복(step) : 4 , 손실함수(cost) : 0.114101
# 반복(step) : 4 , 손실함수(cost) : 0.117264
# 반복(step) : 4 , 손실함수(cost) : 0.114426
# 반복(step) : 4 , 손실함수(cost) : 0.116666
# 반복(step) : 4 , 손실함수(cost) : 0.114818
# 반복(step) : 4 , 손실함수(cost) : 0.117480
# 반복(step) : 4 , 손실함수(cost) : 0.117395
# 반복(step) : 4 , 손실함수(cost) : 0.113390
# 반복(step) : 4 , 손실함수(cost) : 0.113569
# 반복(step) : 4 , 손실함수(cost) : 0.113722
# 반복(step) : 4 , 손실함수(cost) : 0.115082
# 반복(step) : 4 , 손실함수(cost) : 0.115139
# 반복(step) : 4 , 손실함수(cost) : 0.114429
# 반복(step) : 4 , 손실함수(cost) : 0.112972
# 반복(step) : 4 , 손실함수(cost) : 0.115352
# 반복(step) : 4 , 손실함수(cost) : 0.111763
# 반복(step) : 4 , 손실함수(cost) : 0.115116
# 반복(step) : 4 , 손실함수(cost) : 0.113704
# 반복(step) : 4 , 손실함수(cost) : 0.114172
# 반복(step) : 4 , 손실함수(cost) : 0.116537
# 반복(step) : 4 , 손실함수(cost) : 0.111361
# 반복(step) : 4 , 손실함수(cost) : 0.113157
# 반복(step) : 4 , 손실함수(cost) : 0.113838
# 반복(step) : 4 , 손실함수(cost) : 0.113452
# 반복(step) : 4 , 손실함수(cost) : 0.111670
# 반복(step) : 4 , 손실함수(cost) : 0.111599
# 반복(step) : 4 , 손실함수(cost) : 0.115222
# 반복(step) : 4 , 손실함수(cost) : 0.115385
# 반복(step) : 4 , 손실함수(cost) : 0.115276
# 반복(step) : 4 , 손실함수(cost) : 0.113395
# 반복(step) : 5 , 손실함수(cost) : 0.114341
# 반복(step) : 5 , 손실함수(cost) : 0.112536
# 반복(step) : 5 , 손실함수(cost) : 0.115878
# 반복(step) : 5 , 손실함수(cost) : 0.115629
# 반복(step) : 5 , 손실함수(cost) : 0.115708
# 반복(step) : 5 , 손실함수(cost) : 0.113267
# 반복(step) : 5 , 손실함수(cost) : 0.114728
# 반복(step) : 5 , 손실함수(cost) : 0.113850
# 반복(step) : 5 , 손실함수(cost) : 0.113499
# 반복(step) : 5 , 손실함수(cost) : 0.114172
# 반복(step) : 5 , 손실함수(cost) : 0.113953
# 반복(step) : 5 , 손실함수(cost) : 0.116685
# 반복(step) : 5 , 손실함수(cost) : 0.114500
# 반복(step) : 5 , 손실함수(cost) : 0.113073
# 반복(step) : 5 , 손실함수(cost) : 0.113060
# 반복(step) : 5 , 손실함수(cost) : 0.112427
# 반복(step) : 5 , 손실함수(cost) : 0.111735
# 반복(step) : 5 , 손실함수(cost) : 0.113444
# 반복(step) : 5 , 손실함수(cost) : 0.114253
# 반복(step) : 5 , 손실함수(cost) : 0.113328
# 반복(step) : 5 , 손실함수(cost) : 0.112597
# 반복(step) : 5 , 손실함수(cost) : 0.111864
# 반복(step) : 5 , 손실함수(cost) : 0.113191
# 반복(step) : 5 , 손실함수(cost) : 0.114595
# 반복(step) : 5 , 손실함수(cost) : 0.115176
# 반복(step) : 5 , 손실함수(cost) : 0.111531
# 반복(step) : 5 , 손실함수(cost) : 0.111360
# 반복(step) : 5 , 손실함수(cost) : 0.111066
# 반복(step) : 5 , 손실함수(cost) : 0.113765
# 반복(step) : 5 , 손실함수(cost) : 0.113204
# 반복(step) : 5 , 손실함수(cost) : 0.110260
# 반복(step) : 5 , 손실함수(cost) : 0.112647
# 반복(step) : 5 , 손실함수(cost) : 0.111099
# 반복(step) : 5 , 손실함수(cost) : 0.112825
# 반복(step) : 5 , 손실함수(cost) : 0.111573
# 반복(step) : 5 , 손실함수(cost) : 0.114261
# 반복(step) : 5 , 손실함수(cost) : 0.117979
# 반복(step) : 5 , 손실함수(cost) : 0.114508
# 반복(step) : 5 , 손실함수(cost) : 0.113448
# 반복(step) : 5 , 손실함수(cost) : 0.114313
# 반복(step) : 5 , 손실함수(cost) : 0.113241
# 반복(step) : 5 , 손실함수(cost) : 0.112306
# 반복(step) : 5 , 손실함수(cost) : 0.109824
# 반복(step) : 5 , 손실함수(cost) : 0.110206
# 반복(step) : 5 , 손실함수(cost) : 0.110170
# 반복(step) : 5 , 손실함수(cost) : 0.111413
# 반복(step) : 5 , 손실함수(cost) : 0.114717
# 반복(step) : 5 , 손실함수(cost) : 0.113646
# 반복(step) : 5 , 손실함수(cost) : 0.113732
# 반복(step) : 5 , 손실함수(cost) : 0.111887
# 반복(step) : 5 , 손실함수(cost) : 0.113011
# 반복(step) : 5 , 손실함수(cost) : 0.115802
# 반복(step) : 5 , 손실함수(cost) : 0.115807
# 반복(step) : 5 , 손실함수(cost) : 0.111805
# 반복(step) : 5 , 손실함수(cost) : 0.111723
# 반복(step) : 5 , 손실함수(cost) : 0.112553
# 반복(step) : 5 , 손실함수(cost) : 0.110922
# 반복(step) : 5 , 손실함수(cost) : 0.113322
# 반복(step) : 5 , 손실함수(cost) : 0.111154
# 반복(step) : 5 , 손실함수(cost) : 0.111337
# 반복(step) : 5 , 손실함수(cost) : 0.110966
# 반복(step) : 5 , 손실함수(cost) : 0.112158
# 반복(step) : 5 , 손실함수(cost) : 0.113190
# 반복(step) : 5 , 손실함수(cost) : 0.114814
# 반복(step) : 5 , 손실함수(cost) : 0.115899
# 반복(step) : 5 , 손실함수(cost) : 0.111927
# 반복(step) : 5 , 손실함수(cost) : 0.110751
# 반복(step) : 5 , 손실함수(cost) : 0.110656
# 반복(step) : 5 , 손실함수(cost) : 0.111087
# 반복(step) : 5 , 손실함수(cost) : 0.110741
# 반복(step) : 5 , 손실함수(cost) : 0.110204
# 반복(step) : 5 , 손실함수(cost) : 0.108902
# 반복(step) : 5 , 손실함수(cost) : 0.110105
# 반복(step) : 5 , 손실함수(cost) : 0.112922
# 반복(step) : 5 , 손실함수(cost) : 0.110668
# 반복(step) : 5 , 손실함수(cost) : 0.110673
# 반복(step) : 5 , 손실함수(cost) : 0.110246
# 반복(step) : 5 , 손실함수(cost) : 0.114238
# 반복(step) : 5 , 손실함수(cost) : 0.111932
# 반복(step) : 5 , 손실함수(cost) : 0.109066
# 반복(step) : 5 , 손실함수(cost) : 0.111478
# 반복(step) : 5 , 손실함수(cost) : 0.112945
# 반복(step) : 5 , 손실함수(cost) : 0.114812
# 반복(step) : 5 , 손실함수(cost) : 0.113989
# 반복(step) : 5 , 손실함수(cost) : 0.110961
# 반복(step) : 5 , 손실함수(cost) : 0.111178
# 반복(step) : 5 , 손실함수(cost) : 0.111224
# 반복(step) : 5 , 손실함수(cost) : 0.111473
# 반복(step) : 5 , 손실함수(cost) : 0.109153
# 반복(step) : 5 , 손실함수(cost) : 0.110929
# 반복(step) : 5 , 손실함수(cost) : 0.109135
# 반복(step) : 5 , 손실함수(cost) : 0.110112
# 반복(step) : 5 , 손실함수(cost) : 0.111946
# 반복(step) : 5 , 손실함수(cost) : 0.112783
# 반복(step) : 5 , 손실함수(cost) : 0.110388
# 반복(step) : 5 , 손실함수(cost) : 0.111450
# 반복(step) : 5 , 손실함수(cost) : 0.109515
# 반복(step) : 5 , 손실함수(cost) : 0.111259
# 반복(step) : 5 , 손실함수(cost) : 0.112455
# 반복(step) : 5 , 손실함수(cost) : 0.112430
# 반복(step) : 5 , 손실함수(cost) : 0.111430
# 반복(step) : 5 , 손실함수(cost) : 0.115661
# 반복(step) : 5 , 손실함수(cost) : 0.111216
# 반복(step) : 5 , 손실함수(cost) : 0.112326
# 반복(step) : 5 , 손실함수(cost) : 0.111162
# 반복(step) : 5 , 손실함수(cost) : 0.110786
# 반복(step) : 5 , 손실함수(cost) : 0.111653
# 반복(step) : 5 , 손실함수(cost) : 0.111335
# 반복(step) : 5 , 손실함수(cost) : 0.110959
# 반복(step) : 5 , 손실함수(cost) : 0.111188
# 반복(step) : 5 , 손실함수(cost) : 0.112984
# 반복(step) : 5 , 손실함수(cost) : 0.110824
# 반복(step) : 5 , 손실함수(cost) : 0.108248
# 반복(step) : 5 , 손실함수(cost) : 0.107507
# 반복(step) : 5 , 손실함수(cost) : 0.109144
# 반복(step) : 5 , 손실함수(cost) : 0.108753
# 반복(step) : 5 , 손실함수(cost) : 0.109172
# 반복(step) : 5 , 손실함수(cost) : 0.108786
# 반복(step) : 5 , 손실함수(cost) : 0.110173
# 반복(step) : 5 , 손실함수(cost) : 0.110399
# 반복(step) : 5 , 손실함수(cost) : 0.108324
# 반복(step) : 5 , 손실함수(cost) : 0.109558
# 반복(step) : 5 , 손실함수(cost) : 0.108599
# 반복(step) : 5 , 손실함수(cost) : 0.110517
# 반복(step) : 5 , 손실함수(cost) : 0.110019
# 반복(step) : 5 , 손실함수(cost) : 0.111904
# 반복(step) : 5 , 손실함수(cost) : 0.109707
# 반복(step) : 5 , 손실함수(cost) : 0.108957
# 반복(step) : 5 , 손실함수(cost) : 0.109857
# 반복(step) : 5 , 손실함수(cost) : 0.110255
# 반복(step) : 5 , 손실함수(cost) : 0.108547
# 반복(step) : 5 , 손실함수(cost) : 0.108563
# 반복(step) : 5 , 손실함수(cost) : 0.111880
# 반복(step) : 5 , 손실함수(cost) : 0.110004
# 반복(step) : 5 , 손실함수(cost) : 0.111721
# 반복(step) : 5 , 손실함수(cost) : 0.110892
# 반복(step) : 5 , 손실함수(cost) : 0.109422
# 반복(step) : 5 , 손실함수(cost) : 0.108666
# 반복(step) : 5 , 손실함수(cost) : 0.109977
# 반복(step) : 5 , 손실함수(cost) : 0.108802
# 반복(step) : 5 , 손실함수(cost) : 0.110583
# 반복(step) : 5 , 손실함수(cost) : 0.111775
# 반복(step) : 5 , 손실함수(cost) : 0.112106
# 반복(step) : 5 , 손실함수(cost) : 0.108809
# 반복(step) : 5 , 손실함수(cost) : 0.110592
# 반복(step) : 5 , 손실함수(cost) : 0.110425
# 반복(step) : 5 , 손실함수(cost) : 0.111087
# 반복(step) : 5 , 손실함수(cost) : 0.108824
# 반복(step) : 5 , 손실함수(cost) : 0.107922
# 반복(step) : 5 , 손실함수(cost) : 0.109200
# 반복(step) : 5 , 손실함수(cost) : 0.109100
# 반복(step) : 5 , 손실함수(cost) : 0.106364
# 반복(step) : 5 , 손실함수(cost) : 0.107249
# 반복(step) : 5 , 손실함수(cost) : 0.109057
# 반복(step) : 5 , 손실함수(cost) : 0.107513
# 반복(step) : 5 , 손실함수(cost) : 0.107900
# 반복(step) : 5 , 손실함수(cost) : 0.110028
# 반복(step) : 5 , 손실함수(cost) : 0.109274
# 반복(step) : 5 , 손실함수(cost) : 0.105794
# 반복(step) : 5 , 손실함수(cost) : 0.105328
# 반복(step) : 5 , 손실함수(cost) : 0.105839
# 반복(step) : 5 , 손실함수(cost) : 0.105908
# 반복(step) : 5 , 손실함수(cost) : 0.106012
# 반복(step) : 5 , 손실함수(cost) : 0.107656
# 반복(step) : 5 , 손실함수(cost) : 0.109054
# 반복(step) : 5 , 손실함수(cost) : 0.109853
# 반복(step) : 5 , 손실함수(cost) : 0.108603
# 반복(step) : 5 , 손실함수(cost) : 0.108237
# 반복(step) : 5 , 손실함수(cost) : 0.109691
# 반복(step) : 5 , 손실함수(cost) : 0.106611
# 반복(step) : 5 , 손실함수(cost) : 0.108043
# 반복(step) : 5 , 손실함수(cost) : 0.107121
# 반복(step) : 5 , 손실함수(cost) : 0.110781
# 반복(step) : 5 , 손실함수(cost) : 0.108515
# 반복(step) : 5 , 손실함수(cost) : 0.108613
# 반복(step) : 5 , 손실함수(cost) : 0.106678
# 반복(step) : 5 , 손실함수(cost) : 0.105209
# 반복(step) : 5 , 손실함수(cost) : 0.108636
# 반복(step) : 5 , 손실함수(cost) : 0.105886
# 반복(step) : 5 , 손실함수(cost) : 0.109454
# 반복(step) : 5 , 손실함수(cost) : 0.106953
# 반복(step) : 5 , 손실함수(cost) : 0.107621
# 반복(step) : 5 , 손실함수(cost) : 0.107241
# 반복(step) : 5 , 손실함수(cost) : 0.107425
# 반복(step) : 5 , 손실함수(cost) : 0.106670
# 반복(step) : 5 , 손실함수(cost) : 0.109128
# 반복(step) : 5 , 손실함수(cost) : 0.108534
# 반복(step) : 5 , 손실함수(cost) : 0.108939
# 반복(step) : 5 , 손실함수(cost) : 0.107132
# 반복(step) : 5 , 손실함수(cost) : 0.107206
# 반복(step) : 5 , 손실함수(cost) : 0.102763
# 반복(step) : 5 , 손실함수(cost) : 0.103618
# 반복(step) : 5 , 손실함수(cost) : 0.102191
# 반복(step) : 5 , 손실함수(cost) : 0.104085
# 반복(step) : 5 , 손실함수(cost) : 0.105550
# 반복(step) : 5 , 손실함수(cost) : 0.105030
# 반복(step) : 5 , 손실함수(cost) : 0.105438
# 반복(step) : 5 , 손실함수(cost) : 0.105576
# 반복(step) : 5 , 손실함수(cost) : 0.103479
# 반복(step) : 5 , 손실함수(cost) : 0.106614
# 반복(step) : 5 , 손실함수(cost) : 0.107557
# 반복(step) : 5 , 손실함수(cost) : 0.103276
# 반복(step) : 5 , 손실함수(cost) : 0.105634
# 반복(step) : 5 , 손실함수(cost) : 0.104765
# 반복(step) : 5 , 손실함수(cost) : 0.107002
# 반복(step) : 5 , 손실함수(cost) : 0.106858
# 반복(step) : 5 , 손실함수(cost) : 0.108558
# 반복(step) : 5 , 손실함수(cost) : 0.107771
# 반복(step) : 5 , 손실함수(cost) : 0.107450
# 반복(step) : 5 , 손실함수(cost) : 0.108511
# 반복(step) : 5 , 손실함수(cost) : 0.108566
# 반복(step) : 5 , 손실함수(cost) : 0.108167
# 반복(step) : 5 , 손실함수(cost) : 0.106077
# 반복(step) : 5 , 손실함수(cost) : 0.105029
# 반복(step) : 6 , 손실함수(cost) : 0.105443
# 반복(step) : 6 , 손실함수(cost) : 0.106325
# 반복(step) : 6 , 손실함수(cost) : 0.104713
# 반복(step) : 6 , 손실함수(cost) : 0.102792
# 반복(step) : 6 , 손실함수(cost) : 0.103793
# 반복(step) : 6 , 손실함수(cost) : 0.102795
# 반복(step) : 6 , 손실함수(cost) : 0.103920
# 반복(step) : 6 , 손실함수(cost) : 0.107707
# 반복(step) : 6 , 손실함수(cost) : 0.110422
# 반복(step) : 6 , 손실함수(cost) : 0.105326
# 반복(step) : 6 , 손실함수(cost) : 0.104840
# 반복(step) : 6 , 손실함수(cost) : 0.101410
# 반복(step) : 6 , 손실함수(cost) : 0.104642
# 반복(step) : 6 , 손실함수(cost) : 0.102745
# 반복(step) : 6 , 손실함수(cost) : 0.104583
# 반복(step) : 6 , 손실함수(cost) : 0.107147
# 반복(step) : 6 , 손실함수(cost) : 0.107027
# 반복(step) : 6 , 손실함수(cost) : 0.106537
# 반복(step) : 6 , 손실함수(cost) : 0.101769
# 반복(step) : 6 , 손실함수(cost) : 0.104307
# 반복(step) : 6 , 손실함수(cost) : 0.106724
# 반복(step) : 6 , 손실함수(cost) : 0.110938
# 반복(step) : 6 , 손실함수(cost) : 0.105891
# 반복(step) : 6 , 손실함수(cost) : 0.104656
# 반복(step) : 6 , 손실함수(cost) : 0.103178
# 반복(step) : 6 , 손실함수(cost) : 0.104831
# 반복(step) : 6 , 손실함수(cost) : 0.106143
# 반복(step) : 6 , 손실함수(cost) : 0.106636
# 반복(step) : 6 , 손실함수(cost) : 0.105792
# 반복(step) : 6 , 손실함수(cost) : 0.105573
# 반복(step) : 6 , 손실함수(cost) : 0.103837
# 반복(step) : 6 , 손실함수(cost) : 0.104601
# 반복(step) : 6 , 손실함수(cost) : 0.105345
# 반복(step) : 6 , 손실함수(cost) : 0.105945
# 반복(step) : 6 , 손실함수(cost) : 0.103176
# 반복(step) : 6 , 손실함수(cost) : 0.103119
# 반복(step) : 6 , 손실함수(cost) : 0.105729
# 반복(step) : 6 , 손실함수(cost) : 0.107074
# 반복(step) : 6 , 손실함수(cost) : 0.104428
# 반복(step) : 6 , 손실함수(cost) : 0.104641
# 반복(step) : 6 , 손실함수(cost) : 0.104555
# 반복(step) : 6 , 손실함수(cost) : 0.104246
# 반복(step) : 6 , 손실함수(cost) : 0.105408
# 반복(step) : 6 , 손실함수(cost) : 0.105909
# 반복(step) : 6 , 손실함수(cost) : 0.105895
# 반복(step) : 6 , 손실함수(cost) : 0.105505
# 반복(step) : 6 , 손실함수(cost) : 0.105587
# 반복(step) : 6 , 손실함수(cost) : 0.105122
# 반복(step) : 6 , 손실함수(cost) : 0.104810
# 반복(step) : 6 , 손실함수(cost) : 0.105816
# 반복(step) : 6 , 손실함수(cost) : 0.103814
# 반복(step) : 6 , 손실함수(cost) : 0.103950
# 반복(step) : 6 , 손실함수(cost) : 0.105131
# 반복(step) : 6 , 손실함수(cost) : 0.102699
# 반복(step) : 6 , 손실함수(cost) : 0.105831
# 반복(step) : 6 , 손실함수(cost) : 0.105663
# 반복(step) : 6 , 손실함수(cost) : 0.105435
# 반복(step) : 6 , 손실함수(cost) : 0.103368
# 반복(step) : 6 , 손실함수(cost) : 0.106045
# 반복(step) : 6 , 손실함수(cost) : 0.106295
# 반복(step) : 6 , 손실함수(cost) : 0.105892
# 반복(step) : 6 , 손실함수(cost) : 0.106757
# 반복(step) : 6 , 손실함수(cost) : 0.106665
# 반복(step) : 6 , 손실함수(cost) : 0.110101
# 반복(step) : 6 , 손실함수(cost) : 0.107151
# 반복(step) : 6 , 손실함수(cost) : 0.104939
# 반복(step) : 6 , 손실함수(cost) : 0.105119
# 반복(step) : 6 , 손실함수(cost) : 0.105157
# 반복(step) : 6 , 손실함수(cost) : 0.104107
# 반복(step) : 6 , 손실함수(cost) : 0.104595
# 반복(step) : 6 , 손실함수(cost) : 0.103818
# 반복(step) : 6 , 손실함수(cost) : 0.104517
# 반복(step) : 6 , 손실함수(cost) : 0.103670
# 반복(step) : 6 , 손실함수(cost) : 0.106246
# 반복(step) : 6 , 손실함수(cost) : 0.103277
# 반복(step) : 6 , 손실함수(cost) : 0.101022
# 반복(step) : 6 , 손실함수(cost) : 0.103321
# 반복(step) : 6 , 손실함수(cost) : 0.103974
# 반복(step) : 6 , 손실함수(cost) : 0.101430
# 반복(step) : 6 , 손실함수(cost) : 0.105571
# 반복(step) : 6 , 손실함수(cost) : 0.104858
# 반복(step) : 6 , 손실함수(cost) : 0.101679
# 반복(step) : 6 , 손실함수(cost) : 0.103279
# 반복(step) : 6 , 손실함수(cost) : 0.104567
# 반복(step) : 6 , 손실함수(cost) : 0.104091
# 반복(step) : 6 , 손실함수(cost) : 0.104174
# 반복(step) : 6 , 손실함수(cost) : 0.103852
# 반복(step) : 6 , 손실함수(cost) : 0.106667
# 반복(step) : 6 , 손실함수(cost) : 0.103897
# 반복(step) : 6 , 손실함수(cost) : 0.105875
# 반복(step) : 6 , 손실함수(cost) : 0.105389
# 반복(step) : 6 , 손실함수(cost) : 0.107375
# 반복(step) : 6 , 손실함수(cost) : 0.106823
# 반복(step) : 6 , 손실함수(cost) : 0.105084
# 반복(step) : 6 , 손실함수(cost) : 0.103762
# 반복(step) : 6 , 손실함수(cost) : 0.103795
# 반복(step) : 6 , 손실함수(cost) : 0.103411
# 반복(step) : 6 , 손실함수(cost) : 0.106885
# 반복(step) : 6 , 손실함수(cost) : 0.104397
# 반복(step) : 6 , 손실함수(cost) : 0.103757
# 반복(step) : 6 , 손실함수(cost) : 0.102094
# 반복(step) : 6 , 손실함수(cost) : 0.102441
# 반복(step) : 6 , 손실함수(cost) : 0.102404
# 반복(step) : 6 , 손실함수(cost) : 0.103894
# 반복(step) : 6 , 손실함수(cost) : 0.104242
# 반복(step) : 6 , 손실함수(cost) : 0.102609
# 반복(step) : 6 , 손실함수(cost) : 0.103522
# 반복(step) : 6 , 손실함수(cost) : 0.106446
# 반복(step) : 6 , 손실함수(cost) : 0.107673
# 반복(step) : 6 , 손실함수(cost) : 0.107585
# 반복(step) : 6 , 손실함수(cost) : 0.104046
# 반복(step) : 6 , 손실함수(cost) : 0.104793
# 반복(step) : 6 , 손실함수(cost) : 0.102507
# 반복(step) : 6 , 손실함수(cost) : 0.102909
# 반복(step) : 6 , 손실함수(cost) : 0.101308
# 반복(step) : 6 , 손실함수(cost) : 0.103917
# 반복(step) : 6 , 손실함수(cost) : 0.103197
# 반복(step) : 6 , 손실함수(cost) : 0.104833
# 반복(step) : 6 , 손실함수(cost) : 0.105851
# 반복(step) : 6 , 손실함수(cost) : 0.104347
# 반복(step) : 6 , 손실함수(cost) : 0.102993
# 반복(step) : 6 , 손실함수(cost) : 0.103500
# 반복(step) : 6 , 손실함수(cost) : 0.104375
# 반복(step) : 6 , 손실함수(cost) : 0.102815
# 반복(step) : 6 , 손실함수(cost) : 0.103711
# 반복(step) : 6 , 손실함수(cost) : 0.102584
# 반복(step) : 6 , 손실함수(cost) : 0.102464
# 반복(step) : 6 , 손실함수(cost) : 0.103656
# 반복(step) : 6 , 손실함수(cost) : 0.100859
# 반복(step) : 6 , 손실함수(cost) : 0.104712
# 반복(step) : 6 , 손실함수(cost) : 0.105635
# 반복(step) : 6 , 손실함수(cost) : 0.104506
# 반복(step) : 6 , 손실함수(cost) : 0.103341
# 반복(step) : 6 , 손실함수(cost) : 0.100204
# 반복(step) : 6 , 손실함수(cost) : 0.101605
# 반복(step) : 6 , 손실함수(cost) : 0.104142
# 반복(step) : 6 , 손실함수(cost) : 0.103172
# 반복(step) : 6 , 손실함수(cost) : 0.103579
# 반복(step) : 6 , 손실함수(cost) : 0.102687
# 반복(step) : 6 , 손실함수(cost) : 0.103208
# 반복(step) : 6 , 손실함수(cost) : 0.103352
# 반복(step) : 6 , 손실함수(cost) : 0.102986
# 반복(step) : 6 , 손실함수(cost) : 0.105134
# 반복(step) : 6 , 손실함수(cost) : 0.104963
# 반복(step) : 6 , 손실함수(cost) : 0.101915
# 반복(step) : 6 , 손실함수(cost) : 0.101895
# 반복(step) : 6 , 손실함수(cost) : 0.100220
# 반복(step) : 6 , 손실함수(cost) : 0.100940
# 반복(step) : 6 , 손실함수(cost) : 0.101335
# 반복(step) : 6 , 손실함수(cost) : 0.104200
# 반복(step) : 6 , 손실함수(cost) : 0.101478
# 반복(step) : 6 , 손실함수(cost) : 0.101402
# 반복(step) : 6 , 손실함수(cost) : 0.102652
# 반복(step) : 6 , 손실함수(cost) : 0.101853
# 반복(step) : 6 , 손실함수(cost) : 0.101122
# 반복(step) : 6 , 손실함수(cost) : 0.103148
# 반복(step) : 6 , 손실함수(cost) : 0.101639
# 반복(step) : 6 , 손실함수(cost) : 0.105330
# 반복(step) : 6 , 손실함수(cost) : 0.104653
# 반복(step) : 6 , 손실함수(cost) : 0.103659
# 반복(step) : 6 , 손실함수(cost) : 0.102357
# 반복(step) : 6 , 손실함수(cost) : 0.103630
# 반복(step) : 6 , 손실함수(cost) : 0.102739
# 반복(step) : 6 , 손실함수(cost) : 0.104689
# 반복(step) : 6 , 손실함수(cost) : 0.104613
# 반복(step) : 6 , 손실함수(cost) : 0.101498
# 반복(step) : 6 , 손실함수(cost) : 0.101762
# 반복(step) : 6 , 손실함수(cost) : 0.102687
# 반복(step) : 6 , 손실함수(cost) : 0.102571
# 반복(step) : 6 , 손실함수(cost) : 0.102793
# 반복(step) : 6 , 손실함수(cost) : 0.104102
# 반복(step) : 6 , 손실함수(cost) : 0.101692
# 반복(step) : 6 , 손실함수(cost) : 0.100599
# 반복(step) : 6 , 손실함수(cost) : 0.099898
# 반복(step) : 6 , 손실함수(cost) : 0.101975
# 반복(step) : 6 , 손실함수(cost) : 0.104732
# 반복(step) : 6 , 손실함수(cost) : 0.102137
# 반복(step) : 6 , 손실함수(cost) : 0.104739
# 반복(step) : 6 , 손실함수(cost) : 0.103235
# 반복(step) : 6 , 손실함수(cost) : 0.105223
# 반복(step) : 6 , 손실함수(cost) : 0.100321
# 반복(step) : 6 , 손실함수(cost) : 0.102486
# 반복(step) : 6 , 손실함수(cost) : 0.102499
# 반복(step) : 6 , 손실함수(cost) : 0.103309
# 반복(step) : 6 , 손실함수(cost) : 0.102041
# 반복(step) : 6 , 손실함수(cost) : 0.101411
# 반복(step) : 6 , 손실함수(cost) : 0.102163
# 반복(step) : 6 , 손실함수(cost) : 0.103178
# 반복(step) : 6 , 손실함수(cost) : 0.101508
# 반복(step) : 6 , 손실함수(cost) : 0.105866
# 반복(step) : 6 , 손실함수(cost) : 0.103578
# 반복(step) : 6 , 손실함수(cost) : 0.102091
# 반복(step) : 6 , 손실함수(cost) : 0.099512
# 반복(step) : 6 , 손실함수(cost) : 0.100498
# 반복(step) : 6 , 손실함수(cost) : 0.103003
# 반복(step) : 6 , 손실함수(cost) : 0.101099
# 반복(step) : 6 , 손실함수(cost) : 0.102317
# 반복(step) : 6 , 손실함수(cost) : 0.106239
# 반복(step) : 6 , 손실함수(cost) : 0.107548
# 반복(step) : 6 , 손실함수(cost) : 0.103880
# 반복(step) : 6 , 손실함수(cost) : 0.102478
# 반복(step) : 6 , 손실함수(cost) : 0.103229
# 반복(step) : 6 , 손실함수(cost) : 0.098680
# 반복(step) : 6 , 손실함수(cost) : 0.100231
# 반복(step) : 6 , 손실함수(cost) : 0.101260
# 반복(step) : 6 , 손실함수(cost) : 0.102618
# 반복(step) : 6 , 손실함수(cost) : 0.104051
# 반복(step) : 6 , 손실함수(cost) : 0.103236
# 반복(step) : 6 , 손실함수(cost) : 0.103793
# 반복(step) : 6 , 손실함수(cost) : 0.102013
# 반복(step) : 6 , 손실함수(cost) : 0.103255
# 반복(step) : 6 , 손실함수(cost) : 0.101478
# 반복(step) : 6 , 손실함수(cost) : 0.102980
# 반복(step) : 6 , 손실함수(cost) : 0.101999
# 반복(step) : 7 , 손실함수(cost) : 0.105805
# 반복(step) : 7 , 손실함수(cost) : 0.102869
# 반복(step) : 7 , 손실함수(cost) : 0.100707
# 반복(step) : 7 , 손실함수(cost) : 0.100452
# 반복(step) : 7 , 손실함수(cost) : 0.100715
# 반복(step) : 7 , 손실함수(cost) : 0.104055
# 반복(step) : 7 , 손실함수(cost) : 0.101394
# 반복(step) : 7 , 손실함수(cost) : 0.103142
# 반복(step) : 7 , 손실함수(cost) : 0.101861
# 반복(step) : 7 , 손실함수(cost) : 0.102169
# 반복(step) : 7 , 손실함수(cost) : 0.099980
# 반복(step) : 7 , 손실함수(cost) : 0.101507
# 반복(step) : 7 , 손실함수(cost) : 0.101430
# ...
# 반복(step) : 49 , 손실함수(cost) : 0.047681
# 반복(step) : 49 , 손실함수(cost) : 0.046922
# 반복(step) : 49 , 손실함수(cost) : 0.045559
# 반복(step) : 49 , 손실함수(cost) : 0.046896
# 반복(step) : 49 , 손실함수(cost) : 0.046425
# 반복(step) : 49 , 손실함수(cost) : 0.048068
# 반복(step) : 49 , 손실함수(cost) : 0.049381
# 반복(step) : 49 , 손실함수(cost) : 0.047349
# 반복(step) : 49 , 손실함수(cost) : 0.046361
# 반복(step) : 49 , 손실함수(cost) : 0.046145
# 반복(step) : 49 , 손실함수(cost) : 0.047959
# 반복(step) : 49 , 손실함수(cost) : 0.047106
# 반복(step) : 49 , 손실함수(cost) : 0.048199
# 반복(step) : 49 , 손실함수(cost) : 0.048337
# 반복(step) : 49 , 손실함수(cost) : 0.046430
# 반복(step) : 49 , 손실함수(cost) : 0.046234
# 반복(step) : 49 , 손실함수(cost) : 0.045766
# 반복(step) : 49 , 손실함수(cost) : 0.047426
# 반복(step) : 49 , 손실함수(cost) : 0.046378
# 반복(step) : 49 , 손실함수(cost) : 0.048561
# 반복(step) : 49 , 손실함수(cost) : 0.046691
# 반복(step) : 49 , 손실함수(cost) : 0.048440
# 반복(step) : 49 , 손실함수(cost) : 0.047470
# 반복(step) : 49 , 손실함수(cost) : 0.047339
# 반복(step) : 49 , 손실함수(cost) : 0.047784
# 반복(step) : 49 , 손실함수(cost) : 0.046979
# 반복(step) : 49 , 손실함수(cost) : 0.047919
# 반복(step) : 49 , 손실함수(cost) : 0.048295
# 반복(step) : 49 , 손실함수(cost) : 0.048060
# 반복(step) : 49 , 손실함수(cost) : 0.047185
# 반복(step) : 49 , 손실함수(cost) : 0.045542
# 반복(step) : 49 , 손실함수(cost) : 0.046131
# 반복(step) : 49 , 손실함수(cost) : 0.046480
# 반복(step) : 49 , 손실함수(cost) : 0.047207
# 반복(step) : 49 , 손실함수(cost) : 0.047807
# 반복(step) : 49 , 손실함수(cost) : 0.048639
# 반복(step) : 49 , 손실함수(cost) : 0.046871
# 반복(step) : 49 , 손실함수(cost) : 0.046641
# 반복(step) : 49 , 손실함수(cost) : 0.046702
# 반복(step) : 49 , 손실함수(cost) : 0.045913
# 반복(step) : 49 , 손실함수(cost) : 0.046727
# 반복(step) : 49 , 손실함수(cost) : 0.047406
# 반복(step) : 49 , 손실함수(cost) : 0.048143
# 반복(step) : 49 , 손실함수(cost) : 0.049603
# 반복(step) : 49 , 손실함수(cost) : 0.047203
# 반복(step) : 49 , 손실함수(cost) : 0.045978
# 반복(step) : 49 , 손실함수(cost) : 0.046782
# 반복(step) : 49 , 손실함수(cost) : 0.046365
# 반복(step) : 49 , 손실함수(cost) : 0.047084
# 반복(step) : 49 , 손실함수(cost) : 0.046274
# 반복(step) : 49 , 손실함수(cost) : 0.046025
# 반복(step) : 49 , 손실함수(cost) : 0.048207
# 반복(step) : 49 , 손실함수(cost) : 0.048630
# 반복(step) : 49 , 손실함수(cost) : 0.050459
# 반복(step) : 49 , 손실함수(cost) : 0.048141
# 반복(step) : 49 , 손실함수(cost) : 0.047745
# 반복(step) : 49 , 손실함수(cost) : 0.047071
# 반복(step) : 49 , 손실함수(cost) : 0.048998
# 반복(step) : 49 , 손실함수(cost) : 0.052640
# 반복(step) : 49 , 손실함수(cost) : 0.048093
# 반복(step) : 49 , 손실함수(cost) : 0.048137
# 반복(step) : 49 , 손실함수(cost) : 0.047034
# 반복(step) : 49 , 손실함수(cost) : 0.046724
# 반복(step) : 49 , 손실함수(cost) : 0.046592
# 반복(step) : 49 , 손실함수(cost) : 0.047062
# 반복(step) : 49 , 손실함수(cost) : 0.047682
# 반복(step) : 49 , 손실함수(cost) : 0.046923
# 반복(step) : 49 , 손실함수(cost) : 0.048226
# 반복(step) : 49 , 손실함수(cost) : 0.048103
# 반복(step) : 49 , 손실함수(cost) : 0.048338
# 반복(step) : 49 , 손실함수(cost) : 0.046844
# 반복(step) : 49 , 손실함수(cost) : 0.046961
# 반복(step) : 49 , 손실함수(cost) : 0.046579
# 반복(step) : 49 , 손실함수(cost) : 0.048004
# 반복(step) : 49 , 손실함수(cost) : 0.047319
# 반복(step) : 49 , 손실함수(cost) : 0.045620
# 반복(step) : 49 , 손실함수(cost) : 0.045980
# 반복(step) : 49 , 손실함수(cost) : 0.046993
# 반복(step) : 49 , 손실함수(cost) : 0.048038
# 반복(step) : 49 , 손실함수(cost) : 0.048241
# 반복(step) : 49 , 손실함수(cost) : 0.046790
# 반복(step) : 49 , 손실함수(cost) : 0.047202
# 반복(step) : 49 , 손실함수(cost) : 0.046193
# 반복(step) : 49 , 손실함수(cost) : 0.047602
# 반복(step) : 49 , 손실함수(cost) : 0.047391
# 반복(step) : 49 , 손실함수(cost) : 0.047930
# 반복(step) : 49 , 손실함수(cost) : 0.048785
# 반복(step) : 49 , 손실함수(cost) : 0.049910
# 반복(step) : 49 , 손실함수(cost) : 0.049920
# 반복(step) : 49 , 손실함수(cost) : 0.048152
# 반복(step) : 49 , 손실함수(cost) : 0.046991
# 반복(step) : 49 , 손실함수(cost) : 0.047731
# 반복(step) : 49 , 손실함수(cost) : 0.046813
# 반복(step) : 49 , 손실함수(cost) : 0.046345
# 반복(step) : 49 , 손실함수(cost) : 0.046168
# 반복(step) : 49 , 손실함수(cost) : 0.047254
# 반복(step) : 49 , 손실함수(cost) : 0.045489
# 반복(step) : 49 , 손실함수(cost) : 0.047734
# 반복(step) : 49 , 손실함수(cost) : 0.047676
# 반복(step) : 49 , 손실함수(cost) : 0.048459
# 반복(step) : 49 , 손실함수(cost) : 0.047927
# 반복(step) : 49 , 손실함수(cost) : 0.047630
# 반복(step) : 49 , 손실함수(cost) : 0.047341
# 반복(step) : 49 , 손실함수(cost) : 0.047406
# 반복(step) : 49 , 손실함수(cost) : 0.047394
# 반복(step) : 49 , 손실함수(cost) : 0.047064
# 반복(step) : 49 , 손실함수(cost) : 0.046982
# 반복(step) : 49 , 손실함수(cost) : 0.046697
# 반복(step) : 49 , 손실함수(cost) : 0.047187
# 반복(step) : 49 , 손실함수(cost) : 0.046848
# 반복(step) : 49 , 손실함수(cost) : 0.046614
# 반복(step) : 49 , 손실함수(cost) : 0.046843
# 반복(step) : 49 , 손실함수(cost) : 0.046933
# 반복(step) : 49 , 손실함수(cost) : 0.046710
# 반복(step) : 49 , 손실함수(cost) : 0.047358
# 반복(step) : 49 , 손실함수(cost) : 0.047384
# 반복(step) : 49 , 손실함수(cost) : 0.047916
# 반복(step) : 49 , 손실함수(cost) : 0.046812
# 반복(step) : 49 , 손실함수(cost) : 0.048831
# 반복(step) : 49 , 손실함수(cost) : 0.049290
# 반복(step) : 49 , 손실함수(cost) : 0.048104
# 반복(step) : 49 , 손실함수(cost) : 0.048327
# 반복(step) : 49 , 손실함수(cost) : 0.048902
# 반복(step) : 49 , 손실함수(cost) : 0.048707
# 반복(step) : 49 , 손실함수(cost) : 0.046728
# 반복(step) : 49 , 손실함수(cost) : 0.047543
# 반복(step) : 49 , 손실함수(cost) : 0.045516
# 반복(step) : 49 , 손실함수(cost) : 0.046221
# 반복(step) : 49 , 손실함수(cost) : 0.047148
# 반복(step) : 49 , 손실함수(cost) : 0.047103
# 반복(step) : 49 , 손실함수(cost) : 0.046756
# 반복(step) : 49 , 손실함수(cost) : 0.048154
# 반복(step) : 49 , 손실함수(cost) : 0.047663
# 반복(step) : 49 , 손실함수(cost) : 0.048496
# 반복(step) : 49 , 손실함수(cost) : 0.044498
# 반복(step) : 49 , 손실함수(cost) : 0.046009
# 반복(step) : 49 , 손실함수(cost) : 0.045860
# 반복(step) : 49 , 손실함수(cost) : 0.047574
# 반복(step) : 49 , 손실함수(cost) : 0.047011
# 반복(step) : 49 , 손실함수(cost) : 0.046348
# 반복(step) : 49 , 손실함수(cost) : 0.047636
# 반복(step) : 49 , 손실함수(cost) : 0.045958
# 반복(step) : 49 , 손실함수(cost) : 0.045698
# 반복(step) : 49 , 손실함수(cost) : 0.046365
# 반복(step) : 49 , 손실함수(cost) : 0.047083
# 반복(step) : 49 , 손실함수(cost) : 0.049385
# 반복(step) : 49 , 손실함수(cost) : 0.048427
# 반복(step) : 49 , 손실함수(cost) : 0.048758
# 반복(step) : 49 , 손실함수(cost) : 0.048254
# 반복(step) : 49 , 손실함수(cost) : 0.047641
# 반복(step) : 49 , 손실함수(cost) : 0.047215
# 반복(step) : 49 , 손실함수(cost) : 0.048238
# 반복(step) : 49 , 손실함수(cost) : 0.047252
# 반복(step) : 49 , 손실함수(cost) : 0.047138
# 반복(step) : 49 , 손실함수(cost) : 0.046425
# 반복(step) : 49 , 손실함수(cost) : 0.047983
# 반복(step) : 49 , 손실함수(cost) : 0.047134
# 반복(step) : 49 , 손실함수(cost) : 0.047403
# 반복(step) : 49 , 손실함수(cost) : 0.045859
# 반복(step) : 49 , 손실함수(cost) : 0.045749
# 반복(step) : 49 , 손실함수(cost) : 0.046764
# 반복(step) : 49 , 손실함수(cost) : 0.046406
# 반복(step) : 49 , 손실함수(cost) : 0.047370
# 반복(step) : 49 , 손실함수(cost) : 0.045720
# 반복(step) : 49 , 손실함수(cost) : 0.046242
# 반복(step) : 49 , 손실함수(cost) : 0.047363
# 반복(step) : 49 , 손실함수(cost) : 0.047283
# 반복(step) : 49 , 손실함수(cost) : 0.045575
# 반복(step) : 49 , 손실함수(cost) : 0.046525
# 반복(step) : 49 , 손실함수(cost) : 0.045224
# 반복(step) : 49 , 손실함수(cost) : 0.045219
# 반복(step) : 49 , 손실함수(cost) : 0.045614
# 반복(step) : 49 , 손실함수(cost) : 0.046333
# 반복(step) : 49 , 손실함수(cost) : 0.047968
# 반복(step) : 49 , 손실함수(cost) : 0.047636
# 반복(step) : 49 , 손실함수(cost) : 0.048760
# 반복(step) : 49 , 손실함수(cost) : 0.048714
# 반복(step) : 49 , 손실함수(cost) : 0.048991
# 반복(step) : 49 , 손실함수(cost) : 0.046554
# 반복(step) : 49 , 손실함수(cost) : 0.047649
# 반복(step) : 49 , 손실함수(cost) : 0.048184
# 반복(step) : 49 , 손실함수(cost) : 0.050135
# 반복(step) : 49 , 손실함수(cost) : 0.048359
# 반복(step) : 49 , 손실함수(cost) : 0.047907
# 반복(step) : 49 , 손실함수(cost) : 0.045942
# 반복(step) : 49 , 손실함수(cost) : 0.046450
# 반복(step) : 49 , 손실함수(cost) : 0.046583
# 반복(step) : 49 , 손실함수(cost) : 0.044924
# 반복(step) : 49 , 손실함수(cost) : 0.045425
# 반복(step) : 49 , 손실함수(cost) : 0.046964
# 반복(step) : 49 , 손실함수(cost) : 0.046037
# 반복(step) : 49 , 손실함수(cost) : 0.046931
# 반복(step) : 49 , 손실함수(cost) : 0.045498
# 반복(step) : 49 , 손실함수(cost) : 0.045936
# 반복(step) : 49 , 손실함수(cost) : 0.048425
# 반복(step) : 49 , 손실함수(cost) : 0.048161
# 반복(step) : 49 , 손실함수(cost) : 0.048156
# 반복(step) : 49 , 손실함수(cost) : 0.049843
# 반복(step) : 49 , 손실함수(cost) : 0.046847
# 반복(step) : 49 , 손실함수(cost) : 0.048127
# 반복(step) : 49 , 손실함수(cost) : 0.048552
# 반복(step) : 49 , 손실함수(cost) : 0.047035
# 반복(step) : 49 , 손실함수(cost) : 0.046661
# 반복(step) : 49 , 손실함수(cost) : 0.046736
# 반복(step) : 49 , 손실함수(cost) : 0.047312
# 반복(step) : 49 , 손실함수(cost) : 0.047940
# 반복(step) : 49 , 손실함수(cost) : 0.048102
# 반복(step) : 50 , 손실함수(cost) : 0.046304
# 반복(step) : 50 , 손실함수(cost) : 0.046407
# 반복(step) : 50 , 손실함수(cost) : 0.046462
# 반복(step) : 50 , 손실함수(cost) : 0.046542
# 반복(step) : 50 , 손실함수(cost) : 0.045776
# 반복(step) : 50 , 손실함수(cost) : 0.047390
# 반복(step) : 50 , 손실함수(cost) : 0.046434
# 반복(step) : 50 , 손실함수(cost) : 0.046968
# 반복(step) : 50 , 손실함수(cost) : 0.048299
# 반복(step) : 50 , 손실함수(cost) : 0.047627
# 반복(step) : 50 , 손실함수(cost) : 0.049234
# 반복(step) : 50 , 손실함수(cost) : 0.047708
# 반복(step) : 50 , 손실함수(cost) : 0.046259
# 반복(step) : 50 , 손실함수(cost) : 0.046528
# 반복(step) : 50 , 손실함수(cost) : 0.046715
# 반복(step) : 50 , 손실함수(cost) : 0.046892
# 반복(step) : 50 , 손실함수(cost) : 0.046596
# 반복(step) : 50 , 손실함수(cost) : 0.047640
# 반복(step) : 50 , 손실함수(cost) : 0.046792
# 반복(step) : 50 , 손실함수(cost) : 0.047473
# 반복(step) : 50 , 손실함수(cost) : 0.047267
# 반복(step) : 50 , 손실함수(cost) : 0.047429
# 반복(step) : 50 , 손실함수(cost) : 0.047186
# 반복(step) : 50 , 손실함수(cost) : 0.048826
# 반복(step) : 50 , 손실함수(cost) : 0.048216
# 반복(step) : 50 , 손실함수(cost) : 0.047073
# 반복(step) : 50 , 손실함수(cost) : 0.048255
# 반복(step) : 50 , 손실함수(cost) : 0.048270
# 반복(step) : 50 , 손실함수(cost) : 0.048460
# 반복(step) : 50 , 손실함수(cost) : 0.046051
# 반복(step) : 50 , 손실함수(cost) : 0.047428
# 반복(step) : 50 , 손실함수(cost) : 0.047581
# 반복(step) : 50 , 손실함수(cost) : 0.047617
# 반복(step) : 50 , 손실함수(cost) : 0.047642
# 반복(step) : 50 , 손실함수(cost) : 0.048530
# 반복(step) : 50 , 손실함수(cost) : 0.046396
# 반복(step) : 50 , 손실함수(cost) : 0.045586
# 반복(step) : 50 , 손실함수(cost) : 0.046984
# 반복(step) : 50 , 손실함수(cost) : 0.047180
# 반복(step) : 50 , 손실함수(cost) : 0.048303
# 반복(step) : 50 , 손실함수(cost) : 0.046494
# 반복(step) : 50 , 손실함수(cost) : 0.047498
# 반복(step) : 50 , 손실함수(cost) : 0.048341
# 반복(step) : 50 , 손실함수(cost) : 0.048217
# 반복(step) : 50 , 손실함수(cost) : 0.048413
# 반복(step) : 50 , 손실함수(cost) : 0.048530
# 반복(step) : 50 , 손실함수(cost) : 0.048454
# 반복(step) : 50 , 손실함수(cost) : 0.046931
# 반복(step) : 50 , 손실함수(cost) : 0.046456
# 반복(step) : 50 , 손실함수(cost) : 0.047687
# 반복(step) : 50 , 손실함수(cost) : 0.046844
# 반복(step) : 50 , 손실함수(cost) : 0.046985
# 반복(step) : 50 , 손실함수(cost) : 0.047077
# 반복(step) : 50 , 손실함수(cost) : 0.047805
# 반복(step) : 50 , 손실함수(cost) : 0.047630
# 반복(step) : 50 , 손실함수(cost) : 0.045933
# 반복(step) : 50 , 손실함수(cost) : 0.046875
# 반복(step) : 50 , 손실함수(cost) : 0.047385
# 반복(step) : 50 , 손실함수(cost) : 0.046954
# 반복(step) : 50 , 손실함수(cost) : 0.046615
# 반복(step) : 50 , 손실함수(cost) : 0.048396
# 반복(step) : 50 , 손실함수(cost) : 0.048103
# 반복(step) : 50 , 손실함수(cost) : 0.050513
# 반복(step) : 50 , 손실함수(cost) : 0.046751
# 반복(step) : 50 , 손실함수(cost) : 0.047933
# 반복(step) : 50 , 손실함수(cost) : 0.047987
# 반복(step) : 50 , 손실함수(cost) : 0.048897
# 반복(step) : 50 , 손실함수(cost) : 0.048257
# 반복(step) : 50 , 손실함수(cost) : 0.047323
# 반복(step) : 50 , 손실함수(cost) : 0.046052
# 반복(step) : 50 , 손실함수(cost) : 0.046981
# 반복(step) : 50 , 손실함수(cost) : 0.047325
# 반복(step) : 50 , 손실함수(cost) : 0.047281
# 반복(step) : 50 , 손실함수(cost) : 0.046698
# 반복(step) : 50 , 손실함수(cost) : 0.047983
# 반복(step) : 50 , 손실함수(cost) : 0.046301
# 반복(step) : 50 , 손실함수(cost) : 0.046182
# 반복(step) : 50 , 손실함수(cost) : 0.046173
# 반복(step) : 50 , 손실함수(cost) : 0.046851
# 반복(step) : 50 , 손실함수(cost) : 0.045644
# 반복(step) : 50 , 손실함수(cost) : 0.047351
# 반복(step) : 50 , 손실함수(cost) : 0.046478
# 반복(step) : 50 , 손실함수(cost) : 0.047564
# 반복(step) : 50 , 손실함수(cost) : 0.045714
# 반복(step) : 50 , 손실함수(cost) : 0.047692
# 반복(step) : 50 , 손실함수(cost) : 0.048384
# 반복(step) : 50 , 손실함수(cost) : 0.049092
# 반복(step) : 50 , 손실함수(cost) : 0.048670
# 반복(step) : 50 , 손실함수(cost) : 0.049086
# 반복(step) : 50 , 손실함수(cost) : 0.047954
# 반복(step) : 50 , 손실함수(cost) : 0.048143
# 반복(step) : 50 , 손실함수(cost) : 0.046806
# 반복(step) : 50 , 손실함수(cost) : 0.046503
# 반복(step) : 50 , 손실함수(cost) : 0.046886
# 반복(step) : 50 , 손실함수(cost) : 0.048242
# 반복(step) : 50 , 손실함수(cost) : 0.047535
# 반복(step) : 50 , 손실함수(cost) : 0.047232
# 반복(step) : 50 , 손실함수(cost) : 0.046761
# 반복(step) : 50 , 손실함수(cost) : 0.046224
# 반복(step) : 50 , 손실함수(cost) : 0.046215
# 반복(step) : 50 , 손실함수(cost) : 0.046581
# 반복(step) : 50 , 손실함수(cost) : 0.046286
# 반복(step) : 50 , 손실함수(cost) : 0.046904
# 반복(step) : 50 , 손실함수(cost) : 0.048372
# 반복(step) : 50 , 손실함수(cost) : 0.048404
# 반복(step) : 50 , 손실함수(cost) : 0.047503
# 반복(step) : 50 , 손실함수(cost) : 0.047534
# 반복(step) : 50 , 손실함수(cost) : 0.049100
# 반복(step) : 50 , 손실함수(cost) : 0.047214
# 반복(step) : 50 , 손실함수(cost) : 0.046122
# 반복(step) : 50 , 손실함수(cost) : 0.047894
# 반복(step) : 50 , 손실함수(cost) : 0.047988
# 반복(step) : 50 , 손실함수(cost) : 0.047211
# 반복(step) : 50 , 손실함수(cost) : 0.047283
# 반복(step) : 50 , 손실함수(cost) : 0.047582
# 반복(step) : 50 , 손실함수(cost) : 0.048273
# 반복(step) : 50 , 손실함수(cost) : 0.048197
# 반복(step) : 50 , 손실함수(cost) : 0.047769
# 반복(step) : 50 , 손실함수(cost) : 0.046578
# 반복(step) : 50 , 손실함수(cost) : 0.046135
# 반복(step) : 50 , 손실함수(cost) : 0.045558
# 반복(step) : 50 , 손실함수(cost) : 0.047128
# 반복(step) : 50 , 손실함수(cost) : 0.048254
# 반복(step) : 50 , 손실함수(cost) : 0.046766
# 반복(step) : 50 , 손실함수(cost) : 0.046859
# 반복(step) : 50 , 손실함수(cost) : 0.046107
# 반복(step) : 50 , 손실함수(cost) : 0.048385
# 반복(step) : 50 , 손실함수(cost) : 0.047608
# 반복(step) : 50 , 손실함수(cost) : 0.049605
# 반복(step) : 50 , 손실함수(cost) : 0.047494
# 반복(step) : 50 , 손실함수(cost) : 0.046936
# 반복(step) : 50 , 손실함수(cost) : 0.046100
# 반복(step) : 50 , 손실함수(cost) : 0.047514
# 반복(step) : 50 , 손실함수(cost) : 0.047390
# 반복(step) : 50 , 손실함수(cost) : 0.047141
# 반복(step) : 50 , 손실함수(cost) : 0.046936
# 반복(step) : 50 , 손실함수(cost) : 0.049435
# 반복(step) : 50 , 손실함수(cost) : 0.047021
# 반복(step) : 50 , 손실함수(cost) : 0.047087
# 반복(step) : 50 , 손실함수(cost) : 0.046715
# 반복(step) : 50 , 손실함수(cost) : 0.047105
# 반복(step) : 50 , 손실함수(cost) : 0.048267
# 반복(step) : 50 , 손실함수(cost) : 0.046314
# 반복(step) : 50 , 손실함수(cost) : 0.047278
# 반복(step) : 50 , 손실함수(cost) : 0.045916
# 반복(step) : 50 , 손실함수(cost) : 0.046567
# 반복(step) : 50 , 손실함수(cost) : 0.046504
# 반복(step) : 50 , 손실함수(cost) : 0.047345
# 반복(step) : 50 , 손실함수(cost) : 0.047846
# 반복(step) : 50 , 손실함수(cost) : 0.048586
# 반복(step) : 50 , 손실함수(cost) : 0.047394
# 반복(step) : 50 , 손실함수(cost) : 0.048256
# 반복(step) : 50 , 손실함수(cost) : 0.045854
# 반복(step) : 50 , 손실함수(cost) : 0.045906
# 반복(step) : 50 , 손실함수(cost) : 0.045392
# 반복(step) : 50 , 손실함수(cost) : 0.046625
# 반복(step) : 50 , 손실함수(cost) : 0.046140
# 반복(step) : 50 , 손실함수(cost) : 0.046500
# 반복(step) : 50 , 손실함수(cost) : 0.045770
# 반복(step) : 50 , 손실함수(cost) : 0.045702
# 반복(step) : 50 , 손실함수(cost) : 0.047130
# 반복(step) : 50 , 손실함수(cost) : 0.047071
# 반복(step) : 50 , 손실함수(cost) : 0.048020
# 반복(step) : 50 , 손실함수(cost) : 0.048117
# 반복(step) : 50 , 손실함수(cost) : 0.046077
# 반복(step) : 50 , 손실함수(cost) : 0.046399
# 반복(step) : 50 , 손실함수(cost) : 0.046930
# 반복(step) : 50 , 손실함수(cost) : 0.046969
# 반복(step) : 50 , 손실함수(cost) : 0.046109
# 반복(step) : 50 , 손실함수(cost) : 0.045075
# 반복(step) : 50 , 손실함수(cost) : 0.044656
# 반복(step) : 50 , 손실함수(cost) : 0.043904
# 반복(step) : 50 , 손실함수(cost) : 0.045547
# 반복(step) : 50 , 손실함수(cost) : 0.044811
# 반복(step) : 50 , 손실함수(cost) : 0.043713
# 반복(step) : 50 , 손실함수(cost) : 0.044084
# 반복(step) : 50 , 손실함수(cost) : 0.046152
# 반복(step) : 50 , 손실함수(cost) : 0.043992
# 반복(step) : 50 , 손실함수(cost) : 0.045308
# 반복(step) : 50 , 손실함수(cost) : 0.046219
# 반복(step) : 50 , 손실함수(cost) : 0.044822
# 반복(step) : 50 , 손실함수(cost) : 0.046439
# 반복(step) : 50 , 손실함수(cost) : 0.046266
# 반복(step) : 50 , 손실함수(cost) : 0.047409
# 반복(step) : 50 , 손실함수(cost) : 0.047024
# 반복(step) : 50 , 손실함수(cost) : 0.044656
# 반복(step) : 50 , 손실함수(cost) : 0.045670
# 반복(step) : 50 , 손실함수(cost) : 0.047031
# 반복(step) : 50 , 손실함수(cost) : 0.044790
# 반복(step) : 50 , 손실함수(cost) : 0.045422
# 반복(step) : 50 , 손실함수(cost) : 0.044957
# 반복(step) : 50 , 손실함수(cost) : 0.045045
# 반복(step) : 50 , 손실함수(cost) : 0.045920
# 반복(step) : 50 , 손실함수(cost) : 0.045131
# 반복(step) : 50 , 손실함수(cost) : 0.045653
# 반복(step) : 50 , 손실함수(cost) : 0.046641
# 반복(step) : 50 , 손실함수(cost) : 0.047406
# 반복(step) : 50 , 손실함수(cost) : 0.047205
# 반복(step) : 50 , 손실함수(cost) : 0.046353
# 반복(step) : 50 , 손실함수(cost) : 0.045916
# 반복(step) : 50 , 손실함수(cost) : 0.045149
# 반복(step) : 50 , 손실함수(cost) : 0.046657
# 반복(step) : 50 , 손실함수(cost) : 0.046798
# 반복(step) : 50 , 손실함수(cost) : 0.045698
# 반복(step) : 50 , 손실함수(cost) : 0.043827
# 반복(step) : 50 , 손실함수(cost) : 0.044286
# 반복(step) : 50 , 손실함수(cost) : 0.045910
# 반복(step) : 50 , 손실함수(cost) : 0.045470
# 반복(step) : 50 , 손실함수(cost) : 0.046471
# 반복(step) : 50 , 손실함수(cost) : 0.046071
# 반복(step) : 50 , 손실함수(cost) : 0.045269
# 반복(step) : 50 , 손실함수(cost) : 0.044895
# 반복(step) : 50 , 손실함수(cost) : 0.044257
# 반복(step) : 50 , 손실함수(cost) : 0.045106
