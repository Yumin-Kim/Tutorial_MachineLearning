# %%
import tensorflow.compat.v1 as tf
import numpy as np
tf.disable_v2_behavior()

# %%
x_data = np.array([[0,0],[0,1],[1,0],[1,1]],dtype=np.float32)
y_data = np.array([[0],[1],[1],[0]],dtype=np.float32)

X=tf.placeholder(tf.float32)
Y=tf.placeholder(tf.float32)

# %%
    # Deep model 구성하기 위해서 tf.Variable을 더 깊게 구성하게되면 deep model 완성!!
    #결과는 불일치가 나오며 Neural Net을 활용하면 일치 하는 결과로 출력된다!!

# %%
W1 = tf.Variable(tf.random_normal([2,2]),name='weight1')
b1 = tf.Variable(tf.random_normal([2]),name='bias1')
layer1 = tf.sigmoid(tf.matmul(X,W1) + b1)

W2 = tf.Variable(tf.random_normal([2,1]),name='weight2')
b2 = tf.Variable(tf.random_normal([1]),name='bias2')
hypothesis = tf.sigmoid(tf.matmul(layer1,W2) + b2)
cost = -tf.reduce_mean(Y*tf.log(hypothesis)+(1-Y)*tf.log(1-hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

predicted =tf.cast(hypothesis > 0.5 ,dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted,Y),dtype=tf.float32))
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train,feed_dict={X:x_data,Y:y_data})
        if step % 100 ==0 :
            print(step,sess.run(cost,feed_dict={X:x_data,Y:y_data}),sess.run([W1,W2]))
            
    h,c,a = sess.run([hypothesis,predicted,accuracy],feed_dict={X:x_data,Y:y_data})
    print("\nhypothesis :\n",h,"\nCorrect : ",c,"\,Accuracy: ",a)
# Out:
# 0 0.7644054 [array([[-1.0165758 , -0.55325925],
#        [-2.1101663 ,  1.2171437 ]], dtype=float32), array([[ 1.9402049],
#        [-1.4266354]], dtype=float32)]
# 100 0.7330947 [array([[-0.7378415 , -0.56776637],
#        [-1.9205947 ,  1.1459463 ]], dtype=float32), array([[ 1.5759065],
#        [-1.3172561]], dtype=float32)]
# 200 0.7162565 [array([[-0.51030445, -0.58726084],
#        [-1.7841245 ,  1.1083666 ]], dtype=float32), array([[ 1.3211211],
#        [-1.2195401]], dtype=float32)]
# 300 0.70629644 [array([[-0.32622916, -0.60917866],
#        [-1.687363  ,  1.0972662 ]], dtype=float32), array([[ 1.1326444],
#        [-1.1466228]], dtype=float32)]
# 400 0.70001936 [array([[-0.17618419, -0.63606125],
#        [-1.61968   ,  1.1049383 ]], dtype=float32), array([[ 0.990448 ],
#        [-1.0920503]], dtype=float32)]
# 500 0.69577736 [array([[-0.05232492, -0.669036  ],
#        [-1.5733188 ,  1.1267483 ]], dtype=float32), array([[ 0.88160396],
#        [-1.0520606 ]], dtype=float32)]
# 600 0.69266677 [array([[ 0.05166219, -0.7085796 ],
#        [-1.542585  ,  1.1598305 ]], dtype=float32), array([[ 0.7974662],
#        [-1.0245668]], dtype=float32)]
# 700 0.69016874 [array([[ 0.14066753, -0.7549269 ],
#        [-1.5233487 ,  1.202388  ]], dtype=float32), array([[ 0.7321629],
#        [-1.0083826]], dtype=float32)]
# 800 0.6879687 [array([[ 0.21837884, -0.80826133],
#        [-1.5126519 ,  1.2533175 ]], dtype=float32), array([[ 0.68162066],
#        [-1.0028251 ]], dtype=float32)]
# 900 0.6858605 [array([[ 0.28753942, -0.868798  ],
#        [-1.508391  ,  1.3119912 ]], dtype=float32), array([[ 0.64291894],
#        [-1.0075151 ]], dtype=float32)]
# 1000 0.6836964 [array([[ 0.35017774, -0.93681264],
#        [-1.5090741 ,  1.3781189 ]], dtype=float32), array([[ 0.6138641],
#        [-1.0222592]], dtype=float32)]
# 1100 0.6813589 [array([[ 0.4077862, -1.0126323],
#        [-1.5136397,  1.4516497]], dtype=float32), array([[ 0.59271204],
#        [-1.0469809 ]], dtype=float32)]
# 1200 0.6787461 [array([[ 0.46145058, -1.096605  ],
#        [-1.5213234 ,  1.5326931 ]], dtype=float32), array([[ 0.5779877],
#        [-1.0816659]], dtype=float32)]
# 1300 0.6757657 [array([[ 0.5119387, -1.1890486],
#        [-1.5315623,  1.6214477]], dtype=float32), array([[ 0.56836385],
#        [-1.1263152 ]], dtype=float32)]
# 1400 0.67233276 [array([[ 0.55976236, -1.2901859 ],
#        [-1.5439192 ,  1.7181312 ]], dtype=float32), array([[ 0.56258297],
#        [-1.1808923 ]], dtype=float32)]
# 1500 0.6683721 [array([[ 0.60522  , -1.4000671],
#        [-1.5580322,  1.8229039]], dtype=float32), array([[ 0.55940413],
#        [-1.2452714 ]], dtype=float32)]
# 1600 0.6638241 [array([[ 0.6484306, -1.5184964],
#        [-1.5735712,  1.9357916]], dtype=float32), array([[ 0.55757993],
#        [-1.3191798 ]], dtype=float32)]
# 1700 0.65865177 [array([[ 0.6893644, -1.644972 ],
#        [-1.5902114,  2.0566103]], dtype=float32), array([[ 0.5558509],
#        [-1.4021478]], dtype=float32)]
# 1800 0.6528487 [array([[ 0.72787726, -1.7786598 ],
#        [-1.607619  ,  2.1849043 ]], dtype=float32), array([[ 0.5529649],
#        [-1.4934721]], dtype=float32)]
# 1900 0.6464449 [array([[ 0.76374644, -1.9184122 ],
#        [-1.6254442 ,  2.3199055 ]], dtype=float32), array([[ 0.54771304],
#        [-1.5922132 ]], dtype=float32)]
# 2000 0.63950765 [array([[ 0.7967132, -2.0628297],
#        [-1.6433251,  2.4605484]], dtype=float32), array([[ 0.53897876],
#        [-1.6972177 ]], dtype=float32)]
# 2100 0.6321373 [array([[ 0.8265236, -2.2103639],
#        [-1.6609001,  2.6055229]], dtype=float32), array([[ 0.52578706],
#        [-1.8071821 ]], dtype=float32)]
# 2200 0.6244569 [array([[ 0.85296494, -2.3594363 ],
#        [-1.6778216 ,  2.7533605 ]], dtype=float32), array([[ 0.50734293],
#        [-1.9207344 ]], dtype=float32)]
# 2300 0.61660033 [array([[ 0.87589717, -2.5085437 ],
#        [-1.6937717 ,  2.9025524 ]], dtype=float32), array([[ 0.48305503],
#        [-2.0365248 ]], dtype=float32)]
# 2400 0.6086979 [array([[ 0.89526916, -2.656346  ],
#        [-1.7084749 ,  3.0516613 ]], dtype=float32), array([[ 0.45253557],
#        [-2.1532981 ]], dtype=float32)]
# 2500 0.60086584 [array([[ 0.91112876, -2.801715  ],
#        [-1.7217058 ,  3.1994066 ]], dtype=float32), array([[ 0.41558188],
#        [-2.2699513 ]], dtype=float32)]
# 2600 0.5931996 [array([[ 0.92362225, -2.94376   ],
#        [-1.7332923 ,  3.3447194 ]], dtype=float32), array([[ 0.37214303],
#        [-2.3855639 ]], dtype=float32)]
# 2700 0.58576995 [array([[ 0.9329884, -3.0818207],
#        [-1.7431153,  3.4867582]], dtype=float32), array([[ 0.32227796],
#        [-2.4994001 ]], dtype=float32)]
# 2800 0.57862335 [array([[ 0.9395499, -3.2154539],
#        [-1.7511011,  3.6249115]], dtype=float32), array([[ 0.2661124],
#        [-2.6109025]], dtype=float32)]
# 2900 0.57178444 [array([[ 0.94370884, -3.3443906 ],
#        [-1.7572161 ,  3.758768  ]], dtype=float32), array([[ 0.20379706],
#        [-2.719665  ]], dtype=float32)]
# 3000 0.5652577 [array([[ 0.94593954, -3.4685297 ],
#        [-1.7614541 ,  3.8880908 ]], dtype=float32), array([[ 0.13547009],
#        [-2.8254147 ]], dtype=float32)]
# 3100 0.5590321 [array([[ 0.94679254, -3.5878842 ],
#        [-1.7638237 ,  4.0127845 ]], dtype=float32), array([[ 0.06122471],
#        [-2.9279797 ]], dtype=float32)]
# 3200 0.5530817 [array([[ 0.94690365, -3.70256   ],
#        [-1.764335  ,  4.132859  ]], dtype=float32), array([[-0.01891952],
#        [-3.0272703 ]], dtype=float32)]
# 3300 0.54736686 [array([[ 0.9470181, -3.8127549],
#        [-1.762982 ,  4.248414 ]], dtype=float32), array([[-0.1050467],
#        [-3.123258 ]], dtype=float32)]
# 3400 0.5418342 [array([[ 0.948032 , -3.9187322],
#        [-1.7597209,  4.3596144]], dtype=float32), array([[-0.1973739],
#        [-3.2159507]], dtype=float32)]
# 3500 0.53641266 [array([[ 0.9510646, -4.0208225],
#        [-1.7544409,  4.4666705]], dtype=float32), array([[-0.29628855],
#        [-3.3053765 ]], dtype=float32)]
# 3600 0.531007 [array([[ 0.9575796, -4.119426 ],
#        [-1.746924 ,  4.569834 ]], dtype=float32), array([[-0.40239763],
#        [-3.391554  ]], dtype=float32)]
# 3700 0.5254848 [array([[ 0.96958905, -4.2150297 ],
#        [-1.7367783 ,  4.669381  ]], dtype=float32), array([[-0.5165995],
#        [-3.4744575]], dtype=float32)]
# 3800 0.5196501 [array([[ 0.99000084, -4.3082476 ],
#        [-1.7233458 ,  4.7656116 ]], dtype=float32), array([[-0.6401962],
#        [-3.5539458]], dtype=float32)]
# 3900 0.51319444 [array([[ 1.0232137, -4.399882 ],
#        [-1.7055725,  4.858829 ]], dtype=float32), array([[-0.7750756],
#        [-3.6296363]], dtype=float32)]
# 4000 0.505594 [array([[ 1.076097 , -4.491025 ],
#        [-1.681918 ,  4.9493113]], dtype=float32), array([[-0.9240144],
#        [-3.7006285]], dtype=float32)]
# 4100 0.49591845 [array([[ 1.1593043, -4.583203 ],
#        [-1.650741 ,  5.037221 ]], dtype=float32), array([[-1.0911217],
#        [-3.7649703]], dtype=float32)]
# 4200 0.4826023 [array([[ 1.2874804, -4.6784244],
#        [-1.6129553,  5.1224165]], dtype=float32), array([[-1.2821022],
#        [-3.8188655]], dtype=float32)]
# 4300 0.46386772 [array([[ 1.4725246, -4.7785597],
#        [-1.580946 ,  5.2042108]], dtype=float32), array([[-1.5027032],
#        [-3.8572545]], dtype=float32)]
# 4400 0.43977308 [array([[ 1.7065401, -4.883507 ],
#        [-1.5878862,  5.281675 ]], dtype=float32), array([[-1.7536659],
#        [-3.8802807]], dtype=float32)]
# 4500 0.41244507 [array([[ 1.9620178, -4.9905124],
#        [-1.6661973,  5.3547254]], dtype=float32), array([[-2.028679 ],
#        [-3.8995206]], dtype=float32)]
# 4600 0.38325456 [array([[ 2.2179513, -5.0968556],
#        [-1.8152664,  5.424146 ]], dtype=float32), array([[-2.318755 ],
#        [-3.9278388]], dtype=float32)]
# 4700 0.35302544 [array([[ 2.4663842, -5.2010098],
#        [-2.011639 ,  5.490691 ]], dtype=float32), array([[-2.6141505],
#        [-3.9704018]], dtype=float32)]
# 4800 0.3229528 [array([[ 2.7041454, -5.3017497],
#        [-2.2305331,  5.554808 ]], dtype=float32), array([[-2.9053192],
#        [-4.0274487]], dtype=float32)]
# 4900 0.29429647 [array([[ 2.9289107, -5.397848 ],
#        [-2.453889 ,  5.616725 ]], dtype=float32), array([[-3.1845737],
#        [-4.0976415]], dtype=float32)]
# 5000 0.26794732 [array([[ 3.1389487, -5.4883194],
#        [-2.6706288,  5.6765447]], dtype=float32), array([[-3.447017],
#        [-4.179101]], dtype=float32)]
# 5100 0.24431315 [array([[ 3.3334258, -5.5726347],
#        [-2.8749244,  5.734306 ]], dtype=float32), array([[-3.6904342],
#        [-4.2696476]], dtype=float32)]
# 5200 0.22342403 [array([[ 3.5124035, -5.650698 ],
#        [-3.0643723,  5.7900176]], dtype=float32), array([[-3.9146063],
#        [-4.3669915]], dtype=float32)]
# 5300 0.20509067 [array([[ 3.6766016, -5.7227364],
#        [-3.2385905,  5.8436794]], dtype=float32), array([[-4.120538],
#        [-4.468939]], dtype=float32)]
# 5400 0.18902977 [array([[ 3.8271172, -5.7891636],
#        [-3.39826  ,  5.895302 ]], dtype=float32), array([[-4.3098307],
#        [-4.5735774]], dtype=float32)]
# 5500 0.17494074 [array([[ 3.9652004, -5.85048  ],
#        [-3.5445375,  5.944905 ]], dtype=float32), array([[-4.4842744],
#        [-4.679327 ]], dtype=float32)]
# 5600 0.1625423 [array([[ 4.0921116, -5.907202 ],
#        [-3.6787333,  5.992524 ]], dtype=float32), array([[-4.6455994],
#        [-4.7849636]], dtype=float32)]
# 5700 0.15158698 [array([[ 4.2090445, -5.9598227],
#        [-3.8021374,  6.038209 ]], dtype=float32), array([[-4.7953978],
#        [-4.889566 ]], dtype=float32)]
# 5800 0.14186294 [array([[ 4.317094 , -6.008795 ],
#        [-3.9159472,  6.082024 ]], dtype=float32), array([[-4.9350634],
#        [-4.9924726]], dtype=float32)]
# 5900 0.13319206 [array([[ 4.4172287, -6.0545235],
#        [-4.0212336,  6.1240406]], dtype=float32), array([[-5.0658026],
#        [-5.0932293]], dtype=float32)]
# 6000 0.12542535 [array([[ 4.510311 , -6.0973616],
#        [-4.1189427,  6.1643353]], dtype=float32), array([[-5.1886435],
#        [-5.191538 ]], dtype=float32)]
# 6100 0.1184381 [array([[ 4.5970907, -6.1376185],
#        [-4.2098994,  6.2029867]], dtype=float32), array([[-5.3044653],
#        [-5.287222 ]], dtype=float32)]
# 6200 0.112125985 [array([[ 4.6782265, -6.1755624],
#        [-4.2948213,  6.2400827]], dtype=float32), array([[-5.4140162],
#        [-5.3801923]], dtype=float32)]
# 6300 0.1064013 [array([[ 4.7542887, -6.2114286],
#        [-4.3743343,  6.2757006]], dtype=float32), array([[-5.517937],
#        [-5.470421]], dtype=float32)]
# 6400 0.101190224 [array([[ 4.8257847, -6.2454166],
#        [-4.4489813,  6.3099213]], dtype=float32), array([[-5.616777 ],
#        [-5.5579247]], dtype=float32)]
# 6500 0.09642996 [array([[ 4.8931484, -6.277703 ],
#        [-4.519243 ,  6.3428206]], dtype=float32), array([[-5.7110133],
#        [-5.642753 ]], dtype=float32)]
# 6600 0.09206752 [array([[ 4.9567666, -6.308443 ],
#        [-4.5855284,  6.3744745]], dtype=float32), array([[-5.801057],
#        [-5.724975]], dtype=float32)]
# 6700 0.08805707 [array([[ 5.0169773, -6.3377705],
#        [-4.6482034,  6.4049506]], dtype=float32), array([[-5.8872666],
#        [-5.8046737]], dtype=float32)]
# 6800 0.084359616 [array([[ 5.0740767, -6.3658037],
#        [-4.7075896,  6.434317 ]], dtype=float32), array([[-5.969956],
#        [-5.881945]], dtype=float32)]
# 6900 0.08094157 [array([[ 5.1283307, -6.392647 ],
#        [-4.763969 ,  6.4626346]], dtype=float32), array([[-6.0494027],
#        [-5.9568753]], dtype=float32)]
# 7000 0.0777736 [array([[ 5.179974 , -6.4183936],
#        [-4.817592 ,  6.4899635]], dtype=float32), array([[-6.1258535],
#        [-6.029567 ]], dtype=float32)]
# 7100 0.07483035 [array([[ 5.2292147, -6.4431243],
#        [-4.868681 ,  6.516357 ]], dtype=float32), array([[-6.1995263],
#        [-6.100115 ]], dtype=float32)]
# 7200 0.0720895 [array([[ 5.276241 , -6.466915 ],
#        [-4.917439 ,  6.5418673]], dtype=float32), array([[-6.270616 ],
#        [-6.1686144]], dtype=float32)]
# 7300 0.069531836 [array([[ 5.3212175, -6.4898314],
#        [-4.96404  ,  6.566541 ]], dtype=float32), array([[-6.339298 ],
#        [-6.2351575]], dtype=float32)]
# 7400 0.06713994 [array([[ 5.3642974, -6.511934 ],
#        [-5.008647 ,  6.5904255]], dtype=float32), array([[-6.40573  ],
#        [-6.2998333]], dtype=float32)]
# 7500 0.06489899 [array([[ 5.4056134, -6.533272 ],
#        [-5.0513997,  6.613561 ]], dtype=float32), array([[-6.4700546],
#        [-6.3627267]], dtype=float32)]
# 7600 0.06279549 [array([[ 5.4452877, -6.553897 ],
#        [-5.0924296,  6.635987 ]], dtype=float32), array([[-6.5324006],
#        [-6.423919 ]], dtype=float32)]
# 7700 0.060817573 [array([[ 5.483433, -6.573852],
#        [-5.131854,  6.657741]], dtype=float32), array([[-6.592886 ],
#        [-6.4834847]], dtype=float32)]
# 7800 0.058954805 [array([[ 5.520148 , -6.5931787],
#        [-5.1697817,  6.6788554]], dtype=float32), array([[-6.6516166],
#        [-6.5415006]], dtype=float32)]
# 7900 0.057197586 [array([[ 5.555526 , -6.611913 ],
#        [-5.206307 ,  6.6993613]], dtype=float32), array([[-6.70869  ],
#        [-6.5980334]], dtype=float32)]
# 8000 0.05553744 [array([[ 5.5896487, -6.6300893],
#        [-5.2415195,  6.719291 ]], dtype=float32), array([[-6.7642  ],
#        [-6.653148]], dtype=float32)]
# 8100 0.05396684 [array([[ 5.622593 , -6.6477365],
#        [-5.2754984,  6.7386713]], dtype=float32), array([[-6.8182282],
#        [-6.7069087]], dtype=float32)]
# 8200 0.052478924 [array([[ 5.654429 , -6.6648855],
#        [-5.3083196,  6.7575283]], dtype=float32), array([[-6.8708496],
#        [-6.7593727]], dtype=float32)]
# 8300 0.051067453 [array([[ 5.685221 , -6.68156  ],
#        [-5.3400493,  6.7758856]], dtype=float32), array([[-6.9221363],
#        [-6.8105965]], dtype=float32)]
# 8400 0.04972689 [array([[ 5.715029 , -6.6977854],
#        [-5.3707504,  6.793767 ]], dtype=float32), array([[-6.9721527],
#        [-6.860632 ]], dtype=float32)]
# 8500 0.048452176 [array([[ 5.7439065, -6.713584 ],
#        [-5.400482 ,  6.8111944]], dtype=float32), array([[-7.02096 ],
#        [-6.909528]], dtype=float32)]
# 8600 0.04723863 [array([[ 5.7719045, -6.728978 ],
#        [-5.4292946,  6.828187 ]], dtype=float32), array([[-7.068614],
#        [-6.95733 ]], dtype=float32)]
# 8700 0.04608217 [array([[ 5.799068 , -6.743984 ],
#        [-5.457238 ,  6.8447647]], dtype=float32), array([[-7.115168],
#        [-7.004085]], dtype=float32)]
# 8800 0.04497883 [array([[ 5.8254423, -6.7586226],
#        [-5.484358 ,  6.8609433]], dtype=float32), array([[-7.160672 ],
#        [-7.0498333]], dtype=float32)]
# 8900 0.043925233 [array([[ 5.8510656, -6.772908 ],
#        [-5.510698 ,  6.876742 ]], dtype=float32), array([[-7.20517  ],
#        [-7.0946145]], dtype=float32)]
# 9000 0.04291811 [array([[ 5.875977 , -6.786859 ],
#        [-5.5362945,  6.8921742]], dtype=float32), array([[-7.248706],
#        [-7.138467]], dtype=float32)]
# 9100 0.041954458 [array([[ 5.90021  , -6.800488 ],
#        [-5.5611844,  6.907257 ]], dtype=float32), array([[-7.291321],
#        [-7.181426]], dtype=float32)]
# 9200 0.041031744 [array([[ 5.9237957, -6.813809 ],
#        [-5.585404 ,  6.9220047]], dtype=float32), array([[-7.333051],
#        [-7.223525]], dtype=float32)]
# 9300 0.040147323 [array([[ 5.9467683, -6.8268356],
#        [-5.608982 ,  6.9364295]], dtype=float32), array([[-7.3739333],
#        [-7.264795 ]], dtype=float32)]
# 9400 0.039298967 [array([[ 5.9691515, -6.8395796],
#        [-5.6319504,  6.9505434]], dtype=float32), array([[-7.4139986],
#        [-7.305267 ]], dtype=float32)]
# 9500 0.038484633 [array([[ 5.9909735, -6.8520513],
#        [-5.6543355,  6.9643598]], dtype=float32), array([[-7.4532814],
#        [-7.3449697]], dtype=float32)]
# 9600 0.037702248 [array([[ 6.0122595, -6.8642635],
#        [-5.6761637,  6.977889 ]], dtype=float32), array([[-7.4918103],
#        [-7.3839297]], dtype=float32)]
# 9700 0.036950056 [array([[ 6.0330324, -6.8762245],
#        [-5.697459 ,  6.9911413]], dtype=float32), array([[-7.5296125],
#        [-7.4221745]], dtype=float32)]
# 9800 0.03622636 [array([[ 6.0533133, -6.8879457],
#        [-5.718245 ,  7.0041285]], dtype=float32), array([[-7.566715 ],
#        [-7.4597263]], dtype=float32)]
# 9900 0.035529576 [array([[ 6.0731235, -6.8994346],
#        [-5.7385435,  7.0168586]], dtype=float32), array([[-7.6031437],
#        [-7.496611 ]], dtype=float32)]
# 10000 0.03485833 [array([[ 6.0924826, -6.9106984],
#        [-5.758372 ,  7.0293407]], dtype=float32), array([[-7.6389217],
#        [-7.5328507]], dtype=float32)]
#
# hypothesis :
#  [[0.03074433]
#  [0.95947045]
#  [0.9612887 ]
#  [0.02698152]]
# Correct :  [[0.]
#  [1.]
#  [1.]
#  [0.]] \,Accuracy:  1.0
